# %% [markdown]
# # Movies!
#
# **Because who doesn't love a good movie?**

# %% [markdown]
# We've all been there: it's another Friday night, and the COVID pandemic has limited our options for evening entertainment. Go to a party at a friend's house? Can't -- that'd be irresponsible and potentially dangerous. Check out a night club? Nope (let's be real, that was an awful option even before the pandemic hit).
#
# And so, we're resorting once again to -- movie night! Make some stove top popcorn and plop down for 90 - 180 minutes of unbridled cinematic joy in the comfort of your own home (and pajamas).
#
# But how can we possibly make the best choice possible when there are so many options? Nothing is worse than watching the ending credits flash on the screen and thinking (or exclaiming aloud, in extreme instances), "MAN, that sucked!" Here to help is a **movie recommender engine** using data obtained from <https://github.com/rashida048/Datasets/blob/master/movie_dataset.csv>

# %% [markdown]
# ## Part I: Exploration
#
# Let's read in the `dataset` and do some preliminary analysis.

# %%
# Make necessary imports
import pandas as pd
import numpy as np

# %%
# Read in the CSV file and check the head
movies = pd.read_csv('../datasets/movie_dataset.csv')
movies.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2         spy based on novel secret agent sequel mi6                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ... runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...   162.0
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...   169.0
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...   148.0
# 3  Following the death of District Attorney Harve...  112.312950  ...   165.0
# 4  John Carter is a war-weary, former military ca...   43.926995  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
# 2  Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# 3  Christian Bale Michael Caine Gary Oldman Anne ...
# 4  Taylor Kitsch Lynn Collins Samantha Morton Wil...
#
#                                                 crew           director
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...      James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...     Gore Verbinski
# 2  [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 3  [{'name': 'Hans Zimmer', 'gender': 2, 'departm...  Christopher Nolan
# 4  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton
#
# [5 rows x 24 columns]

# %%
# How many rows and columns does our dataset have?
movies.shape
# Out:
# (4803, 24)

# %%
# What are the names of the columns in our dataset?
movies.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director'],
#       dtype='object')

# %%
# How many nulls are in our dataset?
movies.isnull().sum().sort_values(ascending = False)
# Out:
# homepage                3091
# tagline                  844
# keywords                 412
# cast                      43
# director                  30
# genres                    28
# overview                   3
# runtime                    2
# release_date               1
# popularity                 0
# budget                     0
# id                         0
# original_language          0
# original_title             0
# production_countries       0
# production_companies       0
# crew                       0
# revenue                    0
# spoken_languages           0
# status                     0
# title                      0
# vote_average               0
# vote_count                 0
# index                      0
# dtype: int64

# %%
# What datatype is each column?
movies.dtypes
# Out:
# index                     int64
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# cast                     object
# crew                     object
# director                 object
# dtype: object

# %% [markdown]
# **Let's look at each column one by one to see what the data looks like**

# %% [markdown]
# # Part II: Step by Step Examination and Cleaning

# %% [markdown]
# ### Index

# %%
# Preview column index
movies[['index']]
# Out:
#       index
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 4798   4798
# 4799   4799
# 4800   4800
# 4801   4801
# 4802   4802
#
# [4803 rows x 1 columns]

# %% [markdown]
# This data simply matches the already-existing index data of each row. This column can and should be `dropped`.

# %%
# Drop this useless column from the dataframe
movies.drop(columns = 'index', inplace = True)

# %% [markdown]
# ### **Genres**

# %%
# Preview column genres
movies[['genres']]
# Out:
#                                         genres
# 0     Action Adventure Fantasy Science Fiction
# 1                     Adventure Fantasy Action
# 2                       Action Adventure Crime
# 3                  Action Crime Drama Thriller
# 4             Action Adventure Science Fiction
# ...                                        ...
# 4798                     Action Crime Thriller
# 4799                            Comedy Romance
# 4800             Comedy Drama Romance TV Movie
# 4801                                       NaN
# 4802                               Documentary
#
# [4803 rows x 1 columns]

# %% [markdown]
# It looks like this column contains each genre that can be categorically applied to each movie, with no sperator betweemn the genres (i.e., `,`). Let's look to see what the longest `genre` cell in this dataset look like.

# %%
# Sort movies by longest genre
movies.genres.str.len().sort_values(ascending = False)
# Out:
# 1617    51.0
# 3208    50.0
# 305     50.0
# 1277    50.0
# 168     50.0
#         ...
# 4674     NaN
# 4681     NaN
# 4714     NaN
# 4716     NaN
# 4801     NaN
# Name: genres, Length: 4803, dtype: float64

# %%
movies.iloc[1617]['genres']
# Out:
# 'Action Adventure Animation Science Fiction Thriller'

# %% [markdown]
# This movie looks like the greatest one on the list! Who wouldn't want to watch an `Action/Adventure/Animation/Science Fiction/Thriller?`
#
# When taking a glance at the `NaNs` in this dataset, we can see that there are `28` blank cells in the `genre` category. Let's clear those out now.

# %%
# Drop rows in which the 'genre' values are NaNs.
movies = movies[movies['genres'].notna()]

# Check work
movies[movies['genres'].isna()]
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count, cast, crew, director]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# **How many unique genres are there in the dataset?**

# %%
# Create an empty list called 'genres'
genres = []

# Create a list of indices as long as the column 'genres' in the dataframe
for i in range(0, len(movies['genres'])):
    
    # Isolate each cell one by one and create a list of genres in the cell
    cell = movies.iloc[i]['genres'].split(' ')
    
    # Loop through each list to look for unique genres
    for genre in cell:
        
        # Add unique genres to the genre list
        if genre not in genres:
            genres.append(genre)
            
# Take a look at the genres list and how many unique genres are in it
print(f'There are {len(genres)} unique genres in the dataset, and they are:')
print(genres)
# Out:
# There are 22 unique genres in the dataset, and they are:
# ['Action', 'Adventure', 'Fantasy', 'Science', 'Fiction', 'Crime', 'Drama', 'Thriller', 'Animation', 'Family', 'Western', 'Comedy', 'Romance', 'Horror', 'Mystery', 'History', 'War', 'Music', 'Documentary', 'Foreign', 'TV', 'Movie']

# %% [markdown]
# Looking above, it looks like `Science Fiction` has been split up into `Science` and `Fiction`. This might be ignorable if this had happened to `Romantic Comedy`, but we can't ignore the 2nd best movie `genre` out there (the first being `Horror`, of course).
#
# We can also see that there are 2 genres, one being `TV` and one being `Movie`, that are included in this dataset. This is likely a split of the genre `TV Movie`. If the genre `TV Movie` were shortened to just `TV`, no context would be lost. That said, let's drop `Movie` from final `genres` list.
#
# Let's re-write the function above to fix this. This will be necessary in `binarizing` this column later.

# %%
# Create an empty list called 'genres'
genres = []

# Create a list of indices as long as the column 'genres' in the dataframe
for i in range(0, len(movies['genres'])):
    
    # Isolate each cell one by one and create a list of genres in the cell
    cell = movies.iloc[i]['genres'].split(' ')
    
    # Look for 'Science' and 'Fiction' in each cell
    if 'Science' and 'Fiction' in cell:
        
        # Drop 'Science'
        cell.remove('Science')
        
        # Drop 'Fiction'
        cell.remove('Fiction')
        
        #Add 'Science Fiction'
        cell.append('Science_Fiction')
    
    # Loop through each list to look for unique genres
    for genre in cell:
        
        # Skip over the genre 'Movie'
        if genre == 'Movie':
            pass

        # Add unique genres to the genre list
        elif genre not in genres:
            genres.append(genre)
            
# Take a look at the genres list and how many unique genres are in it
print(f'There are {len(genres)} unique genres in the dataset, and they are:')
print(genres)
# Out:
# There are 20 unique genres in the dataset, and they are:
# ['Action', 'Adventure', 'Fantasy', 'Science_Fiction', 'Crime', 'Drama', 'Thriller', 'Animation', 'Family', 'Western', 'Comedy', 'Romance', 'Horror', 'Mystery', 'History', 'War', 'Music', 'Documentary', 'Foreign', 'TV']

# %% [markdown]
# **Now, let's binarize the genres and drop the genres column from the dataset**

# %%
def binarize_genres(df):
    
    # Create a new dataframe with a column for each unique genre in the list above
    df2 = pd.DataFrame(columns = [genre for genre in genres], index = df.index, data = 0)
        
    # Create a list of indices as long as the column 'genres' in the dataframe
    for i in range(0, len(df['genres'])):
    
        # Isolate each cell one by one and create a list of genres in the cell
        cell = df.iloc[i]['genres'].split(' ')
    
        # Look for 'Science' and 'Fiction' in each cell
        if 'Science' and 'Fiction' in cell:
        
            # Drop 'Science'
            cell.remove('Science')
        
            # Drop 'Fiction'
            cell.remove('Fiction')
        
            #Add 'Science Fiction'
            cell.append('Science_Fiction')
    
        # Loop through the cell for each genre
        for genre in cell:
        
            # Loop through each column of df2
            for column in df2.columns:
                
                # Skip over the genre 'Movie'
                # This step is redundant, as we've already dropped 'Movies' from the 'genres' list, which
                # /n was used to create all the columns in df2. This has been included for continuity's sake.
                if genre == 'Movie':
                    pass
                
                # Look for matching genres
                elif genre == column:
                    
                    # Mark the genre as a 1
                    df2[column].iloc[i] += 1
    
    # Create a list variable called frames for our 2 dataframes
    frames = [df, df2]
    
    # Concatenate the two dataframes
    final_df = pd.concat(frames, axis = 1, sort = False)
    
    return final_df

# %%
# Call function and change 
movies = binarize_genres(movies)

# Drop the genres column now that we've binarized its contents
movies.drop(columns = 'genres', inplace = True)

# %% [markdown]
# ### **Home page**

# %%
movies[['homepage']]
# Out:
#                                                homepage
# 0                           http://www.avatarmovie.com/
# 1          http://disney.go.com/disneypictures/pirates/
# 2           http://www.sonypictures.com/movies/spectre/
# 3                    http://www.thedarkknightrises.com/
# 4                  http://movies.disney.com/john-carter
# ...                                                 ...
# 4797                                                NaN
# 4798                                                NaN
# 4799                                                NaN
# 4800  http://www.hallmarkchannel.com/signedsealeddel...
# 4802                                                NaN
#
# [4775 rows x 1 columns]

# %% [markdown]
# This column isn't important for a recommender engine and can be dropped.

# %%
# Drop column 'homepage' from dataset
movies.drop(columns = 'homepage', inplace = True)

# %% [markdown]
# ### **ID**

# %%
movies[['id']]
# Out:
#           id
# 0      19995
# 1        285
# 2     206647
# 3      49026
# 4      49529
# ...      ...
# 4797   67238
# 4798    9367
# 4799   72766
# 4800  231617
# 4802   25975
#
# [4775 rows x 1 columns]

# %% [markdown]
# This column isn't important for a recommender engine and can be dropped.

# %%
# Drop column 'id' from dataset
movies.drop(columns = 'id', inplace = True)

# %% [markdown]
# ### **Keywords**

# %%
movies[['keywords']]
# Out:
#                                                keywords
# 0     culture clash future space war space colony so...
# 1     ocean drug abuse exotic island east india trad...
# 2            spy based on novel secret agent sequel mi6
# 3     dc comics crime fighter terrorist secret ident...
# 4     based on novel mars medallion space travel pri...
# ...                                                 ...
# 4797                                                NaN
# 4798  united states\u2013mexico barrier legs arms pa...
# 4799                                                NaN
# 4800  date love at first sight narration investigati...
# 4802               obsession camcorder crush dream girl
#
# [4775 rows x 1 columns]

# %% [markdown]
# This looks like a tricky column. Not only are there 412 `NaNs` in this column, but the keywords here look pretty subjective. Who decided on these keywords? The Academy at large? Probably not. Due to its subjectivity and missing data, this column looks droppable from the final dataset.

# %%
# Drop column 'keywords' from dataset
movies.drop(columns = 'keywords', inplace = True)

# %% [markdown]
# ### **Original Language**

# %%
movies[['original_language']]
# Out:
#      original_language
# 0                   en
# 1                   en
# 2                   en
# 3                   en
# 4                   en
# ...                ...
# 4797                en
# 4798                es
# 4799                en
# 4800                en
# 4802                en
#
# [4775 rows x 1 columns]

# %%
# Check unique values of this column
movies.original_language.unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %% [markdown]
# It's unclear what a majority of these abbreviations stand for. There's no key for what these might stand for on the website from which this dataset was pulled, which isn't helpful. Should  we drop this column from the dataset? Or attempt to find a key for this online somewhere? Probably not -- a different key might have been created by someone who would abbreviate languages differently, which could corrupt the accuracy of this dataset.

# %%
movies.original_language.describe()
# Out:
# count     4775
# unique      37
# top         en
# freq      4477
# Name: original_language, dtype: object

# %% [markdown]
# It looks like there are 298 movies of the 4,803 in this dataset that aren't in English. In the interest of time, simplicity, and accuracy, it may be worth changing this project to a movie recommendation enginge in which all movies are in English.

# %%
# Look at the dataset for all non-English movies
movies[movies['original_language'] != 'en']
# Out:
#         budget original_language                      original_title  \
# 97    15000000                ja                              シン・ゴジラ
# 235   97250400                fr         Astérix aux Jeux Olympiques
# 317   94000000                zh                               金陵十三釵
# 474          0                fr                           Évolution
# 492    8000000                es  Don Gato: El inicio de la pandilla
# ...        ...               ...                                 ...
# 4739         0                fr         I Love You, Don't Touch Me!
# 4751         0                pt            Gabriela, Cravo e Canela
# 4790         0                fa                               دایره
# 4792     20000                ja                                 キュア
# 4798    220000                es                         El Mariachi
#
#                                                overview  popularity  \
# 97    From the mind behind Evangelion comes a hit la...    9.476999
# 235   Astérix and Obélix have to win the Olympic Gam...   20.344364
# 317   A Westerner finds refuge with a group of women...   12.516546
# 474   11-year-old Nicolas lives with his mother in a...    3.300061
# 492   Top Cat has arrived to charm his way into your...    0.719996
# ...                                                 ...         ...
# 4739  The story of a 25 year old virgin girl, lookin...    0.020839
# 4751  In 1925, Gabriela becomes cook, mistress, and ...    0.557602
# 4790  Various women struggle to function in the oppr...    1.193779
# 4792  A wave of gruesome murders is sweeping Tokyo. ...    0.212443
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
#
#                                    production_companies  \
# 97    [{"name": "Cine Bazar", "id": 5896}, {"name": ...
# 235   [{"name": "Constantin Film", "id": 47}, {"name...
# 317   [{"name": "Beijing New Picture Film Co. Ltd.",...
# 474   [{"name": "Ex Nihilo", "id": 3307}, {"name": "...
# 492   [{"name": "Anima Estudios", "id": 9965}, {"nam...
# ...                                                 ...
# 4739                                                 []
# 4751  [{"name": "United Artists", "id": 60}, {"name"...
# 4790  [{"name": "Jafar Panahi Film Productions", "id...
# 4792             [{"name": "Daiei Studios", "id": 881}]
# 4798           [{"name": "Columbia Pictures", "id": 5}]
#
#                                    production_countries release_date  \
# 97              [{"iso_3166_1": "JP", "name": "Japan"}]   2016-07-29
# 235   [{"iso_3166_1": "BE", "name": "Belgium"}, {"is...   2008-01-13
# 317   [{"iso_3166_1": "CN", "name": "China"}, {"iso_...   2011-12-15
# 474   [{"iso_3166_1": "BE", "name": "Belgium"}, {"is...   2015-09-14
# 492   [{"iso_3166_1": "IN", "name": "India"}, {"iso_...   2015-10-30
# ...                                                 ...          ...
# 4739  [{"iso_3166_1": "US", "name": "United States o...   1997-01-21
# 4751           [{"iso_3166_1": "BR", "name": "Brazil"}]   1983-03-24
# 4790             [{"iso_3166_1": "IR", "name": "Iran"}]   2000-09-08
# 4792            [{"iso_3166_1": "JP", "name": "Japan"}]   1997-11-06
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
#
#         revenue  runtime  ... Comedy Romance Horror Mystery  History  War  \
# 97     77000000    120.0  ...      0       0      1       0        0    0
# 235   132900000    116.0  ...      1       0      0       0        0    0
# 317    95311434    145.0  ...      0       0      0       0        1    1
# 474           0     81.0  ...      0       0      1       1        0    0
# 492           0     89.0  ...      1       0      0       0        0    0
# ...         ...      ...  ...    ...     ...    ...     ...      ...  ...
# 4739          0     86.0  ...      1       1      0       0        0    0
# 4751          0     99.0  ...      0       1      0       0        0    0
# 4790          0     90.0  ...      0       0      0       0        0    0
# 4792      99000    111.0  ...      0       0      1       1        0    0
# 4798    2040920     81.0  ...      0       0      0       0        0    0
#
#      Music Documentary Foreign  TV
# 97       0           0       0   0
# 235      0           0       0   0
# 317      0           0       0   0
# 474      0           0       0   0
# 492      0           0       0   0
# ...    ...         ...     ...  ..
# 4739     0           0       0   0
# 4751     0           0       0   0
# 4790     0           0       1   0
# 4792     0           0       0   0
# 4798     0           0       0   0
#
# [298 rows x 39 columns]

# %% [markdown]
# After exploring this list on non-English movies further, my decision to drop these from the dataset is validated. Although the `overview` column for these movies are in English, what good is a movie recommendation for a film called "دایره" for someone who doesn't speak that native language? I searched for "دایره" on Google to see if I was able to find the movie described in this dataset, but my search turned up no results.
#
# Let's drop these movies from our dataset.

# %%
# Drop all non-English movies
movies = movies[movies['original_language'] == 'en']

# %%
# Now that all movies are in English, we can drop this column from our dataframe
movies.drop(columns = 'original_language', inplace = True)

# %% [markdown]
# ### **Original Title**

# %%
movies[['original_title']]
# Out:
#                                 original_title
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4796                                    Primer
# 4797                                    Cavite
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4802                         My Date with Drew
#
# [4477 rows x 1 columns]

# %% [markdown]
# Nothing to see here. Using any `Natural Language Processing` or `Binarizing` here would be a mistake, unless people prefer to make watching decisions based on a movie's title and title alone.
#
# What we can do, however, is set this column to be the dataframe's `index` column.

# %%
#Set index
movies.set_index('original_title', inplace = True)

# Check work
movies.head()
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
#
#                                                                                    overview  \
# original_title
# Avatar                                    In the 22nd century, a paraplegic Marine is di...
# Pirates of the Caribbean: At World's End  Captain Barbossa, long believed to be dead, ha...
# Spectre                                   A cryptic message from Bond’s past sends him o...
# The Dark Knight Rises                     Following the death of District Attorney Harve...
# John Carter                               John Carter is a war-weary, former military ca...
#
#                                           popularity  \
# original_title
# Avatar                                    150.437577
# Pirates of the Caribbean: At World's End  139.082615
# Spectre                                   107.376788
# The Dark Knight Rises                     112.312950
# John Carter                                43.926995
#
#                                                                        production_companies  \
# original_title
# Avatar                                    [{"name": "Ingenious Film Partners", "id": 289...
# Pirates of the Caribbean: At World's End  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# Spectre                                   [{"name": "Columbia Pictures", "id": 5}, {"nam...
# The Dark Knight Rises                     [{"name": "Legendary Pictures", "id": 923}, {"...
# John Carter                                     [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                                                        production_countries  \
# original_title
# Avatar                                    [{"iso_3166_1": "US", "name": "United States o...
# Pirates of the Caribbean: At World's End  [{"iso_3166_1": "US", "name": "United States o...
# Spectre                                   [{"iso_3166_1": "GB", "name": "United Kingdom"...
# The Dark Knight Rises                     [{"iso_3166_1": "US", "name": "United States o...
# John Carter                               [{"iso_3166_1": "US", "name": "United States o...
#
#                                          release_date     revenue  runtime  \
# original_title
# Avatar                                     2009-12-10  2787965087    162.0
# Pirates of the Caribbean: At World's End   2007-05-19   961000000    169.0
# Spectre                                    2015-10-26   880674609    148.0
# The Dark Knight Rises                      2012-07-16  1084939099    165.0
# John Carter                                2012-03-07   284139100    132.0
#
#                                                                            spoken_languages  \
# original_title
# Avatar                                    [{"iso_639_1": "en", "name": "English"}, {"iso...
# Pirates of the Caribbean: At World's End           [{"iso_639_1": "en", "name": "English"}]
# Spectre                                   [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# The Dark Knight Rises                              [{"iso_639_1": "en", "name": "English"}]
# John Carter                                        [{"iso_639_1": "en", "name": "English"}]
#
#                                             status  ... Comedy Romance  \
# original_title                                      ...
# Avatar                                    Released  ...      0       0
# Pirates of the Caribbean: At World's End  Released  ...      0       0
# Spectre                                   Released  ...      0       0
# The Dark Knight Rises                     Released  ...      0       0
# John Carter                               Released  ...      0       0
#
#                                           Horror  Mystery History War Music  \
# original_title
# Avatar                                         0        0       0   0     0
# Pirates of the Caribbean: At World's End       0        0       0   0     0
# Spectre                                        0        0       0   0     0
# The Dark Knight Rises                          0        0       0   0     0
# John Carter                                    0        0       0   0     0
#
#                                           Documentary  Foreign  TV
# original_title
# Avatar                                              0        0   0
# Pirates of the Caribbean: At World's End            0        0   0
# Spectre                                             0        0   0
# The Dark Knight Rises                               0        0   0
# John Carter                                         0        0   0
#
# [5 rows x 37 columns]

# %% [markdown]
# ### **Overview**

# %%
movies[['overview']]
# Out:
#                                                                                    overview
# original_title
# Avatar                                    In the 22nd century, a paraplegic Marine is di...
# Pirates of the Caribbean: At World's End  Captain Barbossa, long believed to be dead, ha...
# Spectre                                   A cryptic message from Bond’s past sends him o...
# The Dark Knight Rises                     Following the death of District Attorney Harve...
# John Carter                               John Carter is a war-weary, former military ca...
# ...                                                                                     ...
# Primer                                    Friends/fledgling entrepreneurs invent a devic...
# Cavite                                    Adam, a security guard, travels from Californi...
# Newlyweds                                 A newlywed couple's honeymoon is upended by th...
# Signed, Sealed, Delivered                 "Signed, Sealed, Delivered" introduces a dedic...
# My Date with Drew                         Ever since the second grade when he first saw ...
#
# [4477 rows x 1 columns]

# %% [markdown]
# This column looks more insightful than the `keywords` column. We can use `Natural Language Processing` when creating the model for this dataset.
#
# Before doing so, let's check one more time for `NaNs` in this column. There were `3` of them for `overview` initially, but we've dropped some data from the dataframe `movies` at this point in this jupyter notebook.

# %%
# Check once more for nulls in the 'overview' column
movies['overview'].isna().sum()
# Out:
# 1

# %%
# Let's check to see what this one null overview is from
movies[movies['overview'].isna()]
# Out:
#                              budget overview  popularity  \
# original_title
# To Be Frank, Sinatra at 100       2      NaN    0.050625
#
#                                                          production_companies  \
# original_title
# To Be Frank, Sinatra at 100  [{"name": "Eyeline Entertainment", "id": 60343}]
#
#                                                          production_countries  \
# original_title
# To Be Frank, Sinatra at 100  [{"iso_3166_1": "GB", "name": "United Kingdom"}]
#
#                             release_date  revenue  runtime spoken_languages  \
# original_title
# To Be Frank, Sinatra at 100   2015-12-12        0      NaN               []
#
#                                status  ... Comedy Romance  Horror  Mystery  \
# original_title                         ...
# To Be Frank, Sinatra at 100  Released  ...      0       0       0        0
#
#                             History War Music  Documentary  Foreign  TV
# original_title
# To Be Frank, Sinatra at 100       0   0     0            1        0   0
#
# [1 rows x 37 columns]

# %% [markdown]
# Ahhh yes, the critically acclaimed "To Be Frank, Sinatra at 100", the rave documentary with the $2 budget.
#
# On a serious note -- if we remove this film from our dataframe, we'll be able to use NLP for 100% of the `overviews`.

# %%
# Remove the movie 'To Be Frank, Sinartra at 100' from the dataframe
movies.drop(labels = 'To Be Frank, Sinatra at 100', inplace = True)

# %%
# Import Tokenizer
from nltk.tokenize import RegexpTokenizer

# Import Lemmatizer
from nltk.stem import WordNetLemmatizer

# Import stopwords.
from nltk.corpus import stopwords

# %%
# Write a function to tokenize and then lemmatize the overview
def lemmatize_overview(df):
    
    # Create an empty list that will ultimately be a new column of lemmas
    overview_lemmas = []

    # Instantiate a tokenizer
    # Include the 'r\w+' to ignore spaces and punctuation
    tokenizer = RegexpTokenizer(r'\w+')
    
    # Instantiate a lemmatizer
    lemmatizer = WordNetLemmatizer()
    
    for cell in df['overview']:
        
        # Tokenize the individual overview
        overview_tokens = tokenizer.tokenize(cell.lower())
        
        # Lemmatize the individual overview
        overview_lemma = [lemmatizer.lemmatize(token) for token in overview_tokens]
        
        # Append the lemmatized cell to the empty list titles 'overview_lemmas'
        overview_lemmas.append(overview_lemma)
    
    # Drop the original overview column from the dataframe
    df.drop(columns = 'overview', inplace = True)
    
    # Replace column with the lemmas, rename it 'overview'
    df['overview'] = overview_lemmas
    
    # Return df
    return df

# %%
# Call the function and see if it worked
movies = lemmatize_overview(movies)
movies['overview']
# Out:
# original_title
# Avatar                                      [in, the, 22nd, century, a, paraplegic, marine...
# Pirates of the Caribbean: At World's End    [captain, barbossa, long, believed, to, be, de...
# Spectre                                     [a, cryptic, message, from, bond, s, past, sen...
# The Dark Knight Rises                       [following, the, death, of, district, attorney...
# John Carter                                 [john, carter, is, a, war, weary, former, mili...
#                                                                   ...
# Primer                                      [friend, fledgling, entrepreneur, invent, a, d...
# Cavite                                      [adam, a, security, guard, travel, from, calif...
# Newlyweds                                   [a, newlywed, couple, s, honeymoon, is, upende...
# Signed, Sealed, Delivered                   [signed, sealed, delivered, introduces, a, ded...
# My Date with Drew                           [ever, since, the, second, grade, when, he, fi...
# Name: overview, Length: 4476, dtype: object

# %% [markdown]
# Now that we've `tokenized` and `lemmatized` the `overview` column, we can use one of the vectorizer alogrorithms (either `CountVectorizer` or `TFIDFVectorizer` to process the language for modeling. We'll do that in the next notebook, right before creating the `recommendation engine` itself.

# %% [markdown]
# ### **Popularity**

# %%
movies[['popularity']]
# Out:
#                                           popularity
# original_title
# Avatar                                    150.437577
# Pirates of the Caribbean: At World's End  139.082615
# Spectre                                   107.376788
# The Dark Knight Rises                     112.312950
# John Carter                                43.926995
# ...                                              ...
# Primer                                     23.307949
# Cavite                                      0.022173
# Newlyweds                                   0.642552
# Signed, Sealed, Delivered                   1.444476
# My Date with Drew                           1.929883
#
# [4476 rows x 1 columns]

# %% [markdown]
# I don't like data columns like these. How is this measured? On what scale? And according to whom? It's a set of data that's a bit too subjective for my liking.
#
# That being said, let's drop this column from our dataset.

# %%
movies.drop(columns = ['popularity'], inplace = True)

# %% [markdown]
# ### **Production Companies**

# %%
movies[['production_companies']]
# Out:
#                                                                        production_companies
# original_title
# Avatar                                    [{"name": "Ingenious Film Partners", "id": 289...
# Pirates of the Caribbean: At World's End  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# Spectre                                   [{"name": "Columbia Pictures", "id": 5}, {"nam...
# The Dark Knight Rises                     [{"name": "Legendary Pictures", "id": 923}, {"...
# John Carter                                     [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                                                     ...
# Primer                                                   [{"name": "Thinkfilm", "id": 446}]
# Cavite                                                                                   []
# Newlyweds                                                                                []
# Signed, Sealed, Delivered                 [{"name": "Front Street Pictures", "id": 3958}...
# My Date with Drew                         [{"name": "rusty bear entertainment", "id": 87...
#
# [4476 rows x 1 columns]

# %%
# Let's look at an example of a single "production_company" cell value
movies['production_companies'][0]
# Out:
# '[{"name": "Ingenious Film Partners", "id": 289}, {"name": "Twentieth Century Fox Film Corporation", "id": 306}, {"name": "Dune Entertainment", "id": 444}, {"name": "Lightstorm Entertainment", "id": 574}]'

# %% [markdown]
# It looks like this is a lit of dictionaries that has been converted into a string. In the cell below, I'll see if it'll be possible to isolate the names of the production companies, which will be crucial to doing some feature engineering in the next notebook.

# %%
# Let's used json to convert this string back to a list of dictionaries
import json

# Use the .loads methodology to 
production_companies_0 = json.loads(movies['production_companies'][0])
production_companies_0
# Out:
# [{'name': 'Ingenious Film Partners', 'id': 289},
#  {'name': 'Twentieth Century Fox Film Corporation', 'id': 306},
#  {'name': 'Dune Entertainment', 'id': 444},
#  {'name': 'Lightstorm Entertainment', 'id': 574}]

# %%
# Create an empty list called 'production_companies'
production_companies = []

# Create a list of indices as long as the column 'production_companies' in the dataframe
for i in range(0, len(movies['production_companies'])):
    
    # Isolate each cell one by one and create a list of production_companies in the cell
    cell = movies.iloc[i]['production_companies'].split(' ')
    
    # Loop through each list to look for unique production_companies
    for production_company in cell:
        
        # Add unique production_companies to the production_companies list
        if production_company not in production_companies:
            production_companies.append(production_company)
            
# Take a look at the production_companies list and how many unique production_companies are in it
print(f'There are {len(production_companies)} unique production_companies in the dataset, and they are:')
print(production_companies)
# Out:
# There are 10433 unique production_companies in the dataset, and they are:
# ['[{"name":', '"Ingenious', 'Film', 'Partners",', '"id":', '289},', '{"name":', '"Twentieth', 'Century', 'Fox', 'Corporation",', '306},', '"Dune', 'Entertainment",', '444},', '"Lightstorm', '574}]', '"Walt', 'Disney', 'Pictures",', '2},', '"Jerry', 'Bruckheimer', 'Films",', '130},', '"Second', 'Mate', 'Productions",', '19936}]', '"Columbia', '5},', '"Danjaq",', '10761},', '"B24",', '69434}]', '"Legendary', '923},', '"Warner', 'Bros.",', '6194},', '"DC', '9993},', '"Syncopy",', '9996}]', '2}]', '"Laura', 'Ziskin', '326},', '"Marvel', 'Enterprises",', '19551}]', 'Animation', 'Studios",', '6125}]', '420},', '"Prime', 'Focus",', '15357},', '"Revolution', 'Sun', '76043}]', '"Heyday', '7364}]', 'Comics",', '429},', '"Atlas', '507},', '"Cruel', '&', 'Unusual', '9995},', '"RatPac-Dune', '41624}]', '"Bad', 'Hat', 'Harry', '9168}]', '"Eon', '7576}]', '"Infinitum', 'Nihil",', '2691},', '"Silver', 'Bullet', 'Productions', '(II)",', '37380},', '"Blind', 'Wink', '37381},', '"Classic', 'Media",', '37382}]', '9996},', 'and', '78685}]', 'Disney",', '5888},', '"Walden', '10221},', '"Stillking', '11345},', '"Ozumi', '11440},', '"Propeler",', '11441},', '"Silverbell', '11442},', '"Paramount', '4},', '420}]', '"Moving', 'Picture', 'Company', '(MPC)",', '20478}]', '"Amblin', '56},', '"Media', 'Magik', '5627},', '"Imagenation', 'Abu', 'Dhabi', 'FZ",', '6736},', '"Hemisphere', 'Media', 'Capital",', '9169},', '"Parkes/MacDonald', '11084}]', '"WingNut', '11},', '"New', 'Line', 'Cinema",', '12},', 'Bros.', '174},', '"3Foot7",', '7413},', '"Metro-Goldwyn-Mayer', '(MGM)",', '8411}]', '7505}]', '"Imagine', '23},', '"Universal', '33},', '"Scott', 'Free', '1645},', '"Relativity', '7295}]', '"Depth', 'of', 'Field",', '1473},', '"Scholastic', '1938}]', '"Big', 'Primate', '68},', '"MFPV', 'Film",', '69}]', '"Studio', 'Babelsberg",', '264},', 'Studios', 'Motion', '3036},', '"Vita-Ray', 'Dutch', '(III)",', '84424},', '"Deluxe', 'Digital', '84425}]', '"Hasbro",', '2598},', '"Bluegrass', '13778},', '"Film', '44",', '20153}]', '13},', '"Fuji', 'Television', 'Network",', '3341},', '"Dentsu",', '6452}]', '5}]', '"Team', 'Todd",', '598},', '"Tim', 'Burton', '8601},', '"Roth', '16314},', '"Zanuck', 'Company,', 'The",', '20004}]', '"Donners\'', 'Company",', '431},', '"Major', 'Studio', '445},', '9168},', '"thinkfilm",', '12247},', '19551},', '"X3', 'Canada', '79028},', '"X3US', '79029},', '"XM3', 'Service",', '79030}]', '"Pixar', '3}]', '"DreamWorks', 'SKG",', '27},', '"Di', 'Bonaventura', '435},', '"Platinum', 'Dunes",', '2481},', '"Hasbro', '22826},', '"China', 'Movie', 'Channel",', '11413},', '"Ian', 'Bryce', '38833},', '16314}]', '"Avi', 'Arad', '31828},', '"Matt', 'Tolmach', '53462}]', '"LivePlanet",', '7161},', '"Prana', '18713},', '"Sean', 'Bailey', '23791},', '76043},', '"Kontsept', '76067}]', '"De', '2609},', '9993}]', '"The', 'Halcyon', '4021},', '"Wonderland', 'Sound', 'Vision",', '4022},', '6194}]', '"Original', '333},', '6452},', '"One', 'Race', '7154},', 'Co.",', '40890},', '"Qu\\u00e9bec', 'Production', 'Services', 'Tax', 'Credit",', '86352},', 'Rights', 'Capital', '(MRC)",', '86655},', '"Abu', 'Commission",', '87857},', '"Colorado', 'Office', 'Film,', '87858}]', '"GK', '3281},', '"Skydance', '6277},', '"Apparatus', '11956},', '"Latina', '19108},', '"2DUX\\u00b2",', '23644}]', '7505},', '"TSG', '22213},', '"Down', '37336},', 'Robot",', '11461},', '"Kurtzman/Orci",', '12536}]', 'Kid', '8406},', '"Village', 'Roadshow', '79},', '"Bazmark', '240},', '"A&E', 'Networks",', '11858},', '"Red', 'Wagon', '14440},', '"Spectrum', '14604}]', '130}]', '"Disney', 'Double', 'Dare', 'You', '(DDY)",', '19750},', '"Indochina', '19751}]', '19751},', '22826}]', '"Lucasfilm",', '1},', '4}]', '"Perfect', 'Storm', '34530},', '"Alibaba', 'Pictures', 'Group",', '69484},', '82819},', '"Sneaky', 'Shark",', '83644},', '"Huahua', '83645}]', '3},', '"FortyFour', '93408}]', '12}]', '"Centropolis', '347},', 'Mark', 'Gordon', '1557},', '"Farewell', '10905}]', '"ImageMovers",', '11395}]', ' ...

# %% [markdown]
# This was worth exploring, but this looks like a column that should be dropped. There are `10,433` unique production companies (upon further review, it's less than that -- for instance, "New Line Cinema" was split up into "New", "Line", and "Cinema". Fixing this simply isn't worth the effort -- including these companies in the dataframe may have been valuable, but its value doesn't justify the time it'll take to work on this.

# %%
# Let's drop this column from the dataframe
movies.drop(columns = 'production_companies', inplace = True)

# %% [markdown]
# ### **Production Countries**

# %%
movies[['production_countries']]
# Out:
#                                                                        production_countries
# original_title
# Avatar                                    [{"iso_3166_1": "US", "name": "United States o...
# Pirates of the Caribbean: At World's End  [{"iso_3166_1": "US", "name": "United States o...
# Spectre                                   [{"iso_3166_1": "GB", "name": "United Kingdom"...
# The Dark Knight Rises                     [{"iso_3166_1": "US", "name": "United States o...
# John Carter                               [{"iso_3166_1": "US", "name": "United States o...
# ...                                                                                     ...
# Primer                                    [{"iso_3166_1": "US", "name": "United States o...
# Cavite                                                                                   []
# Newlyweds                                                                                []
# Signed, Sealed, Delivered                 [{"iso_3166_1": "US", "name": "United States o...
# My Date with Drew                         [{"iso_3166_1": "US", "name": "United States o...
#
# [4476 rows x 1 columns]

# %% [markdown]
# The same is true in this column as was in the `production_companies` column. We can convert these to a `dictionary` from a string, but would it even be worth it? `production_countries` probably isn't a great predictor for a recommendation engine.

# %%
movies.drop(columns = 'production_countries', inplace = True)

# %% [markdown]
# ### **Release Date**

# %%
movies['release_date']
# Out:
# original_title
# Avatar                                      2009-12-10
# Pirates of the Caribbean: At World's End    2007-05-19
# Spectre                                     2015-10-26
# The Dark Knight Rises                       2012-07-16
# John Carter                                 2012-03-07
#                                                ...
# Primer                                      2004-10-08
# Cavite                                      2005-03-12
# Newlyweds                                   2011-12-26
# Signed, Sealed, Delivered                   2013-10-13
# My Date with Drew                           2005-08-05
# Name: release_date, Length: 4476, dtype: object

# %% [markdown]
# The `data type` here is an `object` and should instead be converted to a `datetime` format.

# %%
# Import datetime
from datetime import datetime

# Change datatype of 'release_date' column to datetime
movies['release_date'] = pd.to_datetime(movies['release_date'])

# Check work
movies['release_date']
# Out:
# original_title
# Avatar                                     2009-12-10
# Pirates of the Caribbean: At World's End   2007-05-19
# Spectre                                    2015-10-26
# The Dark Knight Rises                      2012-07-16
# John Carter                                2012-03-07
#                                               ...
# Primer                                     2004-10-08
# Cavite                                     2005-03-12
# Newlyweds                                  2011-12-26
# Signed, Sealed, Delivered                  2013-10-13
# My Date with Drew                          2005-08-05
# Name: release_date, Length: 4476, dtype: datetime64[ns]

# %% [markdown]
# ### Runtime

# %%
# Check format and data type
movies['runtime']
# Out:
# original_title
# Avatar                                      162.0
# Pirates of the Caribbean: At World's End    169.0
# Spectre                                     148.0
# The Dark Knight Rises                       165.0
# John Carter                                 132.0
#                                             ...
# Primer                                       77.0
# Cavite                                       80.0
# Newlyweds                                    85.0
# Signed, Sealed, Delivered                   120.0
# My Date with Drew                            90.0
# Name: runtime, Length: 4476, dtype: float64

# %%
# There were 2 NaNs initially in this dataframe -- how many are there now?
movies['runtime'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Spoken Languages

# %%
# Check format and data type
movies['spoken_languages']
# Out:
# original_title
# Avatar                                      [{"iso_639_1": "en", "name": "English"}, {"iso...
# Pirates of the Caribbean: At World's End             [{"iso_639_1": "en", "name": "English"}]
# Spectre                                     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# The Dark Knight Rises                                [{"iso_639_1": "en", "name": "English"}]
# John Carter                                          [{"iso_639_1": "en", "name": "English"}]
#                                                                   ...
# Primer                                               [{"iso_639_1": "en", "name": "English"}]
# Cavite                                                                                     []
# Newlyweds                                                                                  []
# Signed, Sealed, Delivered                            [{"iso_639_1": "en", "name": "English"}]
# My Date with Drew                                    [{"iso_639_1": "en", "name": "English"}]
# Name: spoken_languages, Length: 4476, dtype: object

# %%
# Isolate one cell to see what its contents look like
movies['spoken_languages'][0]
# Out:
# '[{"iso_639_1": "en", "name": "English"}, {"iso_639_1": "es", "name": "Espa\\u00f1ol"}]'

# %% [markdown]
# The contents of this column are unclear. I've seen Avatar, the movie that the `spoken_languages` above corresponds to, and there's no Spanish in the movie. Could it mean that there exists a Spanish translated version of Avatar?
#
# Whatever the purpose of this column is, it doesn't appear to be necessary. Let's drop it.

# %%
movies.drop(columns = ['spoken_languages'], inplace = True)

# %% [markdown]
# ### Status

# %%
# Check format and data type
movies['status']
# Out:
# original_title
# Avatar                                      Released
# Pirates of the Caribbean: At World's End    Released
# Spectre                                     Released
# The Dark Knight Rises                       Released
# John Carter                                 Released
#                                               ...
# Primer                                      Released
# Cavite                                      Released
# Newlyweds                                   Released
# Signed, Sealed, Delivered                   Released
# My Date with Drew                           Released
# Name: status, Length: 4476, dtype: object

# %%
# Look at unique values in this column
movies['status'].unique()
# Out:
# array(['Released', 'Post Production', 'Rumored'], dtype=object)

# %% [markdown]
# `Rumored` and movies in `Post Production` are included in this? Let's take a closer look.

# %%
# Take a look at all movies with the status 'Post Production'
movies[movies['status'] == 'Post Production']
# Out:
#                  budget release_date  revenue  runtime           status  \
# original_title
# Brotherly Love  1900000   2015-04-24        0     89.0  Post Production
# Higher Ground   2000000   2011-08-26   841733    109.0  Post Production
#
#                tagline           title  vote_average  vote_count  \
# original_title
# Brotherly Love     NaN  Brotherly Love           6.9          21
# Higher Ground      NaN   Higher Ground           5.3          14
#
#                                                              cast  ...  \
# original_title                                                     ...
# Brotherly Love  Keke Palmer Cory Hardrict Eric D. Hill Jr. Qui...  ...
# Higher Ground   Vera Farmiga Donna Murphy Dagmara Domi\u0144cz...  ...
#
#                Romance Horror  Mystery  History  War  Music  Documentary  \
# original_title
# Brotherly Love       0      0        0        0    0      0            0
# Higher Ground        0      0        0        0    0      0            0
#
#                 Foreign  TV                                           overview
# original_title
# Brotherly Love        0   0  [west, philadelphia, basketball, star, sergio,...
# Higher Ground         0   0  [a, chronicle, of, one, woman, s, lifelong, st...
#
# [2 rows x 33 columns]

# %%
# Take a look at all movies with the status 'Rumored'
movies[movies['status'] == 'Rumored']
# Out:
#                           budget release_date  revenue  runtime   status  \
# original_title
# The Helix... Loaded            0   2005-01-01        0     97.0  Rumored
# Crying with Laughter           0   2009-06-01        0     93.0  Rumored
# The Harvest (La Cosecha)   56000   2011-07-29        0     80.0  Rumored
# Little Big Top                 0   2006-01-01        0      0.0  Rumored
# The Naked Ape                  0   2006-09-16        0    110.0  Rumored
#
#                                               tagline  \
# original_title
# The Helix... Loaded                               NaN
# Crying with Laughter      A Bad Trip Down Memory Lane
# The Harvest (La Cosecha)                          NaN
# Little Big Top                                    NaN
# The Naked Ape                                     NaN
#
#                                              title  vote_average  vote_count  \
# original_title
# The Helix... Loaded            The Helix... Loaded           4.8           2
# Crying with Laughter          Crying with Laughter           7.0           1
# The Harvest (La Cosecha)  The Harvest (La Cosecha)           0.0           0
# Little Big Top                      Little Big Top          10.0           1
# The Naked Ape                        The Naked Ape           5.0           1
#
#                                                                        cast  \
# original_title
# The Helix... Loaded                                                     NaN
# Crying with Laughter      Stephen McCole Malcolm Shields Andrew Neil Jo ...
# The Harvest (La Cosecha)                                                NaN
# Little Big Top            Sid Haig Richard Riehle Mel England Jacob Zach...
# The Naked Ape             Josh Wise Chelse Swain Sean Shanks Amanda MacD...
#
#                           ... Romance Horror  Mystery  History  War  Music  \
# original_title            ...
# The Helix... Loaded       ...       0      0        0        0    0      0
# Crying with Laughter      ...       0      0        0        0    0      0
# The Harvest (La Cosecha)  ...       0      0        0        0    0      0
# Little Big Top            ...       0      0        0        0    0      0
# The Naked Ape             ...       0      0        0        0    0      0
#
#                           Documentary  Foreign  TV  \
# original_title
# The Helix... Loaded                 0        0   0
# Crying with Laughter                0        0   0
# The Harvest (La Cosecha)            1        0   0
# Little Big Top                      0        0   0
# The Naked Ape                       0        0   0
#
#                                                                    overview
# original_title
# The Helix... Loaded                                                      []
# Crying with Laughter      [powerfully, redemptive, and, darkly, comedic,...
# The Harvest (La Cosecha)  [the, story, of, the, child, who, work, 12, 14...
# Little Big Top            [an, aging, out, of, work, clown, return, to, ...
# The Naked Ape             [the, naked, ape, is, a, coming, of, age, film...
#
# [5 rows x 33 columns]

# %% [markdown]
# Movies with statuses that are anything except for `Released` should be droppped. Not only is a movie reccomendation for a movie that hasn't been released a crappy recommendation, but these movies look like they were never released. For example, The Naked Ape (ahem) has apparently been rumored since 2006, and a simple Google search has confirmed that there is no such film.

# %%
# Drop the 36 movies from the dataframe whose statuses are either 'Rumored' or 'Post Production'
movies = movies[movies['status'] == 'Released']

# %%
# Now let's drop the 'status' column from the dataset, now that all the data within it is uniform
movies.drop(columns = ['status'], inplace = True)

# %% [markdown]
# ### Tagline

# %%
movies['tagline']
# Out:
# original_title
# Avatar                                                            Enter the World of Pandora.
# Pirates of the Caribbean: At World's End       At the end of the world, the adventure begins.
# Spectre                                                                 A Plan No One Escapes
# The Dark Knight Rises                                                         The Legend Ends
# John Carter                                              Lost in our world, found in another.
#                                                                   ...
# Primer                                                     What happens if it actually works?
# Cavite                                                                                    NaN
# Newlyweds                                   A newlywed couple's honeymoon is upended by th...
# Signed, Sealed, Delivered                                                                 NaN
# My Date with Drew                                                                         NaN
# Name: tagline, Length: 4469, dtype: object

# %% [markdown]
# This column essentially looks like a less informative and far cornier edition of the `overview` column. Let's drop it.

# %%
movies.drop(columns = ['tagline'], inplace = True)

# %% [markdown]
# That's odd that the above command generated a warning...let's check to make sure that this column is gone from `movies`.

# %%
movies.columns
# Out:
# Index(['budget', 'release_date', 'revenue', 'runtime', 'status', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'Action',
#        'Adventure', 'Fantasy', 'Science_Fiction', 'Crime', 'Drama', 'Thriller',
#        'Animation', 'Family', 'Western', 'Comedy', 'Romance', 'Horror',
#        'Mystery', 'History', 'War', 'Music', 'Documentary', 'Foreign', 'TV',
#        'overview'],
#       dtype='object')

# %% [markdown]
# Good, it looks like the column is gone.

# %% [markdown]
# ### Title
#
# How is this different from `original_title` ?

# %%
# Check column and data type
movies['title']
# Out:
# original_title
# Avatar                                                                        Avatar
# Pirates of the Caribbean: At World's End    Pirates of the Caribbean: At World's End
# Spectre                                                                      Spectre
# The Dark Knight Rises                                          The Dark Knight Rises
# John Carter                                                              John Carter
#                                                               ...
# Primer                                                                        Primer
# Cavite                                                                        Cavite
# Newlyweds                                                                  Newlyweds
# Signed, Sealed, Delivered                                  Signed, Sealed, Delivered
# My Date with Drew                                                  My Date with Drew
# Name: title, Length: 4469, dtype: object

# %% [markdown]
# Let's check to see how exactly, if it all, this column is different from `orginial_title`.

# %%
# Define a function to look for differences in 'original_title' and 'title'
def check_title_differences(df):
    
    # Create an empty dataframe
    title_differences = pd.DataFrame()
    
    # Create an empty list called 'original titles'
    original_titles = []
    
    # Create an empty list called 'titles'
    titles = []
    
    # Start for loop to go through the entire dataframe
    for i in range(0, len(df.index)):
        
        # If statement: if 'original title' and 'title' are unequal values
        if df.index[i] != df.iloc[i]['title']:
            
            # Add unequal original title to appropriate list
            original_titles.append(df.index[i])
            
            # Add unequal title to appropriate list
            titles.append(df.iloc[i]['title'])
    
    # Create 'original titles' column in new dataframe with newly created list
    title_differences['original_titles'] = original_titles
    
    # Create 'titles' column in new dataframe with newly created list
    title_differences['titles'] = titles
    
    # Return new dataframe
    return title_differences

# %%
# Call function on 'movies' dataframe
check_title_differences(movies)
# Out:
#                            original_titles  \
# 0             4: Rise of the Silver Surfer
# 1                   Arthur et les Minimoys
# 2                              Deux frères
# 3             Michael Jackson's This Is It
# 4                             Lo imposible
# 5                                    Nomad
# 6                   Le Hussard sur le toit
# 7                       The House of Magic
# 8                    The Neverending Story
# 9                                EverAfter
# 10            Highlander III: The Sorcerer
# 11                     La migliore offerta
# 12  Sammy's avonturen: De geheime doorgang
# 13                                   Chéri
# 14                                 三国之见龙卸甲
# 15                                  Saw 3D
# 16           Jackass Presents: Bad Grandpa
# 17                  The Hills Have Eyes II
# 18                                 Bathory
# 19                                Autómata
# 20                La veuve de Saint-Pierre
# 21                      How to Be a Player
# 22                          Run Fatboy Run
# 23          La femme de chambre du Titanic
# 24                          Hai Marjawaan!
# 25                     Due occhi diabolici
# 26        Star Wars: Clone Wars (Volume 1)
# 27                          Håkon Håkonsen
# 28  And When Did You Last See Your Father?
# 29                             Hodejegerne
# 30               Salvando al Soldado Perez
# 31                             Dawn Patrol
# 32                            Opposite Sex
# 33                       Rejsen til Saturn
# 34                               Mad Max 2
# 35                              Jerusalema
# 36                         $upercapitalist
# 37                   Walking with the Dead
# 38                   La Navaja De Don Juan
# 39                            Cama adentro
# 40           L.I.E. Long Island Expressway
# 41                            Arnolds Park
# 42                   Kita svajonių komanda
# 43                           Chats perchés
#
#                                         titles
# 0       Fantastic 4: Rise of the Silver Surfer
# 1                    Arthur and the Invisibles
# 2                                 Two Brothers
# 3                                   This Is It
# 4                               The Impossible
# 5                           Nomad: The Warrior
# 6                     The Horseman on the Roof
# 7               Thunder and the House of Magic
# 8                        The NeverEnding Story
# 9               Ever After: A Cinderella Story
# 10             Highlander: The Final Dimension
# 11                              The Best Offer
# 12         A Turtle's Tale: Sammy's Adventures
# 13                                       Cheri
# 14  Three Kingdoms: Resurrection of the Dragon
# 15                      Saw: The Final Chapter
# 16                                 Bad Grandpa
# 17                       The Hills Have Eyes 2
# 18                  Bathory: Countess of Blood
# 19                                    Automata
# 20                   The Widow of Saint-Pierre
# 21                Def Jam's How to Be a Player
# 22                            Run, Fatboy, Run
# 23              The Chambermaid on the Titanic
# 24                  It's a Wonderful Afterlife
# 25                               Two Evil Eyes
# 26             Star Wars: Clone Wars: Volume 1
# 27                                 Shipwrecked
# 28          When Did You Last See Your Father?
# 29                                 Headhunters
# 30                        Saving Private Perez
# 31                                    Stranded
# 32                            The Opposite Sex
# 33                           Journey to Saturn
# 34                 Mad Max 2: The Road Warrior
# 35             Gangster's Paradise: Jerusalema
# 36                             Supercapitalist
# 37                        The Walking Deceased
# 38                       The Blade of Don Juan
# 39                                Live-In Maid
# 40                                      L.I.E.
# 41                         Carousel of Revenge
# 42                        The Other Dream Team
# 43                The Case of the Grinning Cat

# %% [markdown]
# It might be a good idea to reset the index of `movies` to `titles`, simply because the column `title` seems to be entirely in English, whereas the `original_title` column (which is now the index) does not.

# %%
# Check columns
movies.columns
# Out:
# Index(['budget', 'release_date', 'revenue', 'runtime', 'status', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'Action',
#        'Adventure', 'Fantasy', 'Science_Fiction', 'Crime', 'Drama', 'Thriller',
#        'Animation', 'Family', 'Western', 'Comedy', 'Romance', 'Horror',
#        'Mystery', 'History', 'War', 'Music', 'Documentary', 'Foreign', 'TV',
#        'overview'],
#       dtype='object')

# %%
# Drop 'title' from the dataframe now that it's been set as the index
movies.drop(columns = 'title', inplace = True)

# %% [markdown]
# ### Vote Average and Vote Count

# %%
# Preview column
movies['vote_average']
# Out:
# original_title
# Avatar                                      7.2
# Pirates of the Caribbean: At World's End    6.9
# Spectre                                     6.3
# The Dark Knight Rises                       7.6
# John Carter                                 6.1
#                                            ...
# Primer                                      6.9
# Cavite                                      7.5
# Newlyweds                                   5.9
# Signed, Sealed, Delivered                   7.0
# My Date with Drew                           6.3
# Name: vote_average, Length: 4469, dtype: float64

# %%
# Preview column
movies['vote_count']
# Out:
# original_title
# Avatar                                      11800
# Pirates of the Caribbean: At World's End     4500
# Spectre                                      4466
# The Dark Knight Rises                        9106
# John Carter                                  2124
#                                             ...
# Primer                                        658
# Cavite                                          2
# Newlyweds                                       5
# Signed, Sealed, Delivered                       6
# My Date with Drew                              16
# Name: vote_count, Length: 4469, dtype: int64

# %% [markdown]
# These are much better indicators of popularity than the obscure column titled `popularity` that was dropped previously.

# %% [markdown]
# ### Cast

# %%
# Preview column
movies['cast']
# Out:
# original_title
# Avatar                                      Sam Worthington Zoe Saldana Sigourney Weaver S...
# Pirates of the Caribbean: At World's End    Johnny Depp Orlando Bloom Keira Knightley Stel...
# Spectre                                     Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# The Dark Knight Rises                       Christian Bale Michael Caine Gary Oldman Anne ...
# John Carter                                 Taylor Kitsch Lynn Collins Samantha Morton Wil...
#                                                                   ...
# Primer                                      Shane Carruth David Sullivan Casey Gooden Anan...
# Cavite                                                                                    NaN
# Newlyweds                                   Edward Burns Kerry Bish\u00e9 Marsha Dietlein ...
# Signed, Sealed, Delivered                   Eric Mabius Kristin Booth Crystal Lowe Geoff G...
# My Date with Drew                           Drew Barrymore Brian Herzlinger Corey Feldman ...
# Name: cast, Length: 4469, dtype: object

# %%
# Isolate a single cell in this column for a preview
movies['cast'][0]
# Out:
# 'Sam Worthington Zoe Saldana Sigourney Weaver Stephen Lang Michelle Rodriguez'

# %% [markdown]
# This is a difficult column to work with. While I believe a movie's cast can be a good indicator when it comes to making movie recommendations, there are likely far too many actors in this dataset to account for. Is it possible? Yes. But it would mean that there were more columns than rows in this dataset, which is never a best practice.
#
# Perhaps what we can do it just isolate the first actor in the dataset and drop the rest of the cast from the column, thus renaming the column from `cast` to `star`.
#
# Before doing so, we need to see if there are any `NaNs` in this column, or else the `.split()` method will break the for loop.

# %%
# Number of nulls for 'cast' column
movies['cast'].isnull().sum()
# Out:
# 24

# %%
# Let's take a look at all these movies
movies[movies['cast'].isna()]
# Out:
#                                         budget release_date   revenue  \
# original_title
# Barney's Great Adventure                     0   1998-01-01         0
# Running Forever                              0   2015-10-27         0
# 2016: Obama's America                  2500000   2012-07-13  33400000
# Me You and Five Bucks                        1   2015-07-07         0
# Down & Out With The Dolls                    0   2003-03-20         0
# Sex With Strangers                           0   2002-02-22         0
# The Hadza:  Last of the First                0   2014-10-31         0
# Mad Hot Ballroom                             0   2005-05-13         0
# Straight Out of Brooklyn                     0   1991-06-13         0
# I Want Your Money                            0   2010-07-06         0
# Fabled                                       0   2002-01-01         0
# Sisters in Law                               0   2005-09-03         0
# Ayurveda: Art of Being                  300000   2001-09-20   2074000
# Amidst the Devil's Wings                300000   2014-12-01         0
# Call + Response                              0   2008-10-10         0
# Chats perchés                                0   2004-12-05         0
# The Trials Of Darryl Hunt                    0   2007-06-15         0
# Butterfly Girl                               0   2014-03-10         0
# Antarctic Edge: 70° South                    0   2015-04-17         0
# Top Spin                                     0   2014-11-15         0
# Peace, Propaganda & the Promised Land        0   2005-01-28         0
# Counting                                 50000   2015-02-09         0
# Bending Steel                                0   2013-04-20         0
# Cavite                                       0   2005-03-12         0
#
#                                        runtime    status  vote_average  \
# original_title
# Barney's Great Adventure                  76.0  Released           2.9
# Running Forever                           88.0  Released           0.0
# 2016: Obama's America                     87.0  Released           4.6
# Me You and Five Bucks                     90.0  Released          10.0
# Down & Out With The Dolls                 88.0  Released           0.0
# Sex With Strangers                         0.0  Released           5.0
# The Hadza:  Last of the First             70.0  Released           0.0
# Mad Hot Ballroom                         105.0  Released           7.2
# Straight Out of Brooklyn                   0.0  Released           4.3
# I Want Your Money                         92.0  Released           3.8
# Fabled                                    84.0  Released           0.0
# Sisters in Law                           104.0  Released           7.3
# Ayurveda: Art of Being                   101.0  Released           5.5
# Amidst the Devil's Wings                  90.0  Released           0.0
# Call + Response                           86.0  Released           8.0
# Chats perchés                             59.0  Released           7.7
# The Trials Of Darryl Hunt                106.0  Released           6.8
# Butterfly Girl                            77.0  Released           0.0
# Antarctic Edge: 70° South                 72.0  Released           0.0
# Top Spin                                  80.0  Released           6.8
# Peace, Propaganda & the Promised Land     80.0  Released           6.4
# Counting                                 111.0  Released           8.3
# Bending Steel                             93.0  Released           5.0
# Cavite                                    80.0  Released           7.5
#
#                                        vote_count cast  \
# original_title
# Barney's Great Adventure                        8  NaN
# Running Forever                                 0  NaN
# 2016: Obama's America                          19  NaN
# Me You and Five Bucks                           2  NaN
# Down & Out With The Dolls                       0  NaN
# Sex With Strangers                              1  NaN
# The Hadza:  Last of the First                   0  NaN
# Mad Hot Ballroom                                8  NaN
# Straight Out of Brooklyn                        4  NaN
# I Want Your Money                               5  NaN
# Fabled                                          0  NaN
# Sisters in Law                                  2  NaN
# Ayurveda: Art of Being                          3  NaN
# Amidst the Devil's Wings                        0  NaN
# Call + Response                                 1  NaN
# Chats perchés                                   3  NaN
# The Trials Of Darryl Hunt                       4  NaN
# Butterfly Girl                                  0  NaN
# Antarctic Edge: 70° South                       0  NaN
# Top Spin                                        6  NaN
# Peace, Propaganda & the Promised Land           4  NaN
# Counting                                        3  NaN
# Bending Steel                                   1  NaN
# Cavite                                          2  NaN
#
#                                                                                     crew  \
# original_title
# Barney's Great Adventure               [{'name': 'Steve Gomer', 'gender': 2, 'departm...
# Running Forever                                                                       []
# 2016: Obama's America                  [{'name': 'Gerald R. Molen', 'gender': 2, 'dep...
# Me You and Five Bucks                                                                 []
# Down & Out With The Dolls                                                             []
# Sex With Strangers                                                                    []
# The Hadza:  Last of the First          [{'name': 'Bill Benenson', 'gender': 2, 'depar...
# Mad Hot Ballroom                       [{'name': 'Marilyn Agrelo', 'gender': 1, 'depa...
# Straight Out of Brooklyn               [{'name': 'Matty Rich', 'gender': 2, 'departme...
# I Want Your Money                                                                     []
# Fabled                                                                                []
# Sisters in Law                         [{'name': 'Kim Longinotto', 'gender': 0, 'depa...
# Ayurveda: Art of Being                 [{'name': 'Pan Nalin', 'gender': 0, 'departmen...
# Amidst the Devil's Wings                                                              []
# Call + Response                        [{'name': 'Justin Dillon', 'gender': 0, 'depar...
# Chats perchés                          [{'name': 'Chris Marker', 'gender': 0, 'depart...
# The Trials Of Darryl Hunt              [{'name': 'Ricki Stern', 'gender': 1, 'departm...
# Butterfly Girl                         [{'name': 'Jessica Miller', 'gender': 0, 'depa...
# Antarctic Edge: 70° South              [{'name': 'Dena Seidel', 'gender': 0, 'departm...
# Top Spin                               [{'name': 'Sara Newens', 'gender': 0, 'departm...
# Peace, Propaganda & the Promised Land  [{'name': 'Sut Jhally', 'gender': 0, 'departme...
# Counting                               [{'name': 'Jem Cohen', 'gender': 2, 'departmen...
# Bending Steel                          [{'name': 'Dave Carroll', 'gender': 0, 'depart...
# Cavite                                 [{'name': 'Neill Dela Llana', 'gender': 0, 'de...
#
#                                                director  ...  Romance  Horror  \
# original_title                                           ...
# Barney's Great Adventure                    Steve Gomer  ...        0       0
# Running Forever                                     NaN  ...        0       0
# 2016: Obama's America                     John Sullivan  ...        0       0
# Me You and Five Bucks                               NaN  ...        1       0
# Down & Out With The Dolls                           NaN  ...        0       0
# Sex With Strangers                                  NaN  ...        0       0
# The Hadza:  Last of the First             Bill Benenson  ...        0       0
# Mad Hot Ballroom                         Marilyn Agrelo  ...        0       0
# Straight Out of Brooklyn                     Matty Rich  ...        0       0
# I Want Your Money                                   NaN  ...        0       0
# Fabled                                              NaN  ...        0       0
# Sisters in Law                           Kim Longinotto  ...        0       0
# Ayurveda: Art of Being                        Pan Nalin  ...        0       0
# Amidst the Devil's Wings                            NaN  ...        0       0
# Call + Response                           Justin Dillon  ...        0       0
# Chats perchés                              Chris Marker  ...        0       0
# The Trials Of Darryl Hunt                   Ricki Stern  ...        0       0
# Butterfly Girl                                Cary Bell  ...        0       0
# Antarctic Edge: 70° South                   Dena Seidel  ...        0       0
# Top Spin                                    Sara Newens  ...        0       0
# Peace, Propaganda & the Promised Land        Sut Jhally  ...        0       0
# Counting                                      Jem Cohen  ...        0       0
# Bending Steel                              Dave Carroll  ...        0       0
# Cavite                                 Neill Dela Llana  ...        0       0
#
#                                        Mystery  History  War  Music  \
# original_title
# Barney's Great Adventure                     0        0    0      0
# Running Forever                              0        0    0      0
# 2016: Obama's America                        0        0    0      0
# Me You and Five Bucks                        0        0    0      0
# Down & Out With The Dolls                    0        0    0      1
# Sex With Strangers                           0        0    0      0
# The Hadza:  Last of the First                0        0    0      0
# Mad Hot Ballroom                             0        0    0      0
# Straight Out of Brooklyn                     0        0    0      0
# I Want Your Money                            0        0    0      0
# Fabled                                       1        0    0      0
# Sisters in Law                               0        0    0      0
# Ayurveda: Art of Being                       0        0    0      0
# Amidst the Devil's Wings                     0        0    0      0
# Call + Response                              0        0    0      0
# Chats perchés                                0        0    0      0
# The Trials Of Darryl Hunt                    0        0    0      0
# Butterfly Girl                               0        0    0      0
# Antarctic Edge: 70° South                    0        0    0      0
# Top Spin                                     0        0    0      0
# Peace, Propaganda & the Promised Land        0        0    0      0
# Counting                                     0        0    0      0
# Bending Steel                                0        0    0      0
# Cavite                                       0        0    0      0
#
#                                        Documentary  Foreign  TV  \
# original_title
# Barney's Great Adventure                         0        0   0
# Running Forever                                  0        0   0
# 2016: Obama's America                            1        0   0
# Me You and Five Bucks                            0        0   0
# Down & Out With The Dolls                        0        0   0
# Sex With Strangers                               1        0   0
# The Hadza:  Last of the First                    1        0   0
# Mad Hot Ballroom                                 1        0   0
# Straight Out of Brooklyn                         0        0   0
# I Want Your Money                                1        0   0
# Fabled                                           0        0   0
# Sisters in Law                                   1        0   0
# Ayurveda: Art of Being                           1        0   0
# Amidst the Devil's Wings                         0        0   0
# Call + Response                                  1        0   0
# Chats perchés                                    1        0   0
# The Trials Of Darryl Hunt                        1        0   0
# Butterfly Girl                                   1        0   0
# Antarctic Edge: 70° South                        1        0   0
# Top Spin                                         1        0   0
# Peace, Propaganda & the Promised Land            1        0   0
# Counting                                         1        0   0
# Bending Steel                                    1        0   0
# Cavite                                           0        1   0
#
#                                                                                 overview
# original_title
# Barney's Great Adventure               [mom, and, dad, dump, son, cody, daughter, abb...
# Running Forever                        [after, being, estranged, since, her, mother, ...
# 2016: Obama's America                  [2016, obama, s, america, take, audience, on, ...
# Me You and Five Bucks                  [a, womanizing, yet, lovable, loser, charlie, ...
# Down & Out With The Dolls              [the, raunchy, spunky, tale, of, the, rise, an...
# Sex With Strangers                     [for, some, married, couple, sex, is, an, obse...
# The Hadza:  Last of the First          [a, look, at, human, origin, in, the, very, pl...
# Mad Hot Ballroom                       [eleven, year, old, new, york, city, public, s...
# Straight Out of Brooklyn               [a, special, jury, award, winner, at, the, sun...
# I Want Your Money                      [two, version, of, the, american, dream, now, ...
# Fabled                                 [joseph, just, broke, up, with, his, girlfrien...
# Sisters in Law                         [set, in, kumba, in, south, west, cameroon, si...
# Ayurveda: Art of Being                 [ayurveda, is, a, science, of, life, and, a, h...
# Amidst the Devil's Wings                               [prequel, to, 5th, of, a, degree]
# Call + Response                        [call, response, is, a, first, of, it, kind, f...
# Chats perchés                          [paris, 2002, yellow, cat, appear, on, the, wa...
# The Trials Of Darryl Hunt              [the, trial, of, darryl, hunt, is, a, feature,...
# Butterfly Girl                         [abbie, came, of, age, in, honky, tonks, defyi...
# Antarctic Edge: 70° South              [in, 2014, scientist, declared, west, antarcti...
# Top Spin                               [three, teenager, quest, to, qualify, for, the...
# Peace, Propaganda & the Promised Land  [this, video, show, how, the, foreign, policy,...
# Counting                               [an, associative, collection, of, visual, impr...
# Bending Steel                          [the, cyclone, the, freakshow, the, mermaid, p...
# Cavite                                 [adam, a, security, guard, travel, from, calif...
#
# [24 rows x 31 columns]

# %% [markdown]
# QUESTION: Will anyone care if we drop these castless movies from our dataset?

# %%
# Tally total number of votew for all 24 castless movies
movies[movies['cast'].isna()]['vote_count'].sum()
# Out:
# 76

# %% [markdown]
# ANSWER: probably not.

# %%
movies = movies[movies['cast'].isna() == False]

# %% [markdown]
# #### Cleaning the Cast Column
#
# The cast column is a single string containing the names of the biggest names in each movie. Some of the names have errors in them, containing characters that aren't letters. In the cell below, we'll run a command to change each string into a list of names and to fix any spelling errors.

# %%
# Create an empty list
cleaned_names = []

# Loop through all values in the 'cast' column
for i in movies['cast']:
    
    # Create an empty list for each movie in the loop
    cast = []
    
    # Turn the string into a list of names, splitting on the spaces
    cell = i.split(' ')
    
    # Loop through each name in the variable 'cell'
    for name in cell:
        
        # Create an empty string object
        cleaned_name = ''
        
        # Add each character to 'cleaned_name' if it is, in fact, a letter
        for letter in name:
            if letter.isalpha() == True: cleaned_name += letter 
         
        # Add the cleaned name to 'cast'
        cast.append(cleaned_name)
        
    # Add the new cleaned cell to the 'cleaned_names' list
    cleaned_names.append(cast)
            
# Check work          
cleaned_names
# Out:
# [['Sam',
#   'Worthington',
#   'Zoe',
#   'Saldana',
#   'Sigourney',
#   'Weaver',
#   'Stephen',
#   'Lang',
#   'Michelle',
#   'Rodriguez'],
#  ['Johnny',
#   'Depp',
#   'Orlando',
#   'Bloom',
#   'Keira',
#   'Knightley',
#   'Stellan',
#   'Skarsguerd',
#   'Chow',
#   'Yunfat'],
#  ['Daniel',
#   'Craig',
#   'Christoph',
#   'Waltz',
#   'Luea',
#   'Seydoux',
#   'Ralph',
#   'Fiennes',
#   'Monica',
#   'Bellucci'],
#  ['Christian',
#   'Bale',
#   'Michael',
#   'Caine',
#   'Gary',
#   'Oldman',
#   'Anne',
#   'Hathaway',
#   'Tom',
#   'Hardy'],
#  ['Taylor',
#   'Kitsch',
#   'Lynn',
#   'Collins',
#   'Samantha',
#   'Morton',
#   'Willem',
#   'Dafoe',
#   'Thomas',
#   'Haden',
#   'Church'],
#  ['Tobey',
#   'Maguire',
#   'Kirsten',
#   'Dunst',
#   'James',
#   'Franco',
#   'Thomas',
#   'Haden',
#   'Church',
#   'Topher',
#   'Grace'],
#  ['Zachary',
#   'Levi',
#   'Mandy',
#   'Moore',
#   'Donna',
#   'Murphy',
#   'Ron',
#   'Perlman',
#   'MC',
#   'Gainey'],
#  ['Robert',
#   'Downey',
#   'Jr',
#   'Chris',
#   'Hemsworth',
#   'Mark',
#   'Ruffalo',
#   'Chris',
#   'Evans',
#   'Scarlett',
#   'Johansson'],
#  ['Daniel',
#   'Radcliffe',
#   'Rupert',
#   'Grint',
#   'Emma',
#   'Watson',
#   'Tom',
#   'Felton',
#   'Michael',
#   'Gambon'],
#  ['Ben',
#   'Affleck',
#   'Henry',
#   'Cavill',
#   'Gal',
#   'Gadot',
#   'Amy',
#   'Adams',
#   'Jesse',
#   'Eisenberg'],
#  ['Brandon',
#   'Routh',
#   'Kevin',
#   'Spacey',
#   'Kate',
#   'Bosworth',
#   'James',
#   'Marsden',
#   'Parker',
#   'Posey'],
#  ['Daniel',
#   'Craig',
#   'Olga',
#   'Kurylenko',
#   'Mathieu',
#   'Amalric',
#   'Judi',
#   'Dench',
#   'Giancarlo',
#   'Giannini'],
#  ['Johnny',
#   'Depp',
#   'Orlando',
#   'Bloom',
#   'Keira',
#   'Knightley',
#   'Stellan',
#   'Skarsguerd',
#   'Bill',
#   'Nighy'],
#  ['Johnny',
#   'Depp',
#   'Armie',
#   'Hammer',
#   'William',
#   'Fichtner',
#   'Helena',
#   'Bonham',
#   'Carter',
#   'James',
#   'Badge',
#   'Dale'],
#  ['Henry',
#   'Cavill',
#   'Amy',
#   'Adams',
#   'Michael',
#   'Shannon',
#   'Kevin',
#   'Costner',
#   'Diane',
#   'Lane'],
#  ['Ben',
#   'Barnes',
#   'William',
#   'Moseley',
#   'Anna',
#   'Popplewell',
#   'Skandar',
#   'Keynes',
#   'Georgie',
#   'Henley'],
#  ['Robert',
#   'Downey',
#   'Jr',
#   'Chris',
#   'Evans',
#   'Mark',
#   'Ruffalo',
#   'Chris',
#   'Hemsworth',
#   'Scarlett',
#   'Johansson'],
#  ['Johnny',
#   'Depp',
#   'Penuelope',
#   'Cruz',
#   'Ian',
#   'McShane',
#   'Kevin',
#   'McNally',
#   'Geoffrey',
#   'Rush'],
#  ['Will',
#   'Smith',
#   'Tommy',
#   'Lee',
#   'Jones',
#   'Josh',
#   'Brolin',
#   'Michael',
#   'Stuhlbarg',
#   'Emma',
#   'Thompson'],
#  ['Martin',
#   'Freeman',
#   'Ian',
#   'McKellen',
#   'Richard',
#   'Armitage',
#   'Ken',
#   'Stott',
#   'Graham',
#   'McTavish'],
#  ['Andrew',
#   'Garfield',
#   'Emma',
#   'Stone',
#   'Rhys',
#   'Ifans',
#   'Denis',
#   'Leary',
#   'Campbell',
#   'Scott'],
#  ['Russell',
#   'Crowe',
#   'Cate',
#   'Blanchett',
#   'Max',
#   'von',
#   'Sydow',
#   'William',
#   'Hurt',
#   'Mark',
#   'Strong'],
#  ['Martin',
#   'Freeman',
#   'Ian',
#   'McKellen',
#   'Richard',
#   'Armitage',
#   'Ken',
#   'Stott',
#   'Graham',
#   'McTavish'],
#  ['Dakota',
#   'Blue',
#   'Richards',
#   'Nicole',
#   'Kidman',
#   'Daniel',
#   'Craig',
#   'Sam',
#   'Elliott',
#   'Eva',
#   'Green'],
#  ['Naomi',
#   'Watts',
#   'Jack',
#   'Black',
#   'Adrien',
#   'Brody',
#   'Thomas',
#   'Kretschmann',
#   'Colin',
#   'Hanks'],
#  ['Kate',
#   'Winslet',
#   'Leonardo',
#   'DiCaprio',
#   'Frances',
#   'Fisher',
#   'Billy',
#   'Zane',
#   'Kathy',
#   'Bates'],
#  ['Chris',
#   'Evans',
#   'Robert',
#   'Downey',
#   'Jr',
#   'Scarlett',
#   'Johansson',
#   'Sebastian',
#   'Stan',
#   'Anthony',
#   'Mackie'],
#  ['Taylor',
#   'Kitsch',
#   'Alexander',
#   'Skarsguerd',
#   'Rihanna',
#   'Brooklyn',
#   'Decker',
#   'Tadanobu',
#   'Asano'],
#  ['Chris',
#   'Pratt',
#   'Bryce',
#   'Dallas',
#   'Howard',
#   'Irrfan',
#   'Khan',
#   'Vincent',
#   'DOnofrio',
#   'Nick',
#   'Robinson'],
#  ['Daniel',
#   'Craig',
#   'Judi',
#   'Dench',
#   'Javier',
#   'Bardem',
#   'Ralph',
#   'Fiennes',
#   'Naomie',
#   'Harris'],
#  ['Tobey',
#   'Maguire',
#   'Kirsten',
#   'Dunst',
#   'James',
#   'Franco',
#   'Alfred',
#   'Molina',
#   'Rosemary',
#   'Harris'],
#  ['Robert',
#   'Downey',
#   'Jr',
#   'Gwyneth',
#   'Paltrow',
#   'Don',
#   'Cheadle',
#   'Guy',
#   'Pearce',
#   'Rebecca',
#   'Hall'],
#  ['Mia',
#   'Wasikowska',
#   'Johnny',
#   'Depp',
#   'Anne',
#   'Hathaway',
#   'Helena',
#   'Bonham',
#   'Carter',
#   'Crispin',
#   'Glover'],
#  ['Hugh',
#   'Jackman',
#   'Halle',
#   'Berry',
#   'Ian',
#   'McKellen',
#   'Patrick',
#   'Stewart',
#   'Famke',
#   'Janssen'],
#  ['Billy',
#   'Crystal',
#   'John',
#   'Goodman',
#   'Steve',
#   'Buscemi',
#   'Helen',
#   'Mirren',
#   'Noah',
#   'Johnston'],
#  ['Shia',
#   'LaBeouf',
#   'Megan',
#   'Fox',
#   'Josh',
#   'Duhamel',
#   'Rainn',
#   'Wilson',
#   'Tyrese',
#   'Gibson'],
#  ['Mark',
#   'Wahlberg',
#   'Stanley',
#   'Tucci',
#   'Kelsey',
#   'Grammer',
#   'Nicola',
#   'Peltz',
#   'Jack',
#   'Reynor'],
#  ['James',
#   'Franco',
#   'Mila',
#   'Kunis',
#   'Rachel',
#   'Weisz',
#   'Michelle',
#   'Williams',
#   'Zach',
#   'Braff'],
#  ['Andrew',
#   'Garfield',
#   'Emma',
#   'Stone',
#   'Jamie',
#   'Foxx',
#   'Dane',
#   'DeHaan',
#   'Campbell',
#   'Scott'],
#  ['Garrett',
#   'Hedlund',
#   'Jeff',
#   'Bridges',
#   'Olivia',
#   'Wilde',
#   'Bruce',
#   'Boxleitner',
#   'Yaya',
#   'DaCosta'],
#  ['Owen',
#   'Wilson',
#   'Larry',
#   'the',
#   'Cable',
#   'Guy',
#   'Michael',
#   'Caine',
#   'Emily',
#   'Mortimer',
#   'John',
#   'Turturro'],
#  ['Ryan',
#   'Reynolds',
#   'Blake',
#   'Lively',
#   'Peter',
#   'Sarsgaard',
#   'Tim',
#   'Robbins',
#   'Mark',
#   'Strong'],
#  ['Tom',
#   'Hanks',
#   'Tim',
#   'Allen',
#   'Ned',
#   'Beatty',
#   'Joan',
#   'Cusack',
#   'Michael',
#   'Keaton'],
#  ['Christian',
#   'Bale',
#   'Sam',
#   'Worthington',
#   'Anton',
#   'Yelchin',
#   'Moon',
#   'Bloodgood',
#   'Bryce',
#   'Dallas',
#   'Howard'],
#  ['Vin',
#   'Diesel',
#   'Paul',
#   'Walker',
#   'Dwayne',
#   'Johnson',
#   'Michelle',
#   'Rodriguez',
#   'Tyrese',
#   'Gibson'],
#  ['Brad',
#   'Pitt',
#   'Mireille',
#   'Enos',
#   'Abigail',
#   'Hargrove',
#   'Sterling',
#   'Jerins',
#   'James',
#   'Badge',
#   'Dale'],
#  ['Hugh',
#   'Jackman',
#   'James',
#   'McAvoy',
#   'Michael',
#   'Fassbender',
#   'Jennifer',
#   'Lawrence',
#   'Halle',
#   'Berry'],
#  ['Chris',
#   'Pine',
#   'Zachary',
#   'Quinto',
#   'Zoe',
#   'Saldana',
#   'Karl',
#   'Urban',
#   'Simon',
#   'Pegg'],
#  ['Nicholas',
#   'Hoult',
#   'Eleanor',
#   'Tomlinson',
#   'Ewan',
#   'McGregor',
#   'Stanley',
#   'Tucci',
#   'Ian',
#   'McShane'],
#  ['Leonardo',
#   'DiCaprio',
#   'Tobey',
#   'Maguire',
#   'Carey',
#   'Mulligan',
#   'Joel',
#   'Edgerton',
#   'Elizabeth',
#   'Debicki'],
#  ['Jake',
#   'Gyllenhaal',
#   'Gemma',
#   'Arterton',
#   'Ben',
#   'Kingsley',
#   'Alfred',
#   'Molina',
#   'Steve',
#   'Toussaint'],
#  ['Idris',
#   'Elba',
#   'Charlie',
#   'Hunnam',
#   'Charlie',
#   'Day',
#   'Ron',
#   'Perlman',
#   'Burn',
#   'Gorman'],
#  ['Shia',
#   'LaBeouf',
#   'John',
#   'Malkovich',
#   'Ken',
#   'Jeong',
#   'Frances',
#   'McDormand',
#   'Josh',
#   'Duhamel'],
#  ['Harrison',
#   'Ford',
#   'Cate',
#   'Blanchett',
#   'Shia',
#   'LaBeouf',
#   'Ray',
#   'Winstone',
#   'Karen',
#   'Allen'],
#  ['Raymond',
#   'Ochoa',
#   'Jack',
#   'Bright',
#   'Jeffrey',
#   'Wright',
#   'Frances',
#   'McDormand',
#   'Maleah',
#   'NipayPadilla'],
#  ['Kelly',
#   'Macdonald',
#   'Julie',
#   'Walters',
#   'Billy',
#   'Connolly',
#   'Emma',
#   'Thompson',
#   'Kevin',
#   'McKidd'],
#  ['Chris',
#   'Pine',
#   'Zachary',
#   'Quinto',
#   'Karl',
#   'Urban',
#   'Simon',
#   'Pegg',
#   'Zoe',
#   'Saldana'],
#  ['Ben',
#   'Burtt',
#   'Elissa',
#   'Knight',
#   'Jeff',
#   'Garlin',
#   'Fred',
#   'Willard',
#   'John',
#   'Ratzenberger'],
#  ['Chris',
#   'Tucker',
#   'Jackie',
#   'Chan',
#   'Hiroyuki',
#   'Sanada',
#   'Max',
#   'von',
#   'Sydow',
#   'Yvan',
#   'Attal'],
#  ['John',
#   'Cusack',
#   'Amanda',
#   'Peet',
#   'Chiwetel',
#   'Ejiofor',
#   'Thandie',
#   'Newton',
#   'Oliver',
#   'Platt'],
#  ['Gary',
#   'Oldman',
#   'Jim',
#   'Carrey',
#   'Steve',
#   'Valentine',
#   'Daryl',
#   'Sabara',
#   'Sage',
#   'Ryan'],
#  ['Mila',
#   'Kunis',
#   'Channing',
#   'Tatum',
#   'Sean',
#   'Bean',
#   'Eddie',
#   'Redmayne',
#   'Douglas',
#   'Booth'],
#  ['Alexander',
#   'Skarsguerd',
#   'Margot',
#   'Robbie',
#   'Christoph',
#   'Waltz',
#   'Samuel',
#   'L',
#   'Jackson',
#   'Djimon',
#   'Hounsou'],
#  ['William',
#   'Moseley',
#   'Anna',
#   'Popplewell',
#   'Skandar',
#   'Keynes',
#   'Georgie',
#   'Henley',
#   'Liam',
#   'Neeson'],
#  ['James',
#   'McAvoy',
#   'Michael',
#   'Fassbender',
#   'Jennifer',
#   'Lawrence',
#   'Nicholas',
#   'Hoult',
#   'Oscar',
#   'Isaac'],
#  ['Christian',
#   'Bale',
#   'Heath',
#   'Ledger',
#   'Aaron',
#   'Eckhart',
#   'Michael',
#   'Caine',
#   'Maggie',
#   'Gyllenhaal'],
#  ['Ed',
#   'Asner',
#   'Christopher',
#   'Plummer',
#   'Jordan',
#   'Nagai',
#   'Bob',
#   'Peterson',
#   'Delroy',
#   'Lindo'],
#  ['Seth',
#   'Rogen',
#   'Reese',
#   'Witherspoon',
#   'Hugh',
#   'Laurie',
#   'Paul',
#   'Rudd',
#   'Kiefer',
#   'Sutherland'],
#  ['Robert',
#   'Downey',
#   'Jr',
#   'Terrence',
#   'Howard',
#   'Jeff',
#   'Bridges',
#   'Shaun',
#   'Toub',
#   'Gwyneth',
#   'Paltrow'],
#  ['Ben',
#   'Kingsley',
#   'Sacha',
#   'Baron',
#   'Cohen',
#   'Asa',
#   'Butterfield',
#   'Chloueb',
#   'Grace',
#   'Moretz',
#   'Ray',
#   'Winstone'],
#  ['Will',
#   'Smith',
#   'Kevin',
#   'Kline',
#   'Kenneth',
#   'Branagh',
#   'Salma',
#   'Hayek',
#   'M',
#   'Emmet',
#   'Walsh'],
#  ['Brendan',
#   'Fraser',
#   'Jet',
#   'Li',
#   'John',
#   'Hannah',
#   'Maria',
#   'Bello',
#   'Luke',
#   'Ford'],
#  ['Will',
#   'Smith',
#   'Margot',
#   'Robbie',
#   'Joel',
#   'Kinnaman',
#   'Viola',
#   'Davis',
#   'Jared',
#   'Leto'],
#  ['Steve',
#   'Carell',
#   'Lauren',
#   'Graham',
#   'John',
#   'Goodman',
#   'Jimmy',
#   'Bennett',
#   'John',
#   'Michael',
#   'Higgins'],
#  ['Tom',
#   'Cruise',
#   'Emily',
#   'Blunt',
#   'Brendan',
#   'Gleeson',
#   'Bill',
#   'Paxton',
#   'Jonas',
#   'Armstrong'],
#  ['Kevin',
#   'Costner',
#   'Chaim',
#   'Girafi',
#   'Rick',
#   'Aviles',
#   'R',
#   'D',
#   'Call',
#   'Zitto',
#   'Kazann'],
#  ['Dennis',
#   'Quaid',
#   'Channing',
#   'Tatum',
#   'Marlon',
#   'Wayans',
#   'Sienna',
#   'Miller',
#   'Joseph',
#   'GordonLevitt'],
#  ['Amy',
#   'Poehler',
#   'Phyllis',
#   'Smith',
#   'Richard',
#   'Kind',
#   'Bill',
#   'Hader',
#   'Lewis',
#   'Black'],
#  ['Neel',
#   'Sethi',
#   'Bill',
#   'Murray',
#   'Ben',
#   'Kingsley',
#   'Idris',
#   'Elba',
#   'Scarlett',
#   'Johansson'],
#  ['Robert',
#   'Downey',
#   'Jr',
#   'Gwyneth',
#   'Paltrow',
#   'Don',
#   'Cheadle',
#   'Scarlett',
#   'Johansson',
#   'Mickey',
#   'Rourke'],
#  ['Kristen',
#   'Stewart',
#   'Charlize',
#   'Theron',
#   'Chris',
#   'Hemsworth',
#   'Sam',
#   'Claflin',
#   'Ian',
#   'McShane'],
#  ['Angelina',
#   'Jolie',
#   'Elle',
#   'Fanning',
#   'Sharlto',
#   'Copley',
#   'Sam',
#   'Riley',
#   'Juno',
#   'Temple'],
#  ['Andy',
#   'Serkis',
#   'Jason',
#   'Clarke',
#   'Gary',
#   'Oldman',
#   'Keri',
#   'Russell',
#   'Toby',
#   'Kebbell'],
#  ['Josh',
#   'Hartnett',
#   'Simone',
#   'Kessell',
#   'Tamsin',
#   'Egerton',
#   'Alice',
#   'Englert',
#   'Bipasha',
#   'Basu'],
#  ['Keanu',
#   'Reeves',
#   'Hiroyuki',
#   'Sanada',
#   'Kou',
#   'Shibasaki',
#   'Tadanobu',
#   'Asano',
#   'Min',
#   'Tanaka'],
#  ['Chris',
#   'Evans',
#   'Samuel',
#   'L',
#   'Jackson',
#   'Scarlett',
#   'Johansson',
#   'Robert',
#   'Redford',
#   'Sebastian',
#   'Stan'],
#  ['Mike',
#   'Myers',
#   'Eddie',
#   'Murphy',
#   'Cameron',
#   'Diaz',
#   'Antonio',
#   'Banderas',
#   'Julie',
#   'Andrews'],
#  ['Britt',
#   'Robertson',
#   'George',
#   'Clooney',
#   'Raffey',
#   'Cassidy',
#   'Thomas',
#   'Robinson',
#   'Hugh',
#   'Laurie'],
#  ['Scott',
#   'Adsit',
#   'Ryan',
#   'Potter',
#   'Daniel',
#   'Henney',
#   'TJ',
#   'Miller',
#   'Jamie',
#   'Chung'],
#  ['John',
#   'C',
#   'Reilly',
#   'Sarah',
#   'Silverman',
#   'Jack',
#   'McBrayer',
#   'Jane',
#   'Lynch',
#   'Alan',
#   'Tudyk'],
#  ['Tom',
#   'Hanks',
#   'Michael',
#   'Jeter',
#   'Nona',
#   'Gaye',
#   'Peter',
#   'Scolari',
#   'Eddie',
#   'Deezen'],
#  ['Liam',
#   'Hemsworth',
#   'Jeff',
#   'Goldblum',
#   'Bill',
#   'Pullman',
#   'Maika',
#   'Monroe',
#   'Sela',
#   'Ward'],
#  ['Jay',
#   'Baruchel',
#   'Gerard',
#   'Butler',
#   'Craig',
#   'Ferguson',
#   'America',
#   'Ferrera',
#   'Jonah',
#   'Hill'],
#  ['Arnold',
#   'Schwarzenegger',
#   'Nick',
#   'Stahl',
#   'Claire',
#   'Danes',
#   'Kristanna',
#   'Loken',
#   'David',
#   'Andrews'],
#  ['Chris',
#   'Pratt',
#   'Zoe',
#   'Saldana',
#   'Dave',
#   'Bautista',
#   'Vin',
#   'Diesel',
#   'Bradley',
#   'Cooper'],
#  ['Matthew',
#   'McConaughey',
#   'Jessica',
#   'Chastain',
#   'Anne',
#   'Hathaway',
#   'Michael',
#   'Caine',
#   'Casey',
#   'Affleck'],
#  ['Leonardo',
#   'DiCaprio',
#   'Joseph',
#   'GordonLevitt',
#   'Ellen',
#   'Page',
#   'Tom',
#   'Hardy',
#   'Ken',
#   'Watanabe'],
#  ['Ian',
#   'McKellen',
#   'Martin',
#   'Freeman',
#   'Richard',
#   'Armitage',
#   'Andy',
#   'Serkis',
#   'Cate',
#   'Blanchett'],
#  ['Paul',
#   'Walker',
#   'Vin',
#   'Diesel',
#   'Michelle',
#   'Rodriguez',
#   'Jordana',
#   'Brewster',
#   'Rick',
#   'Yune'],
#  ['Cate',
#   'Blanchett',
#   'Brad',
#   'Pitt',
#   'Tilda',
#   'Swinton',
#   'Julia',
#   'Ormond',
#   'Elle',
#   'Fanning'],
#  ['James',
#   'McAvoy',
#   'Michael',
#   'Fassbender',
#   'Jennifer',
#   'Lawrence',
#   'Kevin',
#   'Bacon',
#   'Rose',
#   'Byrne'],
#  ['Jennifer',
#   'Lawrence',
#   'Josh',
#   'Hutcherson',
#   'Liam',
#   'Hemsworth',
#   'Woody',
#   'Harrelson',
#   'Elizabeth',
#   'Banks'],
#  ['Nicolas',
#   'Cage',
#   'Jay',
#   'Baruchel',
#   'Monica',
#   'Bellucci',
#   'Alfred',
#   'Molina',
#   'Teresa',
#   'Palmer'],
#  ['Kurt',
#   'Russell',
#   'Richard',
#   'Dreyfuss',
#   'Josh',
#   'Lucas',
#   'Jacinda',
#   'Barrett',
#   'Emmy',
#   'Rossum'],
#  ['Johnny',
#   'Depp',
#   'Mia',
#   'Wasikowska',
#   'Anne',
#   'Hathaway',
#   'Helena',
#   'Bonham',
#   'Carter',
#   'Alan',
#   'Rickman'],
#  ['Mike',
#   'Myers',
#   'Eddie',
#   'Murphy',
#   'Cameron',
#   'Diaz',
#   'Julie',
#   'Andrews',
#   'Antonio',
#   'Banderas'],
#  ['Paula',
#   'Patton',
#   'Travis',
#   'Fimmel',
#   'Ben',
#   'Foster',
#   'Robert',
#   'Kazinsky',
#   'Dominic',
#   'Cooper'],
#  ['Arnold',
#   'Schwarzenegger',
#   'Jason',
#   'Clarke',
#   'Emilia',
#   'Clarke',
#   'Jai',
#   'Courtney',
#   'JK',
#   'Simmons'],
#  ['Skandar',
#   'Keynes',
#   'Georgie',
#   'Henley',
#   'Simon',
#   'Pegg',
#   'Gary',
#   'Sweet',
#   'Arthur',
#   'Angel'],
#  ['Ben',
#   'Affleck',
#   'Josh',
#   'Hartnett',
#   'Kate',
#   'Beckinsale',
#   'Cuba',
#   'Gooding',
#   'Jr',
#   'Jon',
#   'Voight'],
#  ['Shia',
#   'LaBeouf',
#   'Josh',
#   'Duhamel',
#   'Megan',
#   'Fox',
#   'Rachael',
#   'Taylor',
#   'Tyrese',
#   'Gibson'],
#  ['Colin',
#   'Farrell',
#   'Angelina',
#   'Jolie',
#   'Val',
#   'Kilmer',
#   'Jared',
#   'Leto',
#   'Jonathan',
#   'Rhys',
#   'Meyers'],
#  ['Daniel',
#   'Radcliffe',
#   'Rupert',
#   'Grint',
#   'Emma',
#   'Watson',
#   'Michael',
#   'Gambon',
#   'Ralph',
#   'Fiennes'],
#  ['Daniel',
#   'Radcliffe',
#   'Rupert',
#   'Grint',
#   'Emma',
#   'Watson',
#   'Ralph',
#   'Fiennes',
#   'Michael',
#   'Gambon'],
#  ['Will',
#   'Smith',
#   'Charlize',
#   'Theron',
#   'Jason',
#   'Bateman',
#   'Jae',
#   'Head',
#   'Eddie',
#   'Marsan'],
#  ['Will',
#   'Smith',
#   'Alice',
#   'Braga',
#   'Charlie',
#   'Tahan',
#   'Salli',
#   'RichardsonWhitfield',
#   'Willow',
#   'Smith'],
#  ['Johnny',
#   'Depp',
#   'Freddie',
#   'Highmore',
#   'David',
#   'Kelly',
#   'AnnaSophia',
#   'Robb',
#   'Julia',
#   'Winter'],
#  ['Patton',
#   'Oswalt',
#   'Ian',
#   'Holm',
#   'Lou',
#   'Romano',
#   'Brian',
#   'Dennehy',
#   'Peter',
#   'Sohn'],
#  ['Christian',
#   'Bale',
#   'Michael',
#   'Caine',
#   'Liam',
#   'Neeson',
#   'Katie',
#   'Holmes',
#   'Gary',
#   'Oldman'],
#  ['Ben',
#   'Stiller',
#   'Jada',
#   'Pinkett',
#   'Smith',
#   'David',
#   'Schwimmer',
#   'Chris',
#   'Rock',
#   'Cedric',
#   'the',
#   'Entertainer'],
#  ['Ben',
#   'Stiller',
#   'Amy',
#   'Adams',
#   'Owen',
#   'Wilson',
#   'Hank',
#   'Azaria',
#   'Robin',
#   'Williams'],
#  ['Hugh',
#   'Jackman',
#   'Liev',
#   'Schreiber',
#   'Danny',
#   'Huston',
#   'Lynn',
#   'Collins',
#   'Ryan',
#   'Reynolds'],
#  ['Keanu',
#   'Reeves',
#   'Laurence',
#   'Fishburne',
#   'CarrieAnne',
#   'Moss',
#   'Hugo',
#   'Weaving',
#   'Mary',
#   'Alice'],
#  ['Kristen',
#   'Bell',
#   'Idina',
#   'Menzel',
#   'Jonathan',
#   'Groff',
#   'Josh',
#   'Gad',
#   'Santino',
#   'Fontana'],
#  ['Keanu',
#   'Reeves',
#   'CarrieAnne',
#   'Moss',
#   'Laurence',
#   'Fishburne',
#   'Hugo',
#   'Weaving',
#   'Helmut',
#   'Bakaitis'],
#  ['Chris',
#   'Hemsworth',
#   'Natalie',
#   'Portman',
#   'Tom',
#   'Hiddleston',
#   'Anthony',
#   'Hopkins',
#   'Christopher',
#   'Eccleston'],
#  ['Tom',
#   'Hardy',
#   'Charlize',
#   'Theron',
#   'Nicholas',
#   'Hoult',
#   'Hugh',
#   'KeaysByrne',
#   'Josh',
#   'Helman'],
#  ['Tom',
#   'Hanks',
#   'Ewan',
#   'McGregor',
#   'Ayelet',
#   'Zurer',
#   'Stellan',
#   'Skarsguerd',
#   'Pierfrancesco',
#   'Favino'],
#  ['Chris',
#   'Hemsworth',
#   'Natalie',
#   'Portman',
#   'Tom',
#   'Hiddleston',
#   'Anthony',
#   'Hopkins',
#   'Stellan',
#   'Skarsguerd'],
#  ['John',
#   'Travolta',
#   'Miley',
#   'Cyrus',
#   'Susie',
#   'Essman',
#   'Mark',
#   'Walton',
#   'Malcolm',
#   'McDowell'],
#  ['Sam',
#   'Rockwell',
#   'Penuelope',
#   'Cruz',
#   'Tracy',
#   'Morgan',
#   'Jon',
#   'Favreau',
#   'Steve',
#   'Buscemi'],
#  ['Sam',
#   'Worthington',
#   'Liam',
#   'Neeson',
#   'Ralph',
#   'Fiennes',
#   'Edgar',
#   'Ramuedrez',
#   'Toby',
#   'Kebbell'],
#  ['Johnny',
#   'Depp',
#   'Michelle',
#   'Pfeiffer',
#   'Helena',
#   'Bonham',
#   'Carter',
#   'Jackie',
#   'Earle',
#   'Haley',
#   'Jonny',
#   'Lee',
#   'Miller'],
#  ['Tom',
#   'Cruise',
#   'Rebecca',
#   'Ferguson',
#   'Simon',
#   'Pegg',
#   'Jeremy',
#   'Renner',
#   'Ving',
#   'Rhames'],
#  ['Benicio',
#   'del',
#   'Toro',
#   'Anthony',
#   'Hopkins',
#   'Emily',
#   'Blunt',
#   'Hugo',
#   'Weaving',
#   'Cristina',
#   'Contes'],
#  ['Jerry',
#   'Seinfeld',
#   'Renuee',
#   'Zellweger',
#   'Jim',
#   'Cummings',
#   'Matthew',
#   'Broderick',
#   'Patrick',
#   'Warburton'],
#  ['Jack',
#   'Black',
#   'Angelina',
#   'Jolie',
#   'Dustin',
#   'Hoffman',
#   'Gary',
#   'Oldman',
#   'Jackie',
#   'Chan'],
#  ['Noah',
#   'Ringer',
#   'Nicola',
#   'Peltz',
#   'Jackson',
#   'Rathbone',
#   'Dev',
#   'Patel',
#   'Shaun',
#   'Toub'],
#  ['Tom',
#   'Cruise',
#   'Philip',
#   'Seymour',
#   'Hoffman',
#   'Ving',
#   'Rhames',
#   'Billy',
#   'Crudup',
#   'Jonathan',
#   'Rhys',
#   'Meyers'],
#  ['Channing',
#   'Tatum',
#   'Jamie',
#   'Foxx',
#   'Joey',
#   'King',
#   'Maggie',
#   'Gyllenhaal',
#   'Richard',
#   'Jenkins'],
#  ['Seth',
#   'Green',
#   'Joan',
#   'Cusack',
#   'Dan',
#   'Fogler',
#   'Breckin',
#   'Meyer',
#   'Elisabeth',
#   'Harnois'],
#  ['Hugh',
#   'Jackman',
#   'Kate',
#   'Winslet',
#   'Ian',
#   'McKellen',
#   'Jean',
#   'Reno',
#   'Bill',
#   'Nighy'],
#  ['Levi',
#   'Miller',
#   'Garrett',
#   'Hedlund',
#   'Hugh',
#   'Jackman',
#   'Rooney',
#   'Mara',
#   'Amanda',
#   'Seyfried'],
#  ['Ty',
#   'Burrell',
#   'Max',
#   'Charles',
#   'Ariel',
#   'Winter',
#   'Allison',
#   'Janney',
#   'Ellie',
#   'Kemper'],
#  ['Brad',
#   'Pitt',
#   'Orlando',
#   'Bloom',
#   'Eric',
#   'Bana',
#   'Brian',
#   'Cox',
#   'Sean',
#   'Bean'],
#  ['Ben',
#   'Stiller',
#   'Sacha',
#   'Baron',
#   'Cohen',
#   'David',
#   'Schwimmer',
#   'Frances',
#   'McDormand',
#   'Chris',
#   'Rock'],
#  ['Pierce',
#   'Brosnan',
#   'Halle',
#   'Berry',
#   'Rosamund',
#   'Pike',
#   'Rick',
#   'Yune',
#   'Toby',
#   'Stephens'],
#  ['Melissa',
#   'McCarthy',
#   'Kristen',
#   'Wiig',
#   'Kate',
#   'McKinnon',
#   'Leslie',
#   'Jones',
#   'Chris',
#   'Hemsworth'],
#  ['Bruce',
#   'Willis',
#   'Billy',
#   'Bob',
#   'Thornton',
#   'Ben',
#   'Affleck',
#   'Liv',
#   'Tyler',
#   'Will',
#   'Patton'],
#  ['Tommy',
#   'Lee',
#   'Jones',
#   'Will',
#   'Smith',
#   'Rip',
#   'Torn',
#   'Lara',
#   'Flynn',
#   'Boyle',
#   'Johnny',
#   'Knoxville'],
#  ['Ray',
#   'Winstone',
#   'Angelina',
#   'Jolie',
#   'Anthony',
#   'Hopkins',
#   'Robin',
#   'Wright',
#   'John',
#   'Malkovich'],
#  ['Jack',
#   'Black',
#   'Bryan',
#   'Cranston',
#   'Dustin',
#   'Hoffman',
#   'Angelina',
#   'Jolie',
#   'JK',
#   'Simmons'],
#  ['Tom',
#   'Cruise',
#   'Jeremy',
#   'Renner',
#   'Simon',
#   'Pegg',
#   'Paula',
#   'Patton',
#   'Anil',
#   'Kapoor'],
#  ['Chris',
#   'Pine',
#   'Alec',
#   'Baldwin',
#   'Jude',
#   'Law',
#   'Isla',
#   'Fisher',
#   'Hugh',
#   'Jackman'],
#  ['Jim',
#   'Carrey',
#   'Tuea',
#   'Leoni',
#   'Alec',
#   'Baldwin',
#   'Richard',
#   'Jenkins',
#   'Angie',
#   'Harmon'],
#  ['Tom',
#   'Cruise',
#   'Ken',
#   'Watanabe',
#   'William',
#   'Atherton',
#   'Chad',
#   'Lindberg',
#   'Billy',
#   'Connolly'],
#  ['Christian',
#   'Bale',
#   'Joel',
#   'Edgerton',
#   'John',
#   'Turturro',
#   'Aaron',
#   'Paul',
#   'Ben',
#   'Mendelsohn'],
#  ['Chris',
#   'Pine',
#   'Zachary',
#   'Quinto',
#   'Leonard',
#   'Nimoy',
#   'Eric',
#   'Bana',
#   'Bruce',
#   'Greenwood'],
#  ['Tobey',
#   'Maguire',
#   'Willem',
#   'Dafoe',
#   'Kirsten',
#   'Dunst',
#   'James',
#   'Franco',
#   'Cliff',
#   'Robertson'],
#  ['Jay',
#   'Baruchel',
#   'Gerard',
#   'Butler',
#   'Kristen',
#   'Wiig',
#   'Jonah',
#   'Hill',
#   'Cate',
#   'Blanchett'],
#  ['Brenton',
#   'Thwaites',
#   'Nikolaj',
#   'CosterWaldau',
#   'Gerard',
#   'Butler',
#   'Courtney',
#   'Eaton',
#   'Elodie',
#   'Yung'],
#  ['Josh',
#   'Lucas',
#   'Jessica',
#   'Biel',
#   'Jamie',
#   'Foxx',
#   'Sam',
#   'Shepard',
#   'Richard',
#   'Roxburgh'],
#  ['Malin',
#   'uckerman',
#   'Billy',
#   'Crudup',
#   'Carla',
#   'Gugino',
#   'Jeffrey',
#   'Dean',
#   'Morgan',
#   'Patrick',
#   'Wilson'],
#  ['Mel',
#   'Gibson',
#   'Danny',
#   'Glover',
#   'Joe',
#   'Pesci',
#   'Rene',
#   'Russo',
#   'Jet',
#   'Li'],
#  ['Eric',
#   'Bana',
#   'Jennifer',
#   'Connelly',
#   'Sam',
#   'Elliott',
#   'Josh',
#   'Lucas',
#   'Nick',
#   'Nolte'],
#  ['Dwayne',
#   'Johnson',
#   'DJ',
#   'Cotrona',
#   'Adrianne',
#   'Palicki',
#   'Bruce',
#   'Willis',
#   'Ray',
#   'Park'],
#  ['Matthew',
#   'McConaughey',
#   'Penuelope',
#   'Cruz',
#   'Steve',
#   'Zahn',
#   'William',
#   'H',
#   'Macy',
#   'Lennie',
#   'James'],
#  ['Donald',
#   'Sutherland',
#   'MingNa',
#   'Wen',
#   'Alec',
#   'Baldwin',
#   'Ving',
#   'Rhames',
#   'Steve',
#   'Buscemi'],
#  ['Chris',
#   'Evans',
#   'Hugo',
#   'Weaving',
#   'Tommy',
#   'Lee',
#   'Jones',
#   'Hayley',
#   'Atwell',
#   'Sebastian',
#   'Stan'],
#  ['Pierce',
#   'Brosnan',
#   'Sophie',
#   'Marceau',
#   'Robert',
#   'Carlyle',
#   'Denise',
#   'Richards',
#   'Robbie',
#   'Coltrane'],
#  ['Russell',
#   'Crowe',
#   'Paul',
#   'Bettany',
#   'James',
#   'DArcy',
#   'Billy',
#   'Boyd',
#   'Joseph',
#   'Morgan'],
#  ['Kristen',
#   'Stewart',
#   'Robert',
#   'Pattinson',
#   'Taylor',
#   'Lautner',
#   'Peter',
#   'Facinelli',
#   'Elizabeth',
#   'Reaser'],
#  ['Elijah',
#   'Wood',
#   'Robin',
#   'Williams',
#   'Pink',
#   'EG',
#   'Daily',
#   'Johnny',
#   'A',
#   'Sanchez'],
#  ['Edward',
#   'Norton',
#   'Liv',
#   'Tyler',
#   'Tim',
#   'Roth',
#   'William',
#   'Hurt',
#   'Tim',
#   'Blake',
#   'Nelson'],
#  ['Ruby',
#   'Barnhill',
#   'Mark',
#   'Rylance',
#   'Rebecca',
#   'Hall',
#   'Jemaine',
#   'Clement',
#   'Bill',
#   'Hader'],
#  ['Leonardo',
#   'DiCaprio',
#   'Tom',
#   'Hardy',
#   'Will',
#   'Poulter',
#   'Domhnall',
#   'Gleeson',
#   'Paul',
#   'Anderson'],
#  ['Ryan',
#   'Reynolds',
#   'Paul',
#   'Giamatti',
#   'Michael',
#   'Peufa',
#   'Samuel',
#   'L',
#   'Jackson',
#   'Luis',
#   'Guzmuen'],
#  ['Johnny',
#   'Depp',
#   'Isla',
#   'Fisher',
#   'Ned',
#   'Beatty',
#   'Bill',
#   'Nighy',
#   'Alfred',
#   'Molina'],
#  ['Tom',
#   'McGrath',
#   'Chris',
#   'Miller',
#   'Christopher',
#   'Knights',
#   'Conrad',
#   'Vernon',
#   'John',
#   'Malkovich'],
#  ['Matt',
#   'Damon',
#   'Julia',
#   'Stiles',
#   'David',
#   'Strathairn',
#   'Scott',
#   'Glenn',
#   'Paddy',
#   'Considine'],
#  ['Jack',
#   'Black',
#   'Dustin',
#   'Hoffman',
#   'Angelina',
#   'Jolie',
#   'Jackie',
#   'Chan',
#   'Lucy',
#   'Liu'],
#  ['Paul',
#   'Rudd',
#   'Michael',
#   'Douglas',
#   'Evangeline',
#   'Lilly',
#   'Corey',
#   'Stoll',
#   'Bobby',
#   'Cannavale'],
#  ['Jennifer',
#   'Lawrence',
#   'Josh',
#   'Hutcherson',
#   'Liam',
#   'Hemsworth',
#   'Woody',
#   'Harrelson',
#   'Elizabeth',
#   'Banks'],
#  ['Jim',
#   'Parsons',
#   'Rihanna',
#   'Steve',
#   'Martin',
#   'Jennifer',
#   'Lopez',
#   'Matt',
#   'Jones'],
#  ['Tom',
#   'Cruise',
#   'Dakota',
#   'Fanning',
#   'Miranda',
#   'Otto',
#   'Justin',
#   'Chatwin',
#   'Tim',
#   'Robbins'],
#  ['Martin',
#   'Lawrence',
#   'Will',
#   'Smith',
#   'Jordi',
#   'Mollue',
#   'Gabrielle',
#   'Union',
#   'Peter',
#   'Stormare'],
#  ['Antonio',
#   'Banderas',
#   'Salma',
#   'Hayek',
#   'Zach',
#   'Galifianakis',
#   'Billy',
#   'Bob',
#   'Thornton',
#   'Amy',
#   'Sedaris'],
#  ['Angelina',
#   'Jolie',
#   'Liev',
#   'Schreiber',
#   'Chiwetel',
#   'Ejiofor',
#   'Daniel',
#   'Olbrychski',
#   'August',
#   'Diehl'],
#  ['Russell',
#   'Crowe',
#   'Jennifer',
#   'Connelly',
#   'Emma',
#   'Watson',
#   'Logan',
#   'Lerman',
#   'Anthony',
#   'Hopkins'],
#  ['Jamie',
#   'Bell',
#   'Andy',
#   'Serkis',
#   'Daniel',
#   'Craig',
#   'Nick',
#   'Frost',
#   'Simon',
#   'Pegg'],
#  ['Daniel',
#   'Radcliffe',
#   'Rupert',
#   'Grint',
#   'Emma',
#   'Watson',
#   'Gary',
#   'Oldman',
#   'David',
#   'Thewlis'],
#  ['Nicole',
#   'Kidman',
#   'Hugh',
#   'Jackman',
#   'Essie',
#   'Davis',
#   'David',
#   'Wenham',
#   'Bryan',
#   'Brown'],
#  ['Jaden',
#   'Smith',
#   'Will',
#   'Smith',
#   'Sophie',
#   'Okonedo',
#   'Zoueb',
#   'Kravitz',
#   'Glenn',
#   'Morshower'],
#  ['D',
#   'B',
#   'Sweeney',
#   'Alfre',
#   'Woodard',
#   'Ossie',
#   'Davis',
#   'Max',
#   'Casella',
#   'Hayden',
#   'Panettiere'],
#  ['Ben',
#   'Stiller',
#   'Rami',
#   'Malek',
#   'Rebel',
#   'Wilson',
#   'Robin',
#   'Williams',
#   'Owen',
#   'Wilson'],
#  ['Will',
#   'Ferrell',
#   'Brad',
#   'Pitt',
#   'Tina',
#   'Fey',
#   'Jonah',
#   'Hill',
#   'David',
#   'Cross'],
#  ['Daniel',
#   'Radcliffe',
#   'Rupert',
#   'Grint',
#   'Emma',
#   'Watson',
#   'Richard',
#   'Harris',
#   'Tom',
#   'Felton'],
#  ['Jeff',
#   'Bridges',
#   'Ryan',
#   'Reynolds',
#   'Kevin',
#   'Bacon',
#   'Stephanie',
#   'Szostak',
#   'MaryLouise',
#   'Parker'],
#  ['Johnny',
#   'Depp',
#   'Geoffrey',
#   'Rush',
#   'Orlando',
#   'Bloom',
#   'Keira',
#   'Knightley',
#   'Jack',
#   'Davenport'],
#  ['Jennifer',
#   'Lawrence',
#   'Josh',
#   'Hutcherson',
#   'Liam',
#   'Hemsworth',
#   'Woody',
#   'Harrelson',
#   'Donald',
#   'Sutherland'],
#  ['Tom',
#   'Hanks',
#   'Audrey',
#   'Tautou',
#   'Ian',
#   'McKellen',
#   'Paul',
#   'Bettany',
#   'Jean',
#   'Reno'],
#  ['Jesse',
#   'Eisenberg',
#   'Anne',
#   'Hathaway',
#   'Leslie',
#   'Mann',
#   'Jamie',
#   'Foxx',
#   'Andy',
#   'Garcueda'],
#  ['Patrick',
#   'Stewart',
#   'Hugh',
#   'Jackman',
#   'Ian',
#   'McKellen',
#   'Halle',
#   'Berry',
#   'Famke',
#   'Janssen'],
#  ['Vin',
#   'Diesel',
#   'Paul',
#   'Walker',
#   'Jordana',
#   'Brewster',
#   'Tyrese',
#   'Gibson',
#   'Ludacris'],
#  ['Robert',
#   'Downey',
#   'Jr',
#   'Jude',
#   'Law',
#   'Jared',
#   'Harris',
#   'Noomi',
#   'Rapace',
#   'Kelly',
#   'Reilly'],
#  ['Sam',
#   'Worthington',
#   'Liam',
#   'Neeson',
#   'Ralph',
#   'Fiennes',
#   'Gemma',
#   'Arterton',
#   'Jason',
#   'Flemyng'],
#  ['Arnold',
#   'Schwarzenegger',
#   'Sharon',
#   'Stone',
#   'Rachel',
#   'Ticotin',
#   'Ronny',
#   'Cox',
#   'Michael',
#   'Ironside'],
#  ['Antonio',
#   'Banderas',
#   'Vladimir',
#   'Kulich',
#   'Dennis',
#   'Storhufi',
#   'Daniel',
#   'Southern',
#   'Clive',
#   'Russell'],
#  ['Jeremy',
#   'Renner',
#   'Rachel',
#   'Weisz',
#   'Edward',
#   'Norton',
#   'Scott',
#   'Glenn',
#   'Stacy',
#   'Keach'],
#  ['George',
#   'Clooney',
#   'Chris',
#   'ODonnell',
#   'Arnold',
#   'Schwarzenegger',
#   'Uma',
#   'Thurman',
#   'Alicia',
#   'Silverstone'],
#  ['Jim',
#   'Carrey',
#   'Taylor',
#   'Momsen',
#   'Jeffrey',
#   'Tambor',
#   'Christine',
#   'Baranski',
#   'Bill',
#   'Irwin'],
#  ['Dennis',
#   'Quaid',
#   'Jake',
#   'Gyllenhaal',
#   'Emmy',
#   'Rossum',
#   'Dash',
#   'Mihok',
#   'Jay',
#   'O',
#   'Sanders'],
#  ['Tom',
#   'Cruise',
#   'Dougray',
#   'Scott',
#   'Thandie',
#   'Newton',
#   'Ving',
#   'Rhames',
#   'Richard',
#   'Roxburgh'],
#  ['George',
#   'Clooney',
#   'Mark',
#   'Wahlberg',
#   'Diane',
#   'Lane',
#   'John',
#   'C',
#   'Reilly',
#   'William',
#   'Fichtner'],
#  ['Ioan',
#   'Gruffudd',
#   'Jessica',
#   'Alba',
#   'Chris',
#   'Evans',
#   'Michael',
#   'Chiklis',
#   'Julian',
#   'McMahon'],
#  ['Suraj',
#   'Sharma',
#   'Irrfan',
#   'Khan',
#   'Ayush',
#   'Tandon',
#   'Gautam',
#   'Belur',
#   'Adil',
#   'Hussain'],
#  ['Nicolas',
#   'Cage',
#   'Eva',
#   'Mendes',
#   'Wes',
#   'Bentley',
#   'Donal',
#   'Logue',
#   'Sam',
#   'Elliott'],
#  ['Matt',
#   'Damon',
#   'Alicia',
#   'Vikander',
#   'Tommy',
#   'Lee',
#   'Jones',
#   'Vincent',
#   'Cassel',
#   'Julia',
#   'Stiles'],
#  ['Cameron',
#   'Diaz',
#   'Drew',
#   'Barrymore',
#   'Lucy',
#   'Liu',
#   'Bernie',
#   'Mac',
#   'Robert',
#   'Patrick'],
#  ['Noomi',
#   'Rapace',
#   'Michael',
#   'Fassbender',
#   'Guy',
#   'Pearce',
#   'Idris',
#   'Elba',
#   'Logan',
#   'MarshallGreen'],
#  ['Michael',
#   'J',
#   'Fox',
#   'Geena',
#   'Davis',
#   'Hugh',
#   'Laurie',
#   'Jonathan',
#   'Lipnicki',
#   'Anna',
#   'Hoelck'],
#  ['Matt',
#   'Damon',
#   'Jodie',
#   'Foster',
#   'Sharlto',
#   'Copley',
#   'Alice',
#   'Braga',
#   'Diego',
#   'Luna'],
#  ['Vin',
#   'Diesel',
#   'Thandie',
#   'Newton',
#   'Karl',
#   'Urban',
#   'Colm',
#   'Feore',
#   'Linus',
#   'Roache'],
#  ['Joel',
#   'Kinnaman',
#   'Gary',
#   'Oldman',
#   'Michael',
#   'Keaton',
#   'Abbie',
#   'Cornish',
#   'Jackie',
#   'Earle',
#   'Haley'],
#  ['Emile',
#   'Hirsch',
#   'Christina',
#   'Ricci',
#   'Matthew',
#   'Fox',
#   'Susan',
#   'Sarandon',
#   'Scott',
#   'Porter'],
#  ['Reese',
#   'Witherspoon',
#   'Paul',
#   'Rudd',
#   'Owen',
#   'Wilson',
#   'Jack',
#   'Nicholson',
#   'Kathryn',
#   'Hahn'],
#  ['Tom',
#   'Cruise',
#   'Cameron',
#   'Diaz',
#   'Peter',
#   'Sarsgaard',
#   'Viola',
#   'Davis',
#   'Jordi',
#   'Mollue'],
#  ['Tom',
#   'Cruise',
#   'Morgan',
#   'Freeman',
#   'Olga',
#   'Kurylenko',
#   'Andrea',
#   'Riseborough',
#   'Nikolaj',
#   'CosterWaldau'],
#  ['Ewan',
#   'McGregor',
#   'Natalie',
#   'Portman',
#   'Hayden',
#   'Christensen',
#   'Ian',
#   'McDiarmid',
#   'Samuel',
#   'L',
#   'Jackson'],
#  ['Ewan',
#   'McGregor',
#   'Natalie',
#   'Portman',
#   'Hayden',
#   'Christensen',
#   'Ian',
#   'McDiarmid',
#   'Samuel',
#   'L',
#   'Jackson'],
#  ['John',
#   'Goodman',
#   'Billy',
#   'Crystal',
#   'Mary',
#   'Gibbs',
#   'Steve',
#   'Buscemi',
#   'James',
#   'Coburn'],
#  ['Hugh',
#   'Jackman',
#   'Hiroyuki',
#   'Sanada',
#   'Famke',
#   'Janssen',
#   'Will',
#   'Yun',
#   'Lee',
#   'Tao',
#   'Okamoto'],
#  ['Liam',
#   'Neeson',
#   'Ewan',
#   'McGregor',
#   'Natalie',
#   'Portman',
#   'Jake',
#   'Lloyd',
#   'Ian',
#   'McDiarmid'],
#  ['Nicolas',
#   'Cage',
#   'Emma',
#   'Stone',
#   'Ryan',
#   'Reynolds',
#   'Catherine',
#   'Keener',
#   'Cloris',
#   'Leachman'],
#  ['Nicolas',
#   'Cage',
#   'Adam',
#   'Beach',
#   'Peter',
#   'Stormare',
#   'Noah',
#   'Emmerich',
#   'Mark',
#   'Ruffalo'],
#  ['Chris',
#   'Hemsworth',
#   'Charlize',
#   'Theron',
#   'Emily',
#   'Blunt',
#   'Jessica',
#   'Chastain',
#   'Nick',
#   'Frost'],
#  ['Megan',
#   'Fox',
#   'Will',
#   'Arnett',
#   'William',
#   'Fichtner',
#   'Alan',
#   'Ritchson',
#   'Noel',
#   'Fisher'],
#  ['Sandra',
#   'Bullock',
#   'George',
#   'Clooney',
#   'Ed',
#   'Harris',
#   'Orto',
#   'Ignatiussen',
#   'Phaldut',
#   'Sharma'],
#  ['Pierce',
#   'Brosnan',
#   'Linda',
#   'Hamilton',
#   'Jamie',
#   'Renuee',
#   'Smith',
#   'Jeremy',
#   'Foley',
#   'Elizabeth',
#   'Hoffman'],
#  ['Megan',
#   'Fox',
#   'Stephen',
#   'Amell',
#   'Will',
#   'Arnett',
#   'Laura',
#   'Linney',
#   'Pete',
#   'Ploszek'],
#  ['Miles',
#   'Teller',
#   'Kate',
#   'Mara',
#   'Michael',
#   'B',
#   'Jordan',
#   'Jamie',
#   'Bell',
#   'Toby',
#   'Kebbell'],
#  ['Ben',
#   'Stiller',
#   'Jake',
#   'Cherry',
#   'Carla',
#   'Gugino',
#   'Robin',
#   'Williams',
#   'Dick',
#   'Van',
#   'Dyke'],
#  ['Dwayne',
#   'Johnson',
#   'Alexandra',
#   'Daddario',
#   'Carla',
#   'Gugino',
#   'Ioan',
#   'Gruffudd',
#   'Archie',
#   'Panjabi'],
#  ['Pierce',
#   'Brosnan',
#   'Jonathan',
#   'Pryce',
#   'Michelle',
#   'Yeoh',
#   'Teri',
#   'Hatcher',
#   'Ricky',
#   'Jay'],
#  ['Mel',
#   'Gibson',
#   'Heath',
#   'Ledger',
#   'Joely',
#   'Richardson',
#   'Jason',
#   'Isaacs',
#   'Tchueky',
#   'Karyo'],
#  ['George',
#   'Clooney',
#   'Brad',
#   'Pitt',
#   'Catherine',
#   'ZetaJones',
#   'Julia',
#   'Roberts',
#   'Andy',
#   'Garcueda'],
#  ['Angelina',
#   'Jolie',
#   'Brad',
#   'Pitt',
#   'Vince',
#   'Vaughn',
#   'Adam',
#   'Brody',
#   'Kerry',
#   'Washington'],
#  ['Shailene',
#   'Woodley',
#   'Theo',
#   'James',
#   'Kate',
#   'Winslet',
#   'Ansel',
#   'Elgort',
#   'Miles',
#   'Teller'],
#  ['Leonardo',
#   'DiCaprio',
#   'Cate',
#   'Blanchett',
#   'Kate',
#   'Beckinsale',
#   'John',
#   'C',
#   'Reilly',
#   'Alec',
#   'Baldwin'],
#  ['Jack',
#   'Black',
#   'Amanda',
#   'Peet',
#   'Emily',
#   'Blunt',
#   'Jason',
#   'Segel',
#   'Chris',
#   'ODowd'],
#  ['Seth',
#   'Rogen',
#   'Jay',
#   'Chou',
#   'Christoph',
#   'Waltz',
#   'Cameron',
#   'Diaz',
#   'Edward',
#   'Furlong'],
#  ['Sullivan',
#   'Stapleton',
#   'Eva',
#   'Green',
#   'Lena',
#   'Headey',
#   'Callan',
#   'Mulvey',
#   'David',
#   'Wenham'],
#  ['Hank',
#   'Azaria',
#   'Neil',
#   'Patrick',
#   'Harris',
#   'Jayma',
#   'Mays',
#   'Sofueda',
#   'Vergara',
#   'Tim',
#   'Gunn'],
#  ['Roseanne',
#   'Barr',
#   'Judi',
#   'Dench',
#   'Jennifer',
#   'Tilly',
#   'Steve',
#   'Buscemi',
#   'G',
#   'W',
#   'Bailey'],
#  ['Shailene',
#   'Woodley',
#   'Theo',
#   'James',
#   'Zoueb',
#   'Kravitz',
#   'Miles',
#   'Teller',
#   'Naomi',
#   'Watts'],
#  ['Hugh',
#   'Jackman',
#   'Dakota',
#   'Goyo',
#   'Evangeline',
#   'Lilly',
#   'Anthony',
#   'Mackie',
#   'Kevin',
#   'Durand'],
#  ['Hank',
#   'Azaria',
#   'Neil',
#   'Patrick',
#   'Harris',
#   'Brendan',
#   'Gleeson',
#   'Jayma',
#   'Mays',
#   'Jonathan',
#   'Winters'],
#  ['Sandra',
#   'Bullock',
#   'Jason',
#   'Patric',
#   'Willem',
#   'Dafoe',
#   'Temuera',
#   'Morrison',
#   'Mike',
#   'Hagerty'],
#  ['Asa',
#   'Butterfield',
#   'Harrison',
#   'Ford',
#   'Hailee',
#   'Steinfeld',
#   'Abigail',
#   'Breslin',
#   'Ben',
#   'Kingsley'],
#  ['Bruce',
#   'Willis',
#   'Justin',
#   'Long',
#   'Timothy',
#   'Olyphant',
#   'Cliff',
#   'Curtis',
#   'Maggie',
#   'Q'],
#  ['Elijah',
#   'Wood',
#   'Ian',
#   'McKellen',
#   'Cate',
#   'Blanchett',
#   'Orlando',
#   'Bloom',
#   'Sean',
#   'Bean'],
#  ['Jackie',
#   'Chan',
#   'Steve',
#   'Coogan',
#   'Cuecile',
#   'de',
#   'France',
#   'Robert',
#   'Fyfe',
#   'Jim',
#   'Broadbent'],
#  ['Will',
#   'Smith',
#   'Jamie',
#   'Foxx',
#   'Jon',
#   'Voight',
#   'Mario',
#   'Van',
#   'Peebles',
#   'Ron',
#   'Silver'],
#  ['Mike',
#   'Myers',
#   'Dakota',
#   'Fanning',
#   'Spencer',
#   'Breslin',
#   'Kelly',
#   'Preston',
#   'Alec',
#   'Baldwin'],
#  ['Will',
#   'Smith',
#   'Bridget',
#   'Moynahan',
#   'Alan',
#   'Tudyk',
#   'James',
#   'Cromwell',
#   'Bruce',
#   'Greenwood'],
#  ['Orlando',
#   'Bloom',
#   'Eva',
#   'Green',
#   'Jeremy',
#   'Irons',
#   'Marton',
#   'Csokas',
#   'Brendan',
#   'Gleeson'],
#  ['Michael',
#   'J',
#   'Fox',
#   'Geena',
#   'Davis',
#   'Hugh',
#   'Laurie',
#   'Jonathan',
#   'Lipnicki',
#   'Nathan',
#   'Lane'],
#  ['Anika',
#   'Noni',
#   'Rose',
#   'Bruno',
#   'Campos',
#   'Keith',
#   'David',
#   'MichaelLeon',
#   'Wooley',
#   'Jennifer',
#   'Cody'],
#  ['Matt',
#   'Damon',
#   'Jessica',
#   'Chastain',
#   'Kristen',
#   'Wiig',
#   'Jeff',
#   'Daniels',
#   'Michael',
#   'Peufa'],
#  ['Ewan',
#   'McGregor',
#   'Scarlett',
#   'Johansson',
#   'Djimon',
#   'Hounsou',
#   'Sean',
#   'Bean',
#   'Steve',
#   'Buscemi'],
#  ['Warren',
#   'Beatty',
#   'Diane',
#   'Keaton',
#   'Goldie',
#   'Hawn',
#   'Garry',
#   'Shandling',
#   'Andie',
#   'MacDowell'],
#  ['Nicolas',
#   'Cage',
#   'Angelina',
#   'Jolie',
#   'Giovanni',
#   'Ribisi',
#   'Delroy',
#   'Lindo',
#   'Will',
#   'Patton'],
#  ['Russell',
#   'Crowe',
#   'Joaquin',
#   'Phoenix',
#   'Connie',
#   'Nielsen',
#   'Oliver',
#   'Reed',
#   'Richard',
#   'Harris'],
#  ['Tom',
#   'Cruise',
#   'Colin',
#   'Farrell',
#   'Samantha',
#   'Morton',
#   'Max',
#   'von',
#   'Sydow',
#   'Lois',
#   'Smith'],
#  ['Daniel',
#   'Radcliffe',
#   'Rupert',
#   'Grint',
#   'Emma',
#   'Watson',
#   'Richard',
#   'Harris',
#   'Alan',
#   'Rickman'],
#  ['Daniel',
#   'Craig',
#   'Eva',
#   'Green',
#   'Mads',
#   'Mikkelsen',
#   'Judi',
#   'Dench',
#   'Jeffrey',
#   'Wright'],
#  ['Mark',
#   'Wahlberg',
#   'Tim',
#   'Roth',
#   'Helena',
#   'Bonham',
#   'Carter',
#   'Michael',
#   'Clarke',
#   'Duncan',
#   'Kris',
#   'Kristofferson'],
#  ['Arnold',
#   'Schwarzenegger',
#   'Linda',
#   'Hamilton',
#   'Robert',
#   'Patrick',
#   'Edward',
#   'Furlong',
#   'Michael',
#   'Edwards'],
#  ['Christian',
#   'Bale',
#   'Johnny',
#   'Depp',
#   'Giovanni',
#   'Ribisi',
#   'Billy',
#   'Crudup',
#   'Marion',
#   'Cotillard'],
#  ['Denzel',
#   'Washington',
#   'Russell',
#   'Crowe',
#   'Chiwetel',
#   'Ejiofor',
#   'Josh',
#   'Brolin',
#   'Lymari',
#   'Nadal'],
#  ['Arnold',
#   'Schwarzenegger',
#   'Jamie',
#   'Lee',
#   'Curtis',
#   'Tom',
#   'Arnold',
#   'Bill',
#   'Paxton',
#   'Tia',
#   'Carrere'],
#  ['Denzel',
#   'Washington',
#   'John',
#   'Travolta',
#   'Luis',
#   'Guzmuen',
#   'Victor',
#   'Gojcaj',
#   'John',
#   'Turturro'],
#  ['Robert',
#   'De',
#   'Niro',
#   'Ben',
#   'Stiller',
#   'Owen',
#   'Wilson',
#   'Dustin',
#   'Hoffman',
#   'Barbra',
#   'Streisand'],
#  ['Will',
#   'Ferrell',
#   'Mark',
#   'Wahlberg',
#   'Eva',
#   'Mendes',
#   'Samuel',
#   'L',
#   'Jackson',
#   'Dwayne',
#   'Johnson'],
#  ['Arnold',
#   'Schwarzenegger',
#   'James',
#   'Caan',
#   'Vanessa',
#   'Williams',
#   'James',
#   'Coburn',
#   'Robert',
#   'Pastorelli'],
#  ['Jamie',
#   'Foxx',
#   'Christoph',
#   'Waltz',
#   'Leonardo',
#   'DiCaprio',
#   'Kerry',
#   'Washington',
#   'Samuel',
#   'L',
#   'Jackson'],
#  ['Tom',
#   'Hulce',
#   'Demi',
#   'Moore',
#   'Tony',
#   'Jay',
#   'Kevin',
#   'Kline',
#   'Paul',
#   'Kandel'],
#  ['David',
#   'Spade',
#   'John',
#   'Goodman',
#   'Eartha',
#   'Kitt',
#   'Patrick',
#   'Warburton',
#   'Wendie',
#   'Malick'],
#  ['Sylvester',
#   'Stallone',
#   'Jason',
#   'Statham',
#   'Dolph',
#   'Lundgren',
#   'Bruce',
#   'Willis',
#   'Arnold',
#   'Schwarzenegger'],
#  ['Nicolas',
#   'Cage',
#   'Diane',
#   'Kruger',
#   'Justin',
#   'Bartha',
#   'Sean',
#   'Bean',
#   'Jon',
#   'Voight'],
#  ['Ed',
#   'Speleers',
#   'Jeremy',
#   'Irons',
#   'Sienna',
#   'Guillory',
#   'Robert',
#   'Carlyle',
#   'Djimon',
#   'Hounsou'],
#  ['Max',
#   'Records',
#   'Catherine',
#   'Keener',
#   'Lauren',
#   'Ambrose',
#   'James',
#   'Gandolfini',
#   'Catherine',
#   'OHara'],
#  ['Josh',
#   'Hutcherson',
#   'Amanda',
#   'Seyfried',
#   'Colin',
#   'Farrell',
#   'Jason',
#   'Sudeikis',
#   'Aziz',
#   'Ansari'],
#  ['Johnny',
#   'Depp',
#   'Angelina',
#   'Jolie',
#   'Paul',
#   'Bettany',
#   'Timothy',
#   'Dalton',
#   'Steven',
#   'Berkoff'],
#  ['Arnold',
#   'Schwarzenegger',
#   'Gabriel',
#   'Byrne',
#   'Kevin',
#   'Pollak',
#   'Robin',
#   'Tunney',
#   'CCH',
#   'Pounder'],
#  ['Leonardo',
#   'DiCaprio',
#   'Djimon',
#   'Hounsou',
#   'Jennifer',
#   'Connelly',
#   'Kagiso',
#   'Kuypers',
#   'Arnold',
#   'Vosloo'],
#  ['Leonardo',
#   'DiCaprio',
#   'Jonah',
#   'Hill',
#   'Margot',
#   'Robbie',
#   'Kyle',
#   'Chandler',
#   'Rob',
#   'Reiner'],
#  ['Val',
#   'Kilmer',
#   'Tommy',
#   'Lee',
#   'Jones',
#   'Jim',
#   'Carrey',
#   'Nicole',
#   'Kidman',
#   'Chris',
#   'ODonnell'],
#  ['Casper',
#   'Van',
#   'Dien',
#   'Dina',
#   'Meyer',
#   'Denise',
#   'Richards',
#   'Jake',
#   'Busey',
#   'Neil',
#   'Patrick',
#   'Harris'],
#  ['Tom',
#   'Hanks',
#   'Halle',
#   'Berry',
#   'Jim',
#   'Broadbent',
#   'Hugo',
#   'Weaving',
#   'Jim',
#   'Sturgess'],
#  ['Emily',
#   'Barclay',
#   'Abbie',
#   'Cornish',
#   'Essie',
#   'Davis',
#   'Joel',
#   'Edgerton',
#   'DeborraLee',
#   'Furness'],
#  ['Halle',
#   'Berry',
#   'Benjamin',
#   'Bratt',
#   'Sharon',
#   'Stone',
#   'Lambert',
#   'Wilson',
#   'Frances',
#   'Conroy'],
#  ['Dwayne',
#   'Johnson',
#   'Ian',
#   'McShane',
#   'John',
#   'Hurt',
#   'Rufus',
#   'Sewell',
#   'Aksel',
#   'Hennie'],
#  ['Joseph',
#   'GordonLevitt',
#   'Brian',
#   'Murray',
#   'David',
#   'Hyde',
#   'Pierce',
#   'Emma',
#   'Thompson',
#   'Michael',
#   'Wincott'],
#  ['Will',
#   'Ferrell',
#   'Anna',
#   'Friel',
#   'Danny',
#   'McBride',
#   'Jorma',
#   'Taccone',
#   'Matt',
#   'Lauer'],
#  ['Sylvester',
#   'Stallone',
#   'Jason',
#   'Statham',
#   'Harrison',
#   'Ford',
#   'Arnold',
#   'Schwarzenegger',
#   'Mel',
#   'Gibson'],
#  ['Edgar',
#   'Ramuedrez',
#   'Luke',
#   'Bracey',
#   'Teresa',
#   'Palmer',
#   'Delroy',
#   'Lindo',
#   'Ray',
#   'Winstone'],
#  ['Jamie',
#   'Kennedy',
#   'Alan',
#   'Cumming',
#   'Traylor',
#   'Howard',
#   'Kal',
#   'Penn',
#   'Steven',
#   'Wright'],
#  ['Chris',
#   'Hemsworth',
#   'Benjamin',
#   'Walker',
#   'Cillian',
#   'Murphy',
#   'Brendan',
#   'Gleeson',
#   'Ben',
#   'Whishaw'],
#  ['Eddie',
#   'Murphy',
#   'Randy',
#   'Quaid',
#   'Rosario',
#   'Dawson',
#   'Joe',
#   'Pantoliano',
#   'Jay',
#   'Mohr'],
#  ['Matt',
#   'Damon',
#   'Greg',
#   'Kinnear',
#   'Brendan',
#   'Gleeson',
#   'Amy',
#   'Ryan',
#   'Jason',
#   'Isaacs'],
#  ['Noah',
#   'Schnapp',
#   'Bill',
#   'Melendez',
#   'Venus',
#   'Schultheis',
#   'Hadley',
#   'Belle',
#   'Miller',
#   'Madisyn',
#   'Shipman'],
#  ['Steve',
#   'Martin',
#   'Campbell',
#   'Scott',
#   'Ben',
#   'Gazzara',
#   'Rebecca',
#   'Pidgeon',
#   'Ricky',
#   'Jay'],
#  ['Brendan',
#   'Fraser',
#   'Rachel',
#   'Weisz',
#   'John',
#   'Hannah',
#   'Arnold',
#   'Vosloo',
#   'Oded',
#   'Fehr'],
#  ['Leonardo',
#   'DiCaprio',
#   'Daniel',
#   'DayLewis',
#   'Cameron',
#   'Diaz',
#   'Liam',
#   'Neeson',
#   'Brendan',
#   'Gleeson'],
#  ['Shia',
#   'LaBeouf',
#   'Jeff',
#   'Bridges',
#   'Zooey',
#   'Deschanel',
#   'Jon',
#   'Heder',
#   'James',
#   'Woods'],
#  ['Nicole',
#   'Kidman',
#   'Matthew',
#   'Broderick',
#   'Bette',
#   'Midler',
#   'Glenn',
#   'Close',
#   'Christopher',
#   'Walken'],
#  ['Josh',
#   'Hartnett',
#   'Ewan',
#   'McGregor',
#   'Jason',
#   'Isaacs',
#   'Tom',
#   'Sizemore',
#   'William',
#   'Fichtner'],
#  ['Will',
#   'Ferrell',
#   'Zach',
#   'Galifianakis',
#   'Dylan',
#   'McDermott',
#   'Jason',
#   'Sudeikis',
#   'Sarah',
#   'Baker'],
#  ['Bruce',
#   'Willis',
#   'Gary',
#   'Oldman',
#   'Ian',
#   'Holm',
#   'Milla',
#   'Jovovich',
#   'Chris',
#   'Tucker'],
#  ['Sarah',
#   'Jessica',
#   'Parker',
#   'Kristin',
#   'Davis',
#   'Cynthia',
#   'Nixon',
#   'Kim',
#   'Cattrall',
#   'Chris',
#   'Noth'],
#  ['Kenneth',
#   'Branagh',
#   'Kevin',
#   'Kline',
#   'Rosie',
#   'Perez',
#   'Armand',
#   'Assante',
#   'Edward',
#   'James',
#   'Olmos'],
#  ['John',
#   'Leguizamo',
#   'Ray',
#   'Romano',
#   'Chris',
#   'Wedge',
#   'Denis',
#   'Leary',
#   'Seann',
#   'William',
#   'Scott'],
#  ['Lily',
#   'James',
#   'Cate',
#   'Blanchett',
#   'Richard',
#   'Madden',
#   'Helena',
#   'Bonham',
#   'Carter',
#   'Stellan',
#   'Skarsguerd'],
#  ['Rachel',
#   'Weisz',
#   'Mark',
#   'Wahlberg',
#   'Susan',
#   'Sarandon',
#   'Saoirse',
#   'Ronan',
#   'Stanley',
#   'Tucci'],
#  ['Albert',
#   'Brooks',
#   'Ellen',
#   'DeGeneres',
#   'Alexander',
#   'Gould',
#   'Willem',
#   'Dafoe',
#   'Brad',
#   'Garrett'],
#  ['Elijah',
#   'Wood',
#   'Ian',
#   'McKellen',
#   'Viggo',
#   'Mortensen',
#   'Liv',
#   'Tyler',
#   'Orlando',
#   'Bloom'],
#  ['Elijah',
#   'Wood',
#   'Ian',
#   'McKellen',
#   'Viggo',
#   'Mortensen',
#   'Liv',
#   'Tyler',
#   'Orlando',
#   'Bloom'],
#  ['Jeff',
#   'Bridges',
#   'Julianne',
#   'Moore',
#   'Ben',
#   'Barnes',
#   'Alicia',
#   'Vikander',
#   'Kit',
#   'Harington'],
#  ['Angelina',
#   'Jolie',
#   'Jon',
#   'Voight',
#   'Iain',
#   'Glen',
#   'Noah',
#   'Taylor',
#   'Daniel',
#   'Craig'],
#  ['Johnny',
#   'Depp',
#   'Paul',
#   'Bettany',
#   'Rebecca',
#   'Hall',
#   'Kate',
#   'Mara',
#   'Morgan',
#   'Freeman'],
#  ['Sam',
#   'Neill',
#   'William',
#   'H',
#   'Macy',
#   'Tuea',
#   'Leoni',
#   'Trevor',
#   'Morgan',
#   'Alessandro',
#   'Nivola'],
#  ['James',
#   'Franco',
#   'Freida',
#   'Pinto',
#   'John',
#   'Lithgow',
#   'Brian',
#   'Cox',
#   'Tom',
#   'Felton'],
#  ['Freddie',
#   'Highmore',
#   'MaryLouise',
#   'Parker',
#   'Nick',
#   'Nolte',
#   'Sarah',
#   'Bolger',
#   'Andrew',
#   'McCarthy'],
#  ['Bruce',
#   'Willis',
#   'Jai',
#   'Courtney',
#   'Sebastian',
#   'Koch',
#   'Mary',
#   'Elizabeth',
#   'Winstead',
#   'ueubuuf',
#   'uuduuuuuc'],
#  ['Dennis',
#   'Quaid',
#   'Billy',
#   'Bob',
#   'Thornton',
#   'Jason',
#   'Patric',
#   'Patrick',
#   'Wilson',
#   'Emilio',
#   'Echevarrueda'],
#  ['Craig',
#   'T',
#   'Nelson',
#   'Holly',
#   'Hunter',
#   'Samuel',
#   'L',
#   'Jackson',
#   'Jason',
#   'Lee',
#   'Dominique',
#   'Louis'],
#  ['Geena',
#   'Davis',
#   'Matthew',
#   'Modine',
#   'Frank',
#   'Langella',
#   'Maury',
#   'Chaykin',
#   'Patrick',
#   'Malahide'],
#  ['Logan',
#   'Lerman',
#   'Brandon',
#   'T',
#   'Jackson',
#   'Alexandra',
#   'Daddario',
#   'Jake',
#   'Abel',
#   'Sean',
#   'Bean'],
#  ['Tommy',
#   'Lee',
#   'Jones',
#   'Will',
#   'Smith',
#   'Linda',
#   'Fiorentino',
#   'Vincent',
#   'DOnofrio',
#   'Rip',
#   'Torn'],
#  ['Tom',
#   'Hanks',
#   'Tim',
#   'Allen',
#   'Joan',
#   'Cusack',
#   'Kelsey',
#   'Grammer',
#   'Don',
#   'Rickles'],
#  ['Denzel',
#   'Washington',
#   'Chris',
#   'Pine',
#   'Rosario',
#   'Dawson',
#   'Ethan',
#   'Suplee',
#   'Kevin',
#   'Corrigan'],
#  ['Chris',
#   'Tucker',
#   'Jackie',
#   'Chan',
#   'Zhang',
#   'Ziyi',
#   'Roselyn',
#   'Suenchez',
#   'Ernie',
#   'Reyes',
#   'Jr'],
#  ['Harrison',
#   'Ford',
#   'Michelle',
#   'Pfeiffer',
#   'Diana',
#   'Scarwid',
#   'James',
#   'Remar',
#   'Miranda',
#   'Otto'],
#  ['Bill',
#   'Hader',
#   'Anna',
#   'Faris',
#   'James',
#   'Caan',
#   'Mr',
#   'T',
#   'Benjamin',
#   'Bratt'],
#  ['Ray',
#   'Romano',
#   'John',
#   'Leguizamo',
#   'Denis',
#   'Leary',
#   'Queen',
#   'Latifah',
#   'Simon',
#   'Pegg'],
#  ['Ben',
#   'Stiller',
#   'Kristen',
#   'Wiig',
#   'Patton',
#   'Oswalt',
#   'Shirley',
#   'MacLaine',
#   'Adam',
#   'Scott'],
#  ['Cameron',
#   'Diaz',
#   'Lucy',
#   'Liu',
#   'Drew',
#   'Barrymore',
#   'Bill',
#   'Murray',
#   'John',
#   'Forsythe'],
#  ['Leonardo',
#   'DiCaprio',
#   'Matt',
#   'Damon',
#   'Jack',
#   'Nicholson',
#   'Mark',
#   'Wahlberg',
#   'Martin',
#   'Sheen'],
#  ['Eddie',
#   'Murphy',
#   'Jackie',
#   'Chan',
#   'MingNa',
#   'Wen',
#   'Lea',
#   'Salonga',
#   'June',
#   'Foray'],
#  ['Ben',
#   'Stiller',
#   'Jack',
#   'Black',
#   'Robert',
#   'Downey',
#   'Jr',
#   'Nick',
#   'Nolte',
#   'Steve',
#   'Coogan'],
#  ['Daniel',
#   'Craig',
#   'Rooney',
#   'Mara',
#   'Christopher',
#   'Plummer',
#   'Goran',
#   'Visnjic',
#   'Stellan',
#   'Skarsguerd'],
#  ['Bruce',
#   'Willis',
#   'Jeremy',
#   'Irons',
#   'Samuel',
#   'L',
#   'Jackson',
#   'Graham',
#   'Greene',
#   'Colleen',
#   'Camp'],
#  ['Robert',
#   'Downey',
#   'Jr',
#   'Jude',
#   'Law',
#   'Rachel',
#   'McAdams',
#   'Mark',
#   'Strong',
#   'Eddie',
#   'Marsan'],
#  ['Jack',
#   'Huston',
#   'Toby',
#   'Kebbell',
#   'Rodrigo',
#   'Santoro',
#   'Nazanin',
#   'Boniadi',
#   'Ayelet',
#   'Zurer'],
#  ['Michael',
#   'J',
#   'Fox',
#   'Corey',
#   'Burton',
#   'Claudia',
#   'Christian',
#   'James',
#   'Garner',
#   'John',
#   'Mahoney'],
#  ['Jason',
#   'Lee',
#   'Justin',
#   'Long',
#   'Bella',
#   'Thorne',
#   'Matthew',
#   'Gray',
#   'Gubler',
#   'Jesse',
#   'McCartney'],
#  ['Tom',
#   'Cruise',
#   'Carice',
#   'van',
#   'Houten',
#   'Kenneth',
#   'Branagh',
#   'Bill',
#   'Nighy',
#   'Terence',
#   'Stamp'],
#  ['Adam',
#   'Sandler',
#   'John',
#   'Turturro',
#   'Emmanuelle',
#   'Chriqui',
#   'Nick',
#   'Swardson',
#   'Lainie',
#   'Kazan'],
#  ['Adam',
#   'Sandler',
#   'Michelle',
#   'Monaghan',
#   'Peter',
#   'Dinklage',
#   'Josh',
#   'Gad',
#   'Kevin',
#   'James'],
#  ['Haley',
#   'Joel',
#   'Osment',
#   'Frances',
#   'OConnor',
#   'Sam',
#   'Robards',
#   'Jake',
#   'Thomas',
#   'Jude',
#   'Law'],
#  ['Eddie',
#   'Murphy',
#   'Terence',
#   'Stamp',
#   'Nathaniel',
#   'Parker',
#   'Marsha',
#   'Thomason',
#   'Jennifer',
#   'Tilly'],
#  ['Jodie',
#   'Foster',
#   'Matthew',
#   'McConaughey',
#   'James',
#   'Woods',
#   'John',
#   'Hurt',
#   'Tom',
#   'Skerritt'],
#  ['Kevin',
#   'Bacon',
#   'Elisabeth',
#   'Shue',
#   'Josh',
#   'Brolin',
#   'Kim',
#   'Dickens',
#   'Rhona',
#   'Mitra'],
#  ['Nicole',
#   'Kidman',
#   'Sean',
#   'Penn',
#   'Catherine',
#   'Keener',
#   'Jesper',
#   'Christensen',
#   'Yvan',
#   'Attal'],
#  ['Logan',
#   'Lerman',
#   'Alexandra',
#   'Daddario',
#   'Douglas',
#   'Smith',
#   'Leven',
#   'Rambin',
#   'Brandon',
#   'T',
#   'Jackson'],
#  ['Angelina',
#   'Jolie',
#   'Gerard',
#   'Butler',
#   'Noah',
#   'Taylor',
#   'Djimon',
#   'Hounsou',
#   'Til',
#   'Schweiger'],
#  ['Jesse',
#   'Eisenberg',
#   'Woody',
#   'Harrelson',
#   'Mark',
#   'Ruffalo',
#   'Dave',
#   'Franco',
#   'Morgan',
#   'Freeman'],
#  ['Val',
#   'Kilmer',
#   'Elisabeth',
#   'Shue',
#   'Rade',
#   'Serbedzija',
#   'Henry',
#   'Goodman',
#   'Alun',
#   'Armstrong'],
#  ['Robert',
#   'Redford',
#   'Brad',
#   'Pitt',
#   'Catherine',
#   'McCormack',
#   'Stephen',
#   'Dillane',
#   'Larry',
#   'Bryggman'],
#  ['Gary',
#   'Sinise',
#   'Tim',
#   'Robbins',
#   'Don',
#   'Cheadle',
#   'Connie',
#   'Nielsen',
#   'Jerry',
#   'OConnell'],
#  ['Jesse',
#   'Eisenberg',
#   'Anne',
#   'Hathaway',
#   'Leslie',
#   'Mann',
#   'Jane',
#   'Lynch',
#   'William'],
#  ['Robin',
#   'Williams',
#   'Sam',
#   'Neill',
#   'Embeth',
#   'Davidtz',
#   'Oliver',
#   'Platt',
#   'Kiersten',
#   'Warren'],
#  ['Tommy',
#   'Lee',
#   'Jones',
#   'Anne',
#   'Heche',
#   'Gaby',
#   'Hoffmann',
#   'Don',
#   'Cheadle',
#   'Joshua',
#   'Fardon'],
#  ['Harrison',
#   'Ford',
#   'Brad',
#   'Pitt',
#   'Margaret',
#   'Colin',
#   'Rubuen',
#   'Blades',
#   'Treat',
#   'Williams'],
#  ['Harrison',
#   'Ford',
#   'Liam',
#   'Neeson',
#   'Peter',
#   'Sarsgaard',
#   'Joss',
#   'Ackland',
#   'John',
#   'Shrapnel'],
#  ['Arnold',
#   'Schwarzenegger',
#   'James',
#   'Earl',
#   'Jones',
#   'Max',
#   'von',
#   'Sydow',
#   'Sandahl',
#   'Bergman',
#   'Cassandra',
#   'Gava'],
#  ['Russell',
#   'Crowe',
#   'Renuee',
#   'Zellweger',
#   'Paul',
#   'Giamatti',
#   'Craig',
#   'Bierko',
#   'Paddy',
#   'Considine'],
#  ['Elle',
#   'Fanning',
#   'Nathan',
#   'Lane',
#   'John',
#   'Turturro',
#   'Frances',
#   'de',
#   'la',
#   'Tour',
#   'Charlie',
#   'Rowe'],
#  ['Jeff',
#   'Bridges',
#   'David',
#   'McCullough',
#   'Chris',
#   'Cooper',
#   'Tobey',
#   'Maguire',
#   'Elizabeth',
#   'Banks'],
#  ['Helen',
#   'Hunt',
#   'Bill',
#   'Paxton',
#   'Cary',
#   'Elwes',
#   'Jami',
#   'Gertz',
#   'Philip',
#   'Seymour',
#   'Hoffman'],
#  ['Tom',
#   'Hanks',
#   'Helen',
#   'Hunt',
#   'Chris',
#   'Noth',
#   'Paul',
#   'Sanchez',
#   'Lari',
#   'White'],
#  ['Elijah',
#   'Wood',
#   'Robin',
#   'Williams',
#   'Brittany',
#   'Murphy',
#   'Hugh',
#   'Jackman',
#   'Nicole',
#   'Kidman'],
#  ['Matt',
#   'Damon',
#   'Franka',
#   'Potente',
#   'Brian',
#   'Cox',
#   'Julia',
#   'Stiles',
#   'Karl',
#   'Urban'],
#  ['Harrison',
#   'Ford',
#   'Gary',
#   'Oldman',
#   'Glenn',
#   'Close',
#   'Wendy',
#   'Crewson',
#   'William',
#   'H',
#   'Macy'],
#  ['George',
#   'Clooney',
#   'Brad',
#   'Pitt',
#   'Matt',
#   'Damon',
#   'Andy',
#   'Garcueda',
#   'Julia',
#   'Roberts'],
#  ['Milla',
#   'Jovovich',
#   'Orlando',
#   'Bloom',
#   'Logan',
#   'Lerman',
#   'Ray',
#   'Stevenson',
#   'Matthew',
#   'Macfadyen'],
#  ['Adam',
#   'Sandler',
#   'Steve',
#   'Buscemi',
#   'David',
#   'Spade',
#   'Kevin',
#   'James',
#   'Selena',
#   'Gomez'],
#  ['Amy',
#   'Adams',
#   'Patrick',
#   'Dempsey',
#   'James',
#   'Marsden',
#   'Timothy',
#   'Spall',
#   'Rachel',
#   'Covey'],
#  ['Denzel',
#   'Washington',
#   'Ryan',
#   'Reynolds',
#   'Vera',
#   'Farmiga',
#   'Joel',
#   'Kinnaman',
#   'Brendan',
#   'Gleeson'],
#  ['Glenn',
#   'Close',
#   'Ioan',
#   'Gruffudd',
#   'Alice',
#   'Evans',
#   'Tim',
#   'McInnerny',
#   'Guerard',
#   'Depardieu'],
#  ['Ben',
#   'Stiller',
#   'Eddie',
#   'Murphy',
#   'Casey',
#   'Affleck',
#   'Alan',
#   'Alda',
#   'Matthew',
#   'Broderick'],
#  ['Cameron',
#   'Diaz',
#   'Kate',
#   'Winslet',
#   'Jude',
#   'Law',
#   'Jack',
#   'Black',
#   'Eli',
#   'Wallach'],
#  ['Will',
#   'Smith',
#   'Gene',
#   'Hackman',
#   'Jon',
#   'Voight',
#   'Regina',
#   'King',
#   'Ian',
#   'Hart'],
# ...
#   'John',
#   'Benjamin',
#   'Hickey',
#   'John',
#   'Slattery'],
#  ['Jamie',
#   'Foxx',
#   'Gerard',
#   'Butler',
#   'Colm',
#   'Meaney',
#   'Bruce',
#   'McGill',
#   'Leslie',
#   'Bibb'],
#  ['Kurt',
#   'Russell',
#   'Zoueb',
#   'Bell',
#   'Rosario',
#   'Dawson',
#   'Vanessa',
#   'Ferlito',
#   'Sydney',
#   'Tamiia',
#   'Poitier'],
#  ['Oprah',
#   'Winfrey',
#   'Danny',
#   'Glover',
#   'Thandie',
#   'Newton',
#   'Lisa',
#   'Gay',
#   'Hamilton',
#   'Albert',
#   'Hall'],
#  ['Eric',
#   'Bana',
#   'Drew',
#   'Barrymore',
#   'Robert',
#   'Duvall',
#   'Debra',
#   'Messing',
#   'Robert',
#   'Downey',
#   'Jr'],
#  ['Leonardo',
#   'DiCaprio',
#   'Tom',
#   'Hanks',
#   'Christopher',
#   'Walken',
#   'Martin',
#   'Sheen',
#   'Nathalie',
#   'Baye'],
#  ['Jessica',
#   'Chastain',
#   'Jason',
#   'Clarke',
#   'Mark',
#   'Strong',
#   'Joel',
#   'Edgerton',
#   'Chris',
#   'Pratt'],
#  ['Vince',
#   'Vaughn',
#   'Jennifer',
#   'Aniston',
#   'Joey',
#   'Lauren',
#   'Adams',
#   'Cole',
#   'Hauser',
#   'Jon',
#   'Favreau'],
#  ['Meryl',
#   'Streep',
#   'Pierce',
#   'Brosnan',
#   'Amanda',
#   'Seyfried',
#   'Colin',
#   'Firth',
#   'Stellan',
#   'Skarsguerd'],
#  ['Jessica',
#   'Alba',
#   'Jessica',
#   'Biel',
#   'Bradley',
#   'Cooper',
#   'Eric',
#   'Dane',
#   'Patrick',
#   'Dempsey'],
#  ['Johnny',
#   'Knoxville',
#   'Seann',
#   'William',
#   'Scott',
#   'Jessica',
#   'Simpson',
#   'Willie',
#   'Nelson',
#   'Burt',
#   'Reynolds'],
#  ['Sean',
#   'Penn',
#   'Adrien',
#   'Brody',
#   'Jim',
#   'Caviezel',
#   'Ben',
#   'Chaplin',
#   'George',
#   'Clooney'],
#  ['Olivia',
#   'Wilde',
#   'Ryan',
#   'Reynolds',
#   'Jason',
#   'Bateman',
#   'Leslie',
#   'Mann',
#   'Mircea',
#   'Monroe'],
#  ['Jim',
#   'Carrey',
#   'Courtney',
#   'Love',
#   'Bob',
#   'Zmuda',
#   'Danny',
#   'DeVito',
#   'Gerry',
#   'Becker'],
#  ['Robert',
#   'De',
#   'Niro',
#   'Sharon',
#   'Stone',
#   'Joe',
#   'Pesci',
#   'James',
#   'Woods',
#   'Don',
#   'Rickles'],
#  ['John',
#   'Travolta',
#   'Jonathan',
#   'Rhys',
#   'Meyers',
#   'Kasia',
#   'Smutniak',
#   'Richard',
#   'Durden',
#   'Bing',
#   'Yin'],
#  ['Seann',
#   'William',
#   'Scott',
#   'Jaime',
#   'King',
#   'Karel',
#   'Roden',
#   'Chow',
#   'Yunfat',
#   'K',
#   'C',
#   'Collins'],
#  ['Jim',
#   'Carrey',
#   'Renuee',
#   'Zellweger',
#   'Anthony',
#   'Anderson',
#   'Robert',
#   'Forster',
#   'Richard',
#   'Jenkins'],
#  ['Courteney',
#   'Cox',
#   'Kevin',
#   'James',
#   'Sam',
#   'Elliott',
#   'Danny',
#   'Glover',
#   'Wanda',
#   'Sykes'],
#  ['Danny',
#   'DeVito',
#   'Matthew',
#   'Broderick',
#   'Kristin',
#   'Davis',
#   'Kristin',
#   'Chenoweth',
#   'Fred',
#   'Armisen'],
#  ['Kristen',
#   'Stewart',
#   'Robert',
#   'Pattinson',
#   'Taylor',
#   'Lautner',
#   'Billy',
#   'Burke',
#   'Ashley',
#   'Greene'],
#  ['Mike',
#   'Myers',
#   'Eddie',
#   'Murphy',
#   'Cameron',
#   'Diaz',
#   'John',
#   'Lithgow',
#   'Vincent',
#   'Cassel'],
#  ['Matt',
#   'Damon',
#   'Emily',
#   'Blunt',
#   'John',
#   'Slattery',
#   'Anthony',
#   'Mackie',
#   'Lauren',
#   'Hodges'],
#  ['Kevin',
#   'Costner',
#   'Morgan',
#   'Freeman',
#   'Christian',
#   'Slater',
#   'Mary',
#   'Elizabeth',
#   'Mastrantonio',
#   'Alan',
#   'Rickman'],
#  ['Tom',
#   'Cruise',
#   'Cuba',
#   'Gooding',
#   'Jr',
#   'Renuee',
#   'Zellweger',
#   'Kelly',
#   'Preston',
#   'Alison',
#   'Armitage'],
#  ['Mark',
#   'Wahlberg',
#   'Mila',
#   'Kunis',
#   'Seth',
#   'MacFarlane',
#   'Joel',
#   'McHale',
#   'Giovanni',
#   'Ribisi'],
#  ['Jack',
#   'Nicholson',
#   'Helen',
#   'Hunt',
#   'Greg',
#   'Kinnear',
#   'Cuba',
#   'Gooding',
#   'Jr',
#   'Skeet',
#   'Ulrich'],
#  ['Robin',
#   'Williams',
#   'Philip',
#   'Seymour',
#   'Hoffman',
#   'Bob',
#   'Gunton',
#   'Peter',
#   'Coyote',
#   'Michael',
#   'Jeter'],
#  ['Will',
#   'Ferrell',
#   'Steve',
#   'Carell',
#   'Paul',
#   'Rudd',
#   'Christina',
#   'Applegate',
#   'David',
#   'Koechner'],
#  ['Adam',
#   'Sandler',
#   'Winona',
#   'Ryder',
#   'John',
#   'Turturro',
#   'Allen',
#   'Covert',
#   'Peter',
#   'Gallagher'],
#  ['Joel',
#   'Courtney',
#   'Elle',
#   'Fanning',
#   'Riley',
#   'Griffiths',
#   'Kyle',
#   'Chandler',
#   'Ryan',
#   'Lee'],
#  ['Julia',
#   'Roberts',
#   'Albert',
#   'Finney',
#   'Aaron',
#   'Eckhart',
#   'Marg',
#   'Helgenberger',
#   'Cherry',
#   'Jones'],
#  ['Kate',
#   'Hudson',
#   'Matthew',
#   'McConaughey',
#   'Kathryn',
#   'Hahn',
#   'Annie',
#   'Parisse',
#   'Adam',
#   'Goldberg'],
#  ['Jonah',
#   'Hill',
#   'Channing',
#   'Tatum',
#   'Dave',
#   'Franco',
#   'Ice',
#   'Cube',
#   'Nick',
#   'Offerman'],
#  ['Brad',
#   'Pitt',
#   'Tom',
#   'Cruise',
#   'Kirsten',
#   'Dunst',
#   'Antonio',
#   'Banderas',
#   'Christian',
#   'Slater'],
#  ['Jim',
#   'Carrey',
#   'Zooey',
#   'Deschanel',
#   'Rhys',
#   'Darby',
#   'Sasha',
#   'Alexander',
#   'Fionnula',
#   'Flanagan'],
#  ['Dwayne',
#   'Johnson',
#   'Kevin',
#   'Hart',
#   'Amy',
#   'Ryan',
#   'Aaron',
#   'Paul',
#   'Danielle',
#   'Nicolet'],
#  ['Julia',
#   'Roberts',
#   'Susan',
#   'Sarandon',
#   'Ed',
#   'Harris',
#   'Jena',
#   'Malone',
#   'Liam',
#   'Aiken'],
#  ['Will',
#   'Ferrell',
#   'Mark',
#   'Wahlberg',
#   'Linda',
#   'Cardellini',
#   'Thomas',
#   'Haden',
#   'Church',
#   'Scarlett',
#   'Estevez'],
#  ['Meryl',
#   'Streep',
#   'Emily',
#   'Blunt',
#   'James',
#   'Corden',
#   'Anna',
#   'Kendrick',
#   'Chris',
#   'Pine'],
#  ['Denzel',
#   'Washington',
#   'Clive',
#   'Owen',
#   'Jodie',
#   'Foster',
#   'Christopher',
#   'Plummer',
#   'Willem',
#   'Dafoe'],
#  ['Mel',
#   'Gibson',
#   'Kris',
#   'Kristofferson',
#   'Gregg',
#   'Henry',
#   'Maria',
#   'Bello',
#   'David',
#   'Paymer'],
#  ['Laura',
#   'Linney',
#   'Dylan',
#   'Walsh',
#   'Ernie',
#   'Hudson',
#   'Tim',
#   'Curry',
#   'Grant',
#   'Heslov'],
#  ['Matt',
#   'Damon',
#   'Scarlett',
#   'Johansson',
#   'Thomas',
#   'Haden',
#   'Church',
#   'Colin',
#   'Ford',
#   'Maggie',
#   'Elizabeth',
#   'Jones'],
#  ['Nicolas',
#   'Cage',
#   'Rose',
#   'Byrne',
#   'Chandler',
#   'Canterbury',
#   'Ben',
#   'Mendelsohn',
#   'Nadia',
#   'Townsend'],
#  ['Matthew',
#   'McConaughey',
#   'Sarah',
#   'Jessica',
#   'Parker',
#   'Zooey',
#   'Deschanel',
#   'Justin',
#   'Bartha',
#   'Bradley',
#   'Cooper'],
#  ['Naomi',
#   'Watts',
#   'Simon',
#   'Baker',
#   'Elizabeth',
#   'Perkins',
#   'David',
#   'Dorfman',
#   'Gary',
#   'Cole'],
#  ['Steve',
#   'Carell',
#   'Julianne',
#   'Moore',
#   'Ryan',
#   'Gosling',
#   'Emma',
#   'Stone',
#   'Marisa',
#   'Tomei'],
#  ['Bill',
#   'Murray',
#   'Breckin',
#   'Meyer',
#   'Jennifer',
#   'Love',
#   'Hewitt',
#   'Stephen',
#   'Tobolowsky',
#   'Evan',
#   'Arnold'],
#  ['Tim',
#   'Allen',
#   'Jamie',
#   'Lee',
#   'Curtis',
#   'Dan',
#   'Aykroyd',
#   'M',
#   'Emmet',
#   'Walsh',
#   'Elizabeth',
#   'Franz'],
#  ['Brad',
#   'Pitt',
#   'Jonah',
#   'Hill',
#   'Philip',
#   'Seymour',
#   'Hoffman',
#   'Robin',
#   'Wright',
#   'Chris',
#   'Pratt'],
#  ['Dustin',
#   'Hoffman',
#   'Rene',
#   'Russo',
#   'Morgan',
#   'Freeman',
#   'Kevin',
#   'Spacey',
#   'Cuba',
#   'Gooding',
#   'Jr'],
#  ['Liam',
#   'Neeson',
#   'Julianne',
#   'Moore',
#   'Scoot',
#   'McNairy',
#   'Michelle',
#   'Dockery',
#   'Nate',
#   'Parker'],
#  ['Dwayne',
#   'Johnson',
#   'AnnaSophia',
#   'Robb',
#   'Alexander',
#   'Ludwig',
#   'Carla',
#   'Gugino',
#   'Chris',
#   'Marquette'],
#  ['Natalie',
#   'Portman',
#   'Hugo',
#   'Weaving',
#   'Stephen',
#   'Rea',
#   'Stephen',
#   'Fry',
#   'John',
#   'Hurt'],
#  ['Jackie',
#   'Chan',
#   'Owen',
#   'Wilson',
#   'Fann',
#   'Wong',
#   'Aaron',
#   'TaylorJohnson',
#   'Aidan',
#   'Gillen'],
#  ['Will',
#   'Ferrell',
#   'Drew',
#   'Barrymore',
#   'David',
#   'Cross',
#   'Eugene',
#   'Levy',
#   'Dick',
#   'Van',
#   'Dyke'],
#  ['Lindsay',
#   'Lohan',
#   'Michael',
#   'Keaton',
#   'Matt',
#   'Dillon',
#   'Breckin',
#   'Meyer',
#   'Justin',
#   'Long'],
#  ['Michael',
#   'Douglas',
#   'Sean',
#   'Bean',
#   'Brittany',
#   'Murphy',
#   'Skye',
#   'McCole',
#   'Bartusiak',
#   'Guy',
#   'Torry'],
#  ['Jeremy',
#   'Renner',
#   'Gemma',
#   'Arterton',
#   'Famke',
#   'Janssen',
#   'Pihla',
#   'Viitala',
#   'Derek',
#   'Mears'],
#  ['Richard',
#   'Gere',
#   'Diane',
#   'Lane',
#   'Olivier',
#   'Martinez',
#   'Erik',
#   'Per',
#   'Sullivan',
#   'Zeljko',
#   'Ivanek'],
#  ['Alex',
#   'Pettyfer',
#   'Timothy',
#   'Olyphant',
#   'Teresa',
#   'Palmer',
#   'Dianna',
#   'Agron',
#   'Callan',
#   'McAuliffe'],
#  ['George',
#   'Clooney',
#   'Matt',
#   'Damon',
#   'Jeffrey',
#   'Wright',
#   'Chris',
#   'Cooper',
#   'Amanda',
#   'Peet'],
#  ['James',
#   'Badge',
#   'Dale',
#   'John',
#   'Krasinski',
#   'Max',
#   'Martini',
#   'Pablo',
#   'Schreiber',
#   'Toby',
#   'Stephens'],
#  ['Diego',
#   'Luna',
#   'Channing',
#   'Tatum',
#   'Zoe',
#   'Saldana',
#   'Christina',
#   'Applegate',
#   'Eugenio',
#   'Derbez'],
#  ['Harrison',
#   'Ford',
#   'Paul',
#   'Bettany',
#   'Virginia',
#   'Madsen',
#   'Carly',
#   'Schroeder',
#   'Jimmy',
#   'Bennett'],
#  ['Clint',
#   'Eastwood',
#   'Gene',
#   'Hackman',
#   'Ed',
#   'Harris',
#   'Scott',
#   'Glenn',
#   'Laura',
#   'Linney'],
#  ['Demi',
#   'Moore',
#   'Viggo',
#   'Mortensen',
#   'Anne',
#   'Bancroft',
#   'Jason',
#   'Beghe',
#   'Daniel',
#   'von',
#   'Bargen'],
#  ['Michael',
#   'Douglas',
#   'Sean',
#   'Penn',
#   'Deborah',
#   'Kara',
#   'Unger',
#   'James',
#   'Rebhorn',
#   'Spike',
#   'Jonze'],
#  ['Radha',
#   'Mitchell',
#   'Sean',
#   'Bean',
#   'Laurie',
#   'Holden',
#   'Deborah',
#   'Kara',
#   'Unger',
#   'Kim',
#   'Coates'],
#  ['Keanu',
#   'Reeves',
#   'Gene',
#   'Hackman',
#   'Brooke',
#   'Langton',
#   'Orlando',
#   'Jones',
#   'Faizon',
#   'Love'],
#  ['Jason',
#   'Biggs',
#   'Alyson',
#   'Hannigan',
#   'Seann',
#   'William',
#   'Scott',
#   'Chris',
#   'Klein',
#   'Thomas',
#   'Ian',
#   'Nicholas'],
#  ['Samuel',
#   'L',
#   'Jackson',
#   'Kevin',
#   'Spacey',
#   'David',
#   'Morse',
#   'Ron',
#   'Rifkin',
#   'John',
#   'Spencer'],
#  ['Richard',
#   'Armitage',
#   'Sarah',
#   'Wayne',
#   'Callies',
#   'Matt',
#   'Walsh',
#   'Nathan',
#   'Kress',
#   'Alycia',
#   'DebnamCarey'],
#  ['Eddie',
#   'Murphy',
#   'Judge',
#   'Reinhold',
#   'Huector',
#   'Elizondo',
#   'Gilbert',
#   'R',
#   'Hill',
#   'Timothy',
#   'Carhart'],
#  ['Zach',
#   'Galligan',
#   'Phoebe',
#   'Cates',
#   'John',
#   'Glover',
#   'Robert',
#   'Prosky',
#   'Robert',
#   'Picardo'],
#  ['Robert',
#   'Duvall',
#   'Robert',
#   'Downey',
#   'Jr',
#   'Vera',
#   'Farmiga',
#   'Vincent',
#   'DOnofrio',
#   'Jeremy',
#   'Strong'],
#  ['George',
#   'Clooney',
#   'Nicole',
#   'Kidman',
#   'Marcel',
#   'Iureu',
#   'Goran',
#   'Visnjic',
#   'Armin',
#   'MuellerStahl'],
#  ['Milla',
#   'Jovovich',
#   'Sienna',
#   'Guillory',
#   'Oded',
#   'Fehr',
#   'Thomas',
#   'Kretschmann',
#   'Sophie',
#   'Vavasseur'],
#  ['Renuee',
#   'Zellweger',
#   'Hugh',
#   'Grant',
#   'Colin',
#   'Firth',
#   'Jim',
#   'Broadbent',
#   'Gemma',
#   'Jones'],
#  ['Denzel',
#   'Washington',
#   'Eva',
#   'Mendes',
#   'Sanaa',
#   'Lathan',
#   'John',
#   'Billingsley',
#   'Dean',
#   'Cain'],
#  ['Steven',
#   'Seagal',
#   'Michael',
#   'Caine',
#   'Joan',
#   'Chen',
#   'John',
#   'C',
#   'McGinley',
#   'R',
#   'Lee',
#   'Ermey'],
#  ['Taylor',
#   'Lautner',
#   'Taylor',
#   'Dooley',
#   'Cayden',
#   'Boyd',
#   'David',
#   'Arquette',
#   'Kristin',
#   'Davis'],
#  ['Leonardo',
#   'DiCaprio',
#   'Guillaume',
#   'Canet',
#   'Tilda',
#   'Swinton',
#   'Virginie',
#   'Ledoyen',
#   'Staffan',
#   'Kihlbom'],
#  ['Kate',
#   'Hudson',
#   'John',
#   'Corbett',
#   'Joan',
#   'Cusack',
#   'Hayden',
#   'Panettiere',
#   'Spencer',
#   'Breslin'],
#  ['Rain',
#   'Naomie',
#   'Harris',
#   'Sung',
#   'Kang',
#   'Randall',
#   'Duk',
#   'Kim',
#   'Rick',
#   'Yune'],
#  ['Kevin',
#   'Costner',
#   'Kelly',
#   'Preston',
#   'John',
#   'C',
#   'Reilly',
#   'Jena',
#   'Malone',
#   'JK',
#   'Simmons'],
#  ['Demi',
#   'Moore',
#   'Burt',
#   'Reynolds',
#   'Armand',
#   'Assante',
#   'Ving',
#   'Rhames',
#   'Robert',
#   'Patrick'],
#  ['Owen',
#   'Wilson',
#   'Emma',
#   'Stone',
#   'George',
#   'Lopez',
#   'Christopher',
#   'MintzPlasse',
#   'Steve',
#   'Coogan'],
#  ['Matt',
#   'Damon',
#   'Bryce',
#   'Dallas',
#   'Howard',
#   'George',
#   'McLaren',
#   'Thierry',
#   'Neuvic',
#   'Cyndi',
#   'Mayo',
#   'Davis'],
#  ['Sandra',
#   'Bullock',
#   'Ben',
#   'Chaplin',
#   'Ryan',
#   'Gosling',
#   'Michael',
#   'Pitt',
#   'Agnes',
#   'Bruckner'],
#  ['Sylvester',
#   'Stallone',
#   'Antonio',
#   'Banderas',
#   'Julianne',
#   'Moore',
#   'Anatoli',
#   'Davydov',
#   'Muse',
#   'Watson'],
#  ['Gaspard',
#   'Ulliel',
#   'Aaran',
#   'Thomas',
#   'Gong',
#   'Li',
#   'Dominic',
#   'West',
#   'Rhys',
#   'Ifans'],
#  ['Bruce',
#   'Willis',
#   'Michelle',
#   'Pfeiffer',
#   'Rob',
#   'Reiner',
#   'Colleen',
#   'Rennison',
#   'Jake',
#   'Sandvig'],
#  ['Saoirse',
#   'Ronan',
#   'Diane',
#   'Kruger',
#   'Jake',
#   'Abel',
#   'William',
#   'Hurt',
#   'Frances',
#   'Fisher'],
#  ['John',
#   'Travolta',
#   'Connie',
#   'Nielsen',
#   'Samuel',
#   'L',
#   'Jackson',
#   'Giovanni',
#   'Ribisi',
#   'Tim',
#   'Daly'],
#  ['Clint',
#   'Eastwood',
#   'Jeff',
#   'Daniels',
#   'Anjelica',
#   'Huston',
#   'Wanda',
#   'De',
#   'Jesus',
#   'Tina',
#   'Lifford'],
#  ['Clive',
#   'Owen',
#   'Naomi',
#   'Watts',
#   'Armin',
#   'MuellerStahl',
#   'Ulrich',
#   'Thomsen',
#   'Bruedan',
#   'F',
#   'OByrne'],
#  ['Kurt',
#   'Russell',
#   'Stacy',
#   'Keach',
#   'Steve',
#   'Buscemi',
#   'Pam',
#   'Grier',
#   'Cliff',
#   'Robertson'],
#  ['Eli',
#   'Marienthal',
#   'Jennifer',
#   'Aniston',
#   'Vin',
#   'Diesel',
#   'Christopher',
#   'McDonald',
#   'Harry',
#   'Connick',
#   'Jr'],
#  ['Bill',
#   'Murray',
#   'Anjelica',
#   'Huston',
#   'Cate',
#   'Blanchett',
#   'Willem',
#   'Dafoe',
#   'Owen',
#   'Wilson'],
#  ['Matthew',
#   'McConaughey',
#   'Gugu',
#   'MbathaRaw',
#   'Mahershala',
#   'Ali',
#   'Keri',
#   'Russell',
#   'Jacob',
#   'Lofland'],
#  ['Kevin',
#   'Spacey',
#   'Kate',
#   'Winslet',
#   'Laura',
#   'Linney',
#   'Gabriel',
#   'Mann',
#   'Rhona',
#   'Mitra'],
#  ['Tommy',
#   'Lee',
#   'Jones',
#   'Cedric',
#   'the',
#   'Entertainer',
#   'Christina',
#   'Milian',
#   'Paula',
#   'Garcues',
#   'Monica',
#   'Keena'],
#  ['Liam',
#   'Neeson',
#   'Ed',
#   'Harris',
#   'Joel',
#   'Kinnaman',
#   'Boyd',
#   'Holbrook',
#   'Bruce',
#   'McGill'],
#  ['Naomi',
#   'Watts',
#   'Viggo',
#   'Mortensen',
#   'Vincent',
#   'Cassel',
#   'Armin',
#   'MuellerStahl',
#   'Sinuead',
#   'Cusack'],
#  ['Paul',
#   'Walker',
#   'Jessica',
#   'Alba',
#   'Scott',
#   'Caan',
#   'Ashley',
#   'Scott',
#   'Josh',
#   'Brolin'],
#  ['Danny',
#   'McBride',
#   'James',
#   'Franco',
#   'Natalie',
#   'Portman',
#   'Zooey',
#   'Deschanel',
#   'Justin',
#   'Theroux'],
#  ['Daniel',
#   'Craig',
#   'Naomi',
#   'Watts',
#   'Rachel',
#   'Weisz',
#   'Marton',
#   'Csokas',
#   'Elias',
#   'Koteas'],
#  ['John',
#   'Travolta',
#   'Dustin',
#   'Hoffman',
#   'Mia',
#   'Kirshner',
#   'Alan',
#   'Alda',
#   'Robert',
#   'Prosky'],
#  ['Joe',
#   'Mantegna',
#   'Lara',
#   'Flynn',
#   'Boyle',
#   'Joe',
#   'Pantoliano',
#   'Brian',
#   'Haley',
#   'Cynthia',
#   'Nixon'],
#  ['Demi',
#   'Moore',
#   'Gary',
#   'Oldman',
#   'Robert',
#   'Duvall',
#   'Robert',
#   'Prosky',
#   'Edward',
#   'Hardwicke'],
#  ['Naomi',
#   'Watts',
#   'Sean',
#   'Penn',
#   'Ty',
#   'Burrell',
#   'Brooke',
#   'Smith',
#   'Bruce',
#   'McGill'],
#  ['Keira',
#   'Knightley',
#   'Mickey',
#   'Rourke',
#   'Edgar',
#   'Ramuedrez',
#   'Delroy',
#   'Lindo',
#   'MoNique'],
#  ['David',
#   'Caruso',
#   'Linda',
#   'Fiorentino',
#   'Chazz',
#   'Palminteri',
#   'Michael',
#   'Biehn',
#   'Richard',
#   'Crenna'],
#  ['Gerard',
#   'Butler',
#   'Michael',
#   'C',
#   'Hall',
#   'Logan',
#   'Lerman',
#   'Amber',
#   'Valletta',
#   'Terry',
#   'Crews'],
#  ['Alden',
#   'Ehrenreich',
#   'Alice',
#   'Englert',
#   'Jeremy',
#   'Irons',
#   'Viola',
#   'Davis',
#   'Emmy',
#   'Rossum'],
#  ['Robin',
#   'Williams',
#   'Catherine',
#   'Keener',
#   'Edward',
#   'Norton',
#   'Danny',
#   'DeVito',
#   'Jon',
#   'Stewart'],
#  ['Ben',
#   'Stiller',
#   'Owen',
#   'Wilson',
#   'Will',
#   'Ferrell',
#   'Penuelope',
#   'Cruz',
#   'Kristen',
#   'Wiig'],
#  ['Owen',
#   'Wilson',
#   'Morgan',
#   'Freeman',
#   'Gary',
#   'Sinise',
#   'Sara',
#   'Foster',
#   'Willie',
#   'Nelson'],
#  ['Garry',
#   'Shandling',
#   'Annette',
#   'Bening',
#   'John',
#   'Goodman',
#   'Greg',
#   'Kinnear',
#   'Linda',
#   'Fiorentino'],
#  ['Nicolas',
#   'Cage',
#   'Amber',
#   'Heard',
#   'William',
#   'Fichtner',
#   'Billy',
#   'Burke',
#   'David',
#   'Morse'],
#  ['Kristin',
#   'Kreuk',
#   'Chris',
#   'Klein',
#   'Neal',
#   'McDonough',
#   'Michael',
#   'Clarke',
#   'Duncan',
#   'Moon',
#   'Bloodgood'],
#  ['Jet',
#   'Li',
#   'Jason',
#   'Statham',
#   'Carla',
#   'Gugino',
#   'Delroy',
#   'Lindo',
#   'James',
#   'Morrison'],
#  ['Andrew',
#   'Dice',
#   'Clay',
#   'Wayne',
#   'Newton',
#   'Priscilla',
#   'Presley',
#   'Morris',
#   'Day',
#   'Lauren',
#   'Holly'],
#  ['Tom',
#   'Sturridge',
#   'Philip',
#   'Seymour',
#   'Hoffman',
#   'Rhys',
#   'Ifans',
#   'Bill',
#   'Nighy',
#   'Emma',
#   'Thompson'],
#  ['Michael',
#   'Douglas',
#   'Benicio',
#   'del',
#   'Toro',
#   'Jacob',
#   'Vargas',
#   'Tomues',
#   'Miliuen',
#   'Russell',
#   'G',
#   'Jones'],
#  ['Harrison',
#   'Ford',
#   'Sean',
#   'Connery',
#   'Denholm',
#   'Elliott',
#   'Alison',
#   'Doody',
#   'John',
#   'RhysDavies'],
#  ['Keira',
#   'Knightley',
#   'Jude',
#   'Law',
#   'Aaron',
#   'TaylorJohnson',
#   'Kelly',
#   'Macdonald',
#   'Matthew',
#   'Macfadyen'],
#  ['Sharlto',
#   'Copley',
#   'Dev',
#   'Patel',
#   'Ninja',
#   'Yolandi',
#   'Visser',
#   'Jose',
#   'Pablo',
#   'Cantillo'],
#  ...]

# %%
# Replace old cast column with new move
movies['cast'] = cleaned_names

# %% [markdown]
# ### **Budget**

# %%
# Preview column budget
movies['budget']
# Out:
# original_title
# Avatar                                      237000000
# Pirates of the Caribbean: At World's End    300000000
# Spectre                                     245000000
# The Dark Knight Rises                       250000000
# John Carter                                 260000000
#                                               ...
# Bang                                                0
# Primer                                           7000
# Newlyweds                                        9000
# Signed, Sealed, Delivered                           0
# My Date with Drew                                   0
# Name: budget, Length: 4445, dtype: int64

# %% [markdown]
# The data in this column is difficult to read due to the lack of `,` seperators. Let's assume the data is in American dollars as well.
#
# Some of these values are for `$0` -- are these movies created by studios in a kind of pro bono fashion, or do the `$0` values represent missing data?

# %%
movies[movies['budget'] == 0].shape
# Out:
# (874, 31)

# %% [markdown]
# As it turns out, `1037` of the values in the `budget` column are `$0`.
#
# These scenarios aren't ideal. One idea is to drop this column entirely from the dataset, but I think a film's `budget` would be a good prediction factor to include in the recommendation engine. For example, some people might prefer blockbuster movies with blockbuster budgets, while other people prefer indie movies that with modest budgets.
#
# There are several tactics for tackling this problem. For this particular column, I'm going to fill in all of the missing values with the `mean` value of all the budget amounts in the dataset that are not equal to zero.

# %%
"${:,.2f}".format(round(sum(movies[movies['budget'] != 0]['budget']) / len(movies[movies['budget'] != 0]['budget']), 
                 2))
# Out:
# '$38,341,022.04'

# %% [markdown]
# The average budget for a movie in this daatset is `$37,042,837.63`. We'll now use this value to replace all the `$0s` in this dataset within the `budget` column.

# %%
# Assign average budget to a variable
mean_budget = sum(movies[movies['budget'] != 0]['budget']) / len(movies[movies['budget'] != 0]['budget'])

# Define a function to take in a dataframe
def replace_0_budget(df):
    
    # Create an empty list that will be the new column
    new_budget_column = []
    
    # Begin for loop
    for i in df['budget']:
        
        # If budget doesn't equal 0
        if i != 0:
            
            # Append existing value to empty list
            new_budget_column.append(i)
        
        # If budget is equal to zero
        else:
            
            # Append average budget to new column instead of 0
            new_budget_column.append(mean_budget)
    
    # Replace old column with new column
    df['budget'] = new_budget_column        
    
    # Return dataframe
    return df

# Call function on the movies dataframe
replace_0_budget(movies)
# Out:
#                                                 budget release_date  \
# original_title
# Avatar                                    2.370000e+08   2009-12-10
# Pirates of the Caribbean: At World's End  3.000000e+08   2007-05-19
# Spectre                                   2.450000e+08   2015-10-26
# The Dark Knight Rises                     2.500000e+08   2012-07-16
# John Carter                               2.600000e+08   2012-03-07
# ...                                                ...          ...
# Bang                                      3.834102e+07   1995-09-09
# Primer                                    7.000000e+03   2004-10-08
# Newlyweds                                 9.000000e+03   2011-12-26
# Signed, Sealed, Delivered                 3.834102e+07   2013-10-13
# My Date with Drew                         3.834102e+07   2005-08-05
#
#                                              revenue  runtime    status  \
# original_title
# Avatar                                    2787965087    162.0  Released
# Pirates of the Caribbean: At World's End   961000000    169.0  Released
# Spectre                                    880674609    148.0  Released
# The Dark Knight Rises                     1084939099    165.0  Released
# John Carter                                284139100    132.0  Released
# ...                                              ...      ...       ...
# Bang                                               0     98.0  Released
# Primer                                        424760     77.0  Released
# Newlyweds                                          0     85.0  Released
# Signed, Sealed, Delivered                          0    120.0  Released
# My Date with Drew                                  0     90.0  Released
#
#                                           vote_average  vote_count  \
# original_title
# Avatar                                             7.2       11800
# Pirates of the Caribbean: At World's End           6.9        4500
# Spectre                                            6.3        4466
# The Dark Knight Rises                              7.6        9106
# John Carter                                        6.1        2124
# ...                                                ...         ...
# Bang                                               6.0           1
# Primer                                             6.9         658
# Newlyweds                                          5.9           5
# Signed, Sealed, Delivered                          7.0           6
# My Date with Drew                                  6.3          16
#
#                                                                                        cast  \
# original_title
# Avatar                                    [Sam, Worthington, Zoe, Saldana, Sigourney, We...
# Pirates of the Caribbean: At World's End  [Johnny, Depp, Orlando, Bloom, Keira, Knightle...
# Spectre                                   [Daniel, Craig, Christoph, Waltz, Luea, Seydou...
# The Dark Knight Rises                     [Christian, Bale, Michael, Caine, Gary, Oldman...
# John Carter                               [Taylor, Kitsch, Lynn, Collins, Samantha, Mort...
# ...                                                                                     ...
# Bang                                      [Darling, Narita, Peter, Greene, Michael, Newl...
# Primer                                    [Shane, Carruth, David, Sullivan, Casey, Goode...
# Newlyweds                                 [Edward, Burns, Kerry, Bishue, Marsha, Dietlei...
# Signed, Sealed, Delivered                 [Eric, Mabius, Kristin, Booth, Crystal, Lowe, ...
# My Date with Drew                         [Drew, Barrymore, Brian, Herzlinger, Corey, Fe...
#
#                                                                                        crew  \
# original_title
# Avatar                                    [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...
# Pirates of the Caribbean: At World's End  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...
# Spectre                                   [{'name': 'Thomas Newman', 'gender': 2, 'depar...
# The Dark Knight Rises                     [{'name': 'Hans Zimmer', 'gender': 2, 'departm...
# John Carter                               [{'name': 'Andrew Stanton', 'gender': 2, 'depa...
# ...                                                                                     ...
# Bang                                      [{'name': 'Ash Baron-Cohen', 'gender': 0, 'dep...
# Primer                                    [{'name': 'Shane Carruth', 'gender': 2, 'depar...
# Newlyweds                                 [{'name': 'Edward Burns', 'gender': 2, 'depart...
# Signed, Sealed, Delivered                 [{'name': 'Carla Hetland', 'gender': 0, 'depar...
# My Date with Drew                         [{'name': 'Clark Peterson', 'gender': 2, 'depa...
#
#                                                    director  ...  Romance  \
# original_title                                               ...
# Avatar                                        James Cameron  ...        0
# Pirates of the Caribbean: At World's End     Gore Verbinski  ...        0
# Spectre                                          Sam Mendes  ...        0
# The Dark Knight Rises                     Christopher Nolan  ...        0
# John Carter                                  Andrew Stanton  ...        0
# ...                                                     ...  ...      ...
# Bang                                        Ash Baron-Cohen  ...        0
# Primer                                        Shane Carruth  ...        0
# Newlyweds                                      Edward Burns  ...        1
# Signed, Sealed, Delivered                       Scott Smith  ...        1
# My Date with Drew                          Brian Herzlinger  ...        0
#
#                                           Horror  Mystery  History  War  \
# original_title
# Avatar                                         0        0        0    0
# Pirates of the Caribbean: At World's End       0        0        0    0
# Spectre                                        0        0        0    0
# The Dark Knight Rises                          0        0        0    0
# John Carter                                    0        0        0    0
# ...                                          ...      ...      ...  ...
# Bang                                           0        0        0    0
# Primer                                         0        0        0    0
# Newlyweds                                      0        0        0    0
# Signed, Sealed, Delivered                      0        0        0    0
# My Date with Drew                              0        0        0    0
#
#                                           Music  Documentary  Foreign  TV  \
# original_title
# Avatar                                        0            0        0   0
# Pirates of the Caribbean: At World's End      0            0        0   0
# Spectre                                       0            0        0   0
# The Dark Knight Rises                         0            0        0   0
# John Carter                                   0            0        0   0
# ...                                         ...          ...      ...  ..
# Bang                                          0            0        0   0
# Primer                                        0            0        0   0
# Newlyweds                                     0            0        0   0
# Signed, Sealed, Delivered                     0            0        0   1
# My Date with Drew                             0            1        0   0
#
#                                                                                    overview
# original_title
# Avatar                                    [in, the, 22nd, century, a, paraplegic, marine...
# Pirates of the Caribbean: At World's End  [captain, barbossa, long, believed, to, be, de...
# Spectre                                   [a, cryptic, message, from, bond, s, past, sen...
# The Dark Knight Rises                     [following, the, death, of, district, attorney...
# John Carter                               [john, carter, is, a, war, weary, former, mili...
# ...                                                                                     ...
# Bang                                      [a, young, woman, in, l, a, is, having, a, bad...
# Primer                                    [friend, fledgling, entrepreneur, invent, a, d...
# Newlyweds                                 [a, newlywed, couple, s, honeymoon, is, upende...
# Signed, Sealed, Delivered                 [signed, sealed, delivered, introduces, a, ded...
# My Date with Drew                         [ever, since, the, second, grade, when, he, fi...
#
# [4445 rows x 31 columns]

# %%
movies[movies['budget'] == 0].shape
# Out:
# (0, 31)

# %% [markdown]
# Huzzah!! All movies with a `$0` budget have now had their value in the dataset changed to the average budget of all budgets in the dataset.

# %% [markdown]
# ### **Revenue**

# %%
movies[['revenue']]
# Out:
#                                              revenue
# original_title
# Avatar                                    2787965087
# Pirates of the Caribbean: At World's End   961000000
# Spectre                                    880674609
# The Dark Knight Rises                     1084939099
# John Carter                                284139100
# ...                                              ...
# Bang                                               0
# Primer                                        424760
# Newlyweds                                          0
# Signed, Sealed, Delivered                          0
# My Date with Drew                                  0
#
# [4445 rows x 1 columns]

# %% [markdown]
# The values in this column are a little hard to read without any comma seperators.
#
# It looks like some movies have made `$0` in revenue, which is difficult to believe. How many movies in our dataframe have posted `$0` in revenue?

# %%
movies[movies['revenue'] == 0].shape
# Out:
# (1216, 31)

# %% [markdown]
# Hmmm, so `1,244` movies haven't made a dime? This seems highly implausible.

# %%
"${:,.2f}".format(round(sum(movies[movies['revenue'] != 0]['revenue']) / len(movies[movies['revenue'] != 0]['revenue']), 
                 2))
# Out:
# '$120,640,826.68'

# %% [markdown]
# The average amount of revenue earned by a movie in this daatset is `$120,540,082.02`. We'll now use this value to replace all the `$0s` in this dataset within the `revenue` column.

# %%
mean_revenue = sum(movies[movies['revenue'] != 0]['revenue']) / len(movies[movies['revenue'] != 0]['revenue'])

def replace_0_revenue(df):
    new_revenue_column = []
    for i in df['revenue']:
        if i != 0:
            new_revenue_column.append(i)
        else:
            new_revenue_column.append(mean_revenue)
    df['revenue'] = new_revenue_column        
    return df

replace_0_revenue(movies)
# Out:
#                                                 budget release_date  \
# original_title
# Avatar                                    2.370000e+08   2009-12-10
# Pirates of the Caribbean: At World's End  3.000000e+08   2007-05-19
# Spectre                                   2.450000e+08   2015-10-26
# The Dark Knight Rises                     2.500000e+08   2012-07-16
# John Carter                               2.600000e+08   2012-03-07
# ...                                                ...          ...
# Bang                                      3.834102e+07   1995-09-09
# Primer                                    7.000000e+03   2004-10-08
# Newlyweds                                 9.000000e+03   2011-12-26
# Signed, Sealed, Delivered                 3.834102e+07   2013-10-13
# My Date with Drew                         3.834102e+07   2005-08-05
#
#                                                revenue  runtime    status  \
# original_title
# Avatar                                    2.787965e+09    162.0  Released
# Pirates of the Caribbean: At World's End  9.610000e+08    169.0  Released
# Spectre                                   8.806746e+08    148.0  Released
# The Dark Knight Rises                     1.084939e+09    165.0  Released
# John Carter                               2.841391e+08    132.0  Released
# ...                                                ...      ...       ...
# Bang                                      1.206408e+08     98.0  Released
# Primer                                    4.247600e+05     77.0  Released
# Newlyweds                                 1.206408e+08     85.0  Released
# Signed, Sealed, Delivered                 1.206408e+08    120.0  Released
# My Date with Drew                         1.206408e+08     90.0  Released
#
#                                           vote_average  vote_count  \
# original_title
# Avatar                                             7.2       11800
# Pirates of the Caribbean: At World's End           6.9        4500
# Spectre                                            6.3        4466
# The Dark Knight Rises                              7.6        9106
# John Carter                                        6.1        2124
# ...                                                ...         ...
# Bang                                               6.0           1
# Primer                                             6.9         658
# Newlyweds                                          5.9           5
# Signed, Sealed, Delivered                          7.0           6
# My Date with Drew                                  6.3          16
#
#                                                                                        cast  \
# original_title
# Avatar                                    [Sam, Worthington, Zoe, Saldana, Sigourney, We...
# Pirates of the Caribbean: At World's End  [Johnny, Depp, Orlando, Bloom, Keira, Knightle...
# Spectre                                   [Daniel, Craig, Christoph, Waltz, Luea, Seydou...
# The Dark Knight Rises                     [Christian, Bale, Michael, Caine, Gary, Oldman...
# John Carter                               [Taylor, Kitsch, Lynn, Collins, Samantha, Mort...
# ...                                                                                     ...
# Bang                                      [Darling, Narita, Peter, Greene, Michael, Newl...
# Primer                                    [Shane, Carruth, David, Sullivan, Casey, Goode...
# Newlyweds                                 [Edward, Burns, Kerry, Bishue, Marsha, Dietlei...
# Signed, Sealed, Delivered                 [Eric, Mabius, Kristin, Booth, Crystal, Lowe, ...
# My Date with Drew                         [Drew, Barrymore, Brian, Herzlinger, Corey, Fe...
#
#                                                                                        crew  \
# original_title
# Avatar                                    [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...
# Pirates of the Caribbean: At World's End  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...
# Spectre                                   [{'name': 'Thomas Newman', 'gender': 2, 'depar...
# The Dark Knight Rises                     [{'name': 'Hans Zimmer', 'gender': 2, 'departm...
# John Carter                               [{'name': 'Andrew Stanton', 'gender': 2, 'depa...
# ...                                                                                     ...
# Bang                                      [{'name': 'Ash Baron-Cohen', 'gender': 0, 'dep...
# Primer                                    [{'name': 'Shane Carruth', 'gender': 2, 'depar...
# Newlyweds                                 [{'name': 'Edward Burns', 'gender': 2, 'depart...
# Signed, Sealed, Delivered                 [{'name': 'Carla Hetland', 'gender': 0, 'depar...
# My Date with Drew                         [{'name': 'Clark Peterson', 'gender': 2, 'depa...
#
#                                                    director  ...  Romance  \
# original_title                                               ...
# Avatar                                        James Cameron  ...        0
# Pirates of the Caribbean: At World's End     Gore Verbinski  ...        0
# Spectre                                          Sam Mendes  ...        0
# The Dark Knight Rises                     Christopher Nolan  ...        0
# John Carter                                  Andrew Stanton  ...        0
# ...                                                     ...  ...      ...
# Bang                                        Ash Baron-Cohen  ...        0
# Primer                                        Shane Carruth  ...        0
# Newlyweds                                      Edward Burns  ...        1
# Signed, Sealed, Delivered                       Scott Smith  ...        1
# My Date with Drew                          Brian Herzlinger  ...        0
#
#                                           Horror  Mystery  History  War  \
# original_title
# Avatar                                         0        0        0    0
# Pirates of the Caribbean: At World's End       0        0        0    0
# Spectre                                        0        0        0    0
# The Dark Knight Rises                          0        0        0    0
# John Carter                                    0        0        0    0
# ...                                          ...      ...      ...  ...
# Bang                                           0        0        0    0
# Primer                                         0        0        0    0
# Newlyweds                                      0        0        0    0
# Signed, Sealed, Delivered                      0        0        0    0
# My Date with Drew                              0        0        0    0
#
#                                           Music  Documentary  Foreign  TV  \
# original_title
# Avatar                                        0            0        0   0
# Pirates of the Caribbean: At World's End      0            0        0   0
# Spectre                                       0            0        0   0
# The Dark Knight Rises                         0            0        0   0
# John Carter                                   0            0        0   0
# ...                                         ...          ...      ...  ..
# Bang                                          0            0        0   0
# Primer                                        0            0        0   0
# Newlyweds                                     0            0        0   0
# Signed, Sealed, Delivered                     0            0        0   1
# My Date with Drew                             0            1        0   0
#
#                                                                                    overview
# original_title
# Avatar                                    [in, the, 22nd, century, a, paraplegic, marine...
# Pirates of the Caribbean: At World's End  [captain, barbossa, long, believed, to, be, de...
# Spectre                                   [a, cryptic, message, from, bond, s, past, sen...
# The Dark Knight Rises                     [following, the, death, of, district, attorney...
# John Carter                               [john, carter, is, a, war, weary, former, mili...
# ...                                                                                     ...
# Bang                                      [a, young, woman, in, l, a, is, having, a, bad...
# Primer                                    [friend, fledgling, entrepreneur, invent, a, d...
# Newlyweds                                 [a, newlywed, couple, s, honeymoon, is, upende...
# Signed, Sealed, Delivered                 [signed, sealed, delivered, introduces, a, ded...
# My Date with Drew                         [ever, since, the, second, grade, when, he, fi...
#
# [4445 rows x 31 columns]

# %%
movies[movies['revenue'] == 0].shape
# Out:
# (0, 31)

# %% [markdown]
# It worked! All movies with a revenue of `$0` has now been replaced with the mean revenue in the dataset of `$120,540,082.02`.

# %%
movies.columns
# Out:
# Index(['budget', 'release_date', 'revenue', 'runtime', 'vote_average',
#        'vote_count', 'cast', 'crew', 'director', 'Action', 'Adventure',
#        'Fantasy', 'Science_Fiction', 'Crime', 'Drama', 'Thriller', 'Animation',
#        'Family', 'Western', 'Comedy', 'Romance', 'Horror', 'Mystery',
#        'History', 'War', 'Music', 'Documentary', 'Foreign', 'TV', 'overview'],
#       dtype='object')

# %% [markdown]
# #### Director

# %%
# Preview director column
movies['director'].isna().sum()
# Out:
# original_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# John Carter                                    Andrew Stanton
#                                                   ...
# Bang                                          Ash Baron-Cohen
# Primer                                          Shane Carruth
# Newlyweds                                        Edward Burns
# Signed, Sealed, Delivered                         Scott Smith
# My Date with Drew                            Brian Herzlinger
# Name: director, Length: 4445, dtype: object

# %%
# How many movies are there with null values in the 'director' column?
movies['director'].isna().sum()
# Out:
# 7

# %%
# Drop nulls from movie dataset
movies = movies[movies['director'].isna() == False]

# %% [markdown]
# #### Crew

# %%
movies['crew']
# Out:
# original_title
# Avatar                                      [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...
# Pirates of the Caribbean: At World's End    [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...
# Spectre                                     [{'name': 'Thomas Newman', 'gender': 2, 'depar...
# The Dark Knight Rises                       [{'name': 'Hans Zimmer', 'gender': 2, 'departm...
# John Carter                                 [{'name': 'Andrew Stanton', 'gender': 2, 'depa...
#                                                                   ...
# Bang                                        [{'name': 'Ash Baron-Cohen', 'gender': 0, 'dep...
# Primer                                      [{'name': 'Shane Carruth', 'gender': 2, 'depar...
# Newlyweds                                   [{'name': 'Edward Burns', 'gender': 2, 'depart...
# Signed, Sealed, Delivered                   [{'name': 'Carla Hetland', 'gender': 0, 'depar...
# My Date with Drew                           [{'name': 'Clark Peterson', 'gender': 2, 'depa...
# Name: crew, Length: 4438, dtype: object

# %%
movies.drop(columns = ['crew'], inplace = True)
# Out:
# /Users/michaellaccavole/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
movies
# Out:
#                                                 budget release_date  \
# original_title
# Avatar                                    2.370000e+08   2009-12-10
# Pirates of the Caribbean: At World's End  3.000000e+08   2007-05-19
# Spectre                                   2.450000e+08   2015-10-26
# The Dark Knight Rises                     2.500000e+08   2012-07-16
# John Carter                               2.600000e+08   2012-03-07
# ...                                                ...          ...
# Bang                                      3.834102e+07   1995-09-09
# Primer                                    7.000000e+03   2004-10-08
# Newlyweds                                 9.000000e+03   2011-12-26
# Signed, Sealed, Delivered                 3.834102e+07   2013-10-13
# My Date with Drew                         3.834102e+07   2005-08-05
#
#                                                revenue  runtime  vote_average  \
# original_title
# Avatar                                    2.787965e+09    162.0           7.2
# Pirates of the Caribbean: At World's End  9.610000e+08    169.0           6.9
# Spectre                                   8.806746e+08    148.0           6.3
# The Dark Knight Rises                     1.084939e+09    165.0           7.6
# John Carter                               2.841391e+08    132.0           6.1
# ...                                                ...      ...           ...
# Bang                                      1.206408e+08     98.0           6.0
# Primer                                    4.247600e+05     77.0           6.9
# Newlyweds                                 1.206408e+08     85.0           5.9
# Signed, Sealed, Delivered                 1.206408e+08    120.0           7.0
# My Date with Drew                         1.206408e+08     90.0           6.3
#
#                                           vote_count  \
# original_title
# Avatar                                         11800
# Pirates of the Caribbean: At World's End        4500
# Spectre                                         4466
# The Dark Knight Rises                           9106
# John Carter                                     2124
# ...                                              ...
# Bang                                               1
# Primer                                           658
# Newlyweds                                          5
# Signed, Sealed, Delivered                          6
# My Date with Drew                                 16
#
#                                                                                        cast  \
# original_title
# Avatar                                    [Sam, Worthington, Zoe, Saldana, Sigourney, We...
# Pirates of the Caribbean: At World's End  [Johnny, Depp, Orlando, Bloom, Keira, Knightle...
# Spectre                                   [Daniel, Craig, Christoph, Waltz, Luea, Seydou...
# The Dark Knight Rises                     [Christian, Bale, Michael, Caine, Gary, Oldman...
# John Carter                               [Taylor, Kitsch, Lynn, Collins, Samantha, Mort...
# ...                                                                                     ...
# Bang                                      [Darling, Narita, Peter, Greene, Michael, Newl...
# Primer                                    [Shane, Carruth, David, Sullivan, Casey, Goode...
# Newlyweds                                 [Edward, Burns, Kerry, Bishue, Marsha, Dietlei...
# Signed, Sealed, Delivered                 [Eric, Mabius, Kristin, Booth, Crystal, Lowe, ...
# My Date with Drew                         [Drew, Barrymore, Brian, Herzlinger, Corey, Fe...
#
#                                                    director  Action  \
# original_title
# Avatar                                        James Cameron       1
# Pirates of the Caribbean: At World's End     Gore Verbinski       1
# Spectre                                          Sam Mendes       1
# The Dark Knight Rises                     Christopher Nolan       1
# John Carter                                  Andrew Stanton       1
# ...                                                     ...     ...
# Bang                                        Ash Baron-Cohen       0
# Primer                                        Shane Carruth       0
# Newlyweds                                      Edward Burns       0
# Signed, Sealed, Delivered                       Scott Smith       0
# My Date with Drew                          Brian Herzlinger       0
#
#                                           Adventure  ...  Romance  Horror  \
# original_title                                       ...
# Avatar                                            1  ...        0       0
# Pirates of the Caribbean: At World's End          1  ...        0       0
# Spectre                                           1  ...        0       0
# The Dark Knight Rises                             0  ...        0       0
# John Carter                                       1  ...        0       0
# ...                                             ...  ...      ...     ...
# Bang                                              0  ...        0       0
# Primer                                            0  ...        0       0
# Newlyweds                                         0  ...        1       0
# Signed, Sealed, Delivered                         0  ...        1       0
# My Date with Drew                                 0  ...        0       0
#
#                                           Mystery  History  War  Music  \
# original_title
# Avatar                                          0        0    0      0
# Pirates of the Caribbean: At World's End        0        0    0      0
# Spectre                                         0        0    0      0
# The Dark Knight Rises                           0        0    0      0
# John Carter                                     0        0    0      0
# ...                                           ...      ...  ...    ...
# Bang                                            0        0    0      0
# Primer                                          0        0    0      0
# Newlyweds                                       0        0    0      0
# Signed, Sealed, Delivered                       0        0    0      0
# My Date with Drew                               0        0    0      0
#
#                                           Documentary  Foreign  TV  \
# original_title
# Avatar                                              0        0   0
# Pirates of the Caribbean: At World's End            0        0   0
# Spectre                                             0        0   0
# The Dark Knight Rises                               0        0   0
# John Carter                                         0        0   0
# ...                                               ...      ...  ..
# Bang                                                0        0   0
# Primer                                              0        0   0
# Newlyweds                                           0        0   0
# Signed, Sealed, Delivered                           0        0   1
# My Date with Drew                                   1        0   0
#
#                                                                                    overview
# original_title
# Avatar                                    [in, the, 22nd, century, a, paraplegic, marine...
# Pirates of the Caribbean: At World's End  [captain, barbossa, long, believed, to, be, de...
# Spectre                                   [a, cryptic, message, from, bond, s, past, sen...
# The Dark Knight Rises                     [following, the, death, of, district, attorney...
# John Carter                               [john, carter, is, a, war, weary, former, mili...
# ...                                                                                     ...
# Bang                                      [a, young, woman, in, l, a, is, having, a, bad...
# Primer                                    [friend, fledgling, entrepreneur, invent, a, d...
# Newlyweds                                 [a, newlywed, couple, s, honeymoon, is, upende...
# Signed, Sealed, Delivered                 [signed, sealed, delivered, introduces, a, ded...
# My Date with Drew                         [ever, since, the, second, grade, when, he, fi...
#
# [4438 rows x 29 columns]

# %%
pd.to_csv
